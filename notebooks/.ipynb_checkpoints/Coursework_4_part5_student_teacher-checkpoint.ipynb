# %% [markdown]
# 2017
#
# Machine Learning Practical
#
# University of Edinburgh
#
# Georgios Pligoropoulos - s1687568
#
# Coursework 4 (part 5)

# %% [markdown]
# ### Imports, Inits, and helper functions

# %%
jupyterNotebookEnabled = True
plotting = True
saving = False
coursework, part = 4, 5

if jupyterNotebookEnabled:
    # %load_ext autoreload
    # %autoreload 2

# %%
import sys
import os
mlpdir = os.path.expanduser(
    '~/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical'
)
sys.path.append(mlpdir)

# %%
import pickle
import skopt
from skopt.plots import plot_convergence
import datetime
import time
import tensorflow as tf
import numpy as np
    
import matplotlib.pyplot as plt

from mylibs.tf_helper import tfRMSE, tfMSE, fully_connected_layer, trainEpoch, validateEpoch

from mylibs.py_helper import merge_dicts
    
from mylibs.dropout_helper import constructProbs

from skopt.space.space import Real, Integer
from skopt import gp_minimize

from mylibs.jupyter_notebook_helper import show_graph

from mlp.data_providers import DataProvider, \
    MSD10GenreDataProvider, MSD25GenreDataProvider,\
    MSD10Genre_Autoencoder_DataProvider, MSD10Genre_StackedAutoEncoderDataProvider
    
from mylibs.batch_norm import batchNormWrapper_byExponentialMovingAvg, fully_connected_layer_with_batch_norm

from mylibs.batch_norm import fully_connected_layer_with_batch_norm_and_l2

from mylibs.stacked_autoencoder_pretrainer import \
    constructModelFromPretrainedByAutoEncoderStack,\
    buildGraphOfStackedAutoencoder, executeNonLinearAutoencoder
    
from mylibs.jupyter_notebook_helper import getRunTime, getTrainWriter, getValidWriter,\
    plotStats, initStats, gatherStats, renderStatsCollection

# %%
if jupyterNotebookEnabled:
    # %matplotlib inline

seed = 16011984
rng = np.random.RandomState(seed=seed)

config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)
config.gpu_options.allow_growth = True

figcount = 0

tensorboardLogdir = 'tf_cw{}_{}'.format(coursework, part)

curDtype = tf.float32

reluBias = 0.1

batch_size = 50
numTestSongs = 9950
numClasses = 10

# %%
#http://stackoverflow.com/questions/6568007/how-do-i-save-and-restore-multiple-variables-in-python
def loadPythonVarOrSave(filename, lambda_var):
    if os.path.isfile(filename):
        with open(filename) as f:  # Python 3: open(..., 'rb')
            (thevar, ) = pickle.load(f)
    else:
        thevar = lambda_var()
        with open(filename, 'w') as f:  # Python 3: open(..., 'wb')
            pickle.dump([thevar], f)
            
    return thevar

# %% [markdown]
# ### MSD 10 genre task

# %%
#we want a provider that has as inputs our regular inputs but as outputs the outputs
#we got from the teacher deep-state-of-the-art neural net

# %%
from models.teacher_student_nn import MSD10Genre_Teacher_DataProvider, StudentNN

# %%
#show_graph(studentNN.loadAndGetGraph())
dataset_filename = 'msd-10-genre-train_valid.npz'

# %%
logits_filename = 'rnn_logits.npy'

# %%
studentNN = StudentNN(batch_size=batch_size, rng=rng, dtype=curDtype, config=config)

# %%
show_graph(studentNN.loadAndGetGraph(verbose=False))
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-03-13_22-01-10&quot;).pbtxt = 'node {\n  name: &quot;data/inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;data/targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;params/training&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;data/inputs&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;dropout_inputs/dropout/Shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/max&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/RandomUniform&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/mul&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/add&quot;\n  op: &quot;Add&quot;\n  input: &quot;dropout_inputs/Placeholder&quot;\n  input: &quot;dropout_inputs/dropout/random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;dropout_inputs/dropout/Floor&quot;\n  op: &quot;Floor&quot;\n  input: &quot;dropout_inputs/dropout/add&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name ...

# %% [markdown]
# ## Bayesian Opt

# %%
learning_rate = "1e-4" #1e-4 and 1e-5 have ran already

# %%
epochs = 40 if learning_rate == "1e-5" else 20
epochs
# Out:
# 20

# %%
res_gp_save_filename = 'student_teacher/{}/student_teacher_res_gp.pickle'.\
    format(learning_rate)
statsCollectionFilename = 'student_teacher/{}/student_teacher_bay_opt_statsCollection.npy'.\
    format(learning_rate)
best_params_student_teacher_filename = 'student_teacher/{}/student_teacher_best_params.npy'.\
    format(learning_rate)

# %%
def objective(params): # Here we define the metric we want to minimise
    input_keep_prob, hidden_keep_prob, hidden_dim, lamda2 = params
    
    epochs = epochs
    learning_rate = float(learning_rate)
        
    studentNN = StudentNN(batch_size=batch_size, rng=rng, dtype=curDtype, config=config)

    stats, keys = studentNN.teach_student(
        hidden_dim = hidden_dim,
        lamda2 = lamda2,
        learning_rate = learning_rate,
        epochs = epochs,
        input_keep_prob = input_keep_prob,
        hidden_keep_prob = hidden_keep_prob,
        dataset_filename = dataset_filename,
        logits_filename = logits_filename,
    )
    
    #save everytime in case it crashes
    filename = statsCollectionFilename
    statsCollection = np.load(filename)[()] if os.path.isfile(filename) else dict()
    statsCollection[tuple(params)] = stats
    np.save(filename, statsCollection)
    
    if plotting:
        fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys)
        plt.show()
    
    validAccs = stats[:, -1]
    length10percent = len(validAccs) // 10
    best10percent = np.sort(validAccs)[-length10percent:]
    # We want to maximise the MEAN validation accuracy,
    # i.e. minimise minus
    return -np.mean(best10percent)

# %%
inputKeepProbSpace = Real(0.5, 1.0, "uniform")
hiddenKeepProbSpace = Real(0.5, 1.0, "uniform")
hiddenDimSpace = Integer(20, 2000)
lamda2Space = Real(1e-3, 10, "log-uniform")
space  = [inputKeepProbSpace, hiddenKeepProbSpace, hiddenDimSpace, lamda2Space]

# %% [markdown]
# TARGET IS 58% as the original Deep Neural Net

# %%
if jupyterNotebookEnabled:
    # %%time

#this might crash so you need to run it outside as a python file (file -> save as python)
if not os.path.isfile(res_gp_save_filename):
    if os.path.isfile(statsCollectionFilename):
        os.remove(statsCollectionFilename) #erase before executing
    
    res_gp = gp_minimize(
        func=objective, # function that we wish to minimise
        dimensions=space, #the search space for the hyper-parameters
        #x0=x0, #inital values for the hyper-parameters
        n_calls=50, #number of times the function will be evaluated
        random_state = seed, #random seed
        n_random_starts=5,
            #before we start modelling the optimised function with a GP Regression
            #model, we want to try a few random choices for the hyper-parameters.
        kappa=1.9 #trade-off between exploration vs. exploitation.
    )
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.11 µs

# %%
res_gp = loadPythonVarOrSave(res_gp_save_filename, lambda : res_gp)

# %%
if os.path.isfile(best_params_student_teacher_filename):
    best_params_student_teacher = np.load(best_params_student_teacher_filename)
else:
    np.save(best_params_student_teacher_filename, res_gp.x)
    best_params_student_teacher = res_gp.x
    
best_params_student_teacher
# Out:
# array([  5.00000000e-01,   1.00000000e+00,   1.78400000e+03,
#          1.00000000e-03])

# %%
print "Best score with Bayesian optimisation: {:.3f}".format(-res_gp.fun)
print
print "Best parameters with Bayesian optimisation:"
res_gp.x
# Out:
# Best score with Bayesian optimisation: 0.479
#
# Best parameters with Bayesian optimisation:
# [0.5, 1.0, 1784, 0.001]

# %% [markdown]
# #### Bayesian Optimization plots

# %%
if plotting:
    fig = plt.figure(figsize=(12,6))
    plot_convergence(res_gp)
    plt.grid()
    plt.title('convergence plot')
    plt.ylabel('output of objective function')
    plt.xlabel('Number of calls n')
    plt.show()
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_conv_plot.svg'.format(
            coursework, part, learning_rate
        ))

# %%
if plotting:
    fig = plt.figure(figsize=(12,6))
    plt.hold(True)
    plt.plot(res_gp.func_vals)
    plt.scatter(range(len(res_gp.func_vals)), res_gp.func_vals)
    plt.hold(False)
    plt.ylabel(r'$f(x)$')
    plt.xlabel('Number of calls $n$')
    plt.xlim([0, len(res_gp.func_vals)])
    plt.show()
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_func_val.svg'.format(
            coursework, part, learning_rate
        ))
# Out:
# /home/studenthp/anaconda2/envs/mlp/lib/python2.7/site-packages/ipykernel/__main__.py:3: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   app.launch_new_instance()
# /home/studenthp/anaconda2/envs/mlp/lib/python2.7/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/studenthp/anaconda2/envs/mlp/lib/python2.7/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
# /home/studenthp/anaconda2/envs/mlp/lib/python2.7/site-packages/ipykernel/__main__.py:6: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.

# %%
statsCollection = np.load(statsCollectionFilename)[()]

# %%
if plotting:
    key = "error(train)"
    fig = renderStatsCollection(statsCollection, epochs = epochs, title = "Training Error",
                          k = key, label_texts = ['input_keep_prob', 'hidden_keep_prob',
                                                 'hidden_dim', 'lamda2'])
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_{}.svg'.format(
            coursework, part, learning_rate, key
        ))
# Out:
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:166: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(True)
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:168: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(False)

# %%
if plotting:
    key = "error(valid)"
    fig = renderStatsCollection(statsCollection, epochs = epochs,
                                title = "Validation Error",
                                k = key, label_texts = [
                                    'input_keep_prob', 'hidden_keep_prob',
                                                 'hidden_dim', 'lamda2'])
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_{}.svg'.format(
            coursework, part, learning_rate, key
        ))

# %%
if plotting:
    key = "acc(train)"
    fig = renderStatsCollection(statsCollection, epochs = epochs, title = "Training Accuracy",
                          k = key, label_texts = ['input_keep_prob', 'hidden_keep_prob',
                                                 'hidden_dim', 'lamda2'])
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_{}.svg'.format(
            coursework, part, learning_rate, key
        ))

# %%
if plotting:
    key = "acc(valid)"
    fig = renderStatsCollection(statsCollection, epochs = epochs, title = "Validation Accuracy",
                          k = key, label_texts = ['input_keep_prob', 'hidden_keep_prob',
                                                 'hidden_dim', 'lamda2'])
    if saving:
        fig.savefig('cw{}_part{}_fig_bayes_opt_{}_{}.svg'.format(
            coursework, part, learning_rate, key
        ))

# %% [markdown]
# ### Running full training of shallow neural net

# %%
input_keep_prob, hidden_keep_prob, hidden_dim, lamda2 = best_params_student_teacher
hidden_dim = int(hidden_dim)

epochs = 100

studentNN = StudentNN(batch_size=batch_size, rng=rng, dtype=curDtype, config=config)

stats, keys = studentNN.teach_student(
    hidden_dim = hidden_dim,
    lamda2 = lamda2,
    learning_rate = float(learning_rate),
    epochs = epochs,
    input_keep_prob = input_keep_prob,
    hidden_keep_prob = hidden_keep_prob,
    dataset_filename = dataset_filename,
    logits_filename = logits_filename,
)

if plotting:
    fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys)
    plt.show()
    if saving:
        fig_1.savefig('cw{}_part{}_fig_{}_error.svg'.format(
            coursework, part, learning_rate
        ))
        fig_2.savefig('cw{}_part{}_fig_{}_acc.svg'.format(
            coursework, part, learning_rate
        ))
# Out:
# lamda2: 0.001000
# hidden dim: 1784
# learning rate: 0.000100
# epochs: 100
# input_keep_prob: 0.500000
# hidden_keep_prob: 1.000000
# the inputs have 50000 length and the targets have 50000 length
# End epoch 01 (49.276 secs):err(train)=10.87,acc(train)=0.42,err(valid)=3.12,acc(valid)=0.40,
# End epoch 02 (48.928 secs):err(train)=9.83,acc(train)=0.45,err(valid)=2.72,acc(valid)=0.42,
# End epoch 03 (48.839 secs):err(train)=8.95,acc(train)=0.46,err(valid)=2.42,acc(valid)=0.42,
# End epoch 04 (49.073 secs):err(train)=8.18,acc(train)=0.47,err(valid)=2.20,acc(valid)=0.43,
# End epoch 05 (48.950 secs):err(train)=7.50,acc(train)=0.48,err(valid)=2.06,acc(valid)=0.43,
# End epoch 06 (48.982 secs):err(train)=6.92,acc(train)=0.48,err(valid)=1.95,acc(valid)=0.44,
# End epoch 07 (48.923 secs):err(train)=6.41,acc(train)=0.49,err(valid)=1.86,acc(valid)=0.44,
# End epoch 08 (48.960 secs):err(train)=5.95,acc(train)=0.49,err(valid)=1.81,acc(valid)=0.45,
# End epoch 09 (48.962 secs):err(train)=5.53,acc(train)=0.50,err(valid)=1.76,acc(valid)=0.45,
# End epoch 10 (48.942 secs):err(train)=5.16,acc(train)=0.51,err(valid)=1.73,acc(valid)=0.45,
# End epoch 11 (48.983 secs):err(train)=4.83,acc(train)=0.51,err(valid)=1.71,acc(valid)=0.46,
# End epoch 12 (48.932 secs):err(train)=4.51,acc(train)=0.52,err(valid)=1.70,acc(valid)=0.46,
# End epoch 13 (48.979 secs):err(train)=4.22,acc(train)=0.52,err(valid)=1.68,acc(valid)=0.47,
# End epoch 14 (48.911 secs):err(train)=3.96,acc(train)=0.53,err(valid)=1.66,acc(valid)=0.47,
# End epoch 15 (48.979 secs):err(train)=3.71,acc(train)=0.53,err(valid)=1.66,acc(valid)=0.47,
# End epoch 16 (48.980 secs):err(train)=3.49,acc(train)=0.53,err(valid)=1.65,acc(valid)=0.47,
# End epoch 17 (48.943 secs):err(train)=3.29,acc(train)=0.54,err(valid)=1.65,acc(valid)=0.47,
# End epoch 18 (49.018 secs):err(train)=3.10,acc(train)=0.54,err(valid)=1.64,acc(valid)=0.48,
# End epoch 19 (49.023 secs):err(train)=2.93,acc(train)=0.55,err(valid)=1.64,acc(valid)=0.48,
# End epoch 20 (49.232 secs):err(train)=2.78,acc(train)=0.55,err(valid)=1.63,acc(valid)=0.48,
# End epoch 21 (48.895 secs):err(train)=2.64,acc(train)=0.56,err(valid)=1.63,acc(valid)=0.48,
# End epoch 22 (48.915 secs):err(train)=2.51,acc(train)=0.57,err(valid)=1.63,acc(valid)=0.48,
# End epoch 23 (48.914 secs):err(train)=2.40,acc(train)=0.57,err(valid)=1.62,acc(valid)=0.49,
# End epoch 24 (48.927 secs):err(train)=2.30,acc(train)=0.58,err(valid)=1.61,acc(valid)=0.49,
# End epoch 25 (48.907 secs):err(train)=2.20,acc(train)=0.58,err(valid)=1.62,acc(valid)=0.49,
# End epoch 26 (48.891 secs):err(train)=2.13,acc(train)=0.59,err(valid)=1.63,acc(valid)=0.49,
# End epoch 27 (49.454 secs):err(train)=2.05,acc(train)=0.59,err(valid)=1.61,acc(valid)=0.49,
# End epoch 28 (48.944 secs):err(train)=2.00,acc(train)=0.59,err(valid)=1.61,acc(valid)=0.49,
# End epoch 29 (48.886 secs):err(train)=1.94,acc(train)=0.60,err(valid)=1.62,acc(valid)=0.49,
# End epoch 30 (48.991 secs):err(train)=1.90,acc(train)=0.60,err(valid)=1.62,acc(valid)=0.50,
# End epoch 31 (48.883 secs):err(train)=1.86,acc(train)=0.61,err(valid)=1.62,acc(valid)=0.50,
# End epoch 32 (49.164 secs):err(train)=1.83,acc(train)=0.61,err(valid)=1.62,acc(valid)=0.50,
# End epoch 33 (50.422 secs):err(train)=1.80,acc(train)=0.61,err(valid)=1.63,acc(valid)=0.49,
# End epoch 34 (49.114 secs):err(train)=1.77,acc(train)=0.62,err(valid)=1.63,acc(valid)=0.50,
# End epoch 35 (49.066 secs):err(train)=1.74,acc(train)=0.62,err(valid)=1.63,acc(valid)=0.50,
# End epoch 36 (48.976 secs):err(train)=1.72,acc(train)=0.62,err(valid)=1.64,acc(valid)=0.49,
# End epoch 37 (48.937 secs):err(train)=1.71,acc(train)=0.62,err(valid)=1.64,acc(valid)=0.49,
# End epoch 38 (48.837 secs):err(train)=1.68,acc(train)=0.63,err(valid)=1.65,acc(valid)=0.49,
# End epoch 39 (48.906 secs):err(train)=1.67,acc(train)=0.63,err(valid)=1.64,acc(valid)=0.49,
# End epoch 40 (48.916 secs):err(train)=1.65,acc(train)=0.63,err(valid)=1.66,acc(valid)=0.49,
# End epoch 41 (48.959 secs):err(train)=1.64,acc(train)=0.63,err(valid)=1.66,acc(valid)=0.49,
# End epoch 42 (48.930 secs):err(train)=1.64,acc(train)=0.63,err(valid)=1.66,acc(valid)=0.49,
# End epoch 43 (48.867 secs):err(train)=1.61,acc(train)=0.64,err(valid)=1.66,acc(valid)=0.49,
# End epoch 44 (48.955 secs):err(train)=1.61,acc(train)=0.64,err(valid)=1.67,acc(valid)=0.49,
# End epoch 45 (48.941 secs):err(train)=1.59,acc(train)=0.64,err(valid)=1.67,acc(valid)=0.49,
# End epoch 46 (48.937 secs):err(train)=1.58,acc(train)=0.64,err(valid)=1.68,acc(valid)=0.50,
# End epoch 47 (48.883 secs):err(train)=1.57,acc(train)=0.64,err(valid)=1.67,acc(valid)=0.50,
# End epoch 48 (48.951 secs):err(train)=1.56,acc(train)=0.64,err(valid)=1.69,acc(valid)=0.49,
# End epoch 49 (51.388 secs):err(train)=1.55,acc(train)=0.65,err(valid)=1.68,acc(valid)=0.49,
# End epoch 50 (48.967 secs):err(train)=1.53,acc(train)=0.65,err(valid)=1.68,acc(valid)=0.49,
# End epoch 51 (48.942 secs):err(train)=1.54,acc(train)=0.65,err(valid)=1.69,acc(valid)=0.49,
# End epoch 52 (48.937 secs):err(train)=1.53,acc(train)=0.65,err(valid)=1.69,acc(valid)=0.49,
# End epoch 53 (48.966 secs):err(train)=1.51,acc(train)=0.66,err(valid)=1.69,acc(valid)=0.49,
# End epoch 54 (49.009 secs):err(train)=1.50,acc(train)=0.66,err(valid)=1.70,acc(valid)=0.49,
# End epoch 55 (49.008 secs):err(train)=1.50,acc(train)=0.66,err(valid)=1.69,acc(valid)=0.50,
# End epoch 56 (48.991 secs):err(train)=1.50,acc(train)=0.66,err(valid)=1.70,acc(valid)=0.49,
# End epoch 57 (48.974 secs):err(train)=1.50,acc(train)=0.66,err(valid)=1.71,acc(valid)=0.49,
# End epoch 58 (49.031 secs):err(train)=1.48,acc(train)=0.66,err(valid)=1.71,acc(valid)=0.49,
# End epoch 59 (48.991 secs):err(train)=1.48,acc(train)=0.66,err(valid)=1.71,acc(valid)=0.49,
# End epoch 60 (48.989 secs):err(train)=1.48,acc(train)=0.67,err(valid)=1.71,acc(valid)=0.50,
# End epoch 61 (49.012 secs):err(train)=1.48,acc(train)=0.66,err(valid)=1.72,acc(valid)=0.49,
# End epoch 62 (48.956 secs):err(train)=1.46,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.49,
# End epoch 63 (48.987 secs):err(train)=1.46,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.49,
# End epoch 64 (49.009 secs):err(train)=1.46,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.49,
# End epoch 65 (49.324 secs):err(train)=1.46,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.49,
# End epoch 66 (48.981 secs):err(train)=1.45,acc(train)=0.67,err(valid)=1.73,acc(valid)=0.49,
# End epoch 67 (49.018 secs):err(train)=1.45,acc(train)=0.67,err(valid)=1.73,acc(valid)=0.49,
# End epoch 68 (48.996 secs):err(train)=1.44,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.49,
# End epoch 69 (49.081 secs):err(train)=1.44,acc(train)=0.67,err(valid)=1.72,acc(valid)=0.50,
# End epoch 70 (49.087 secs):err(train)=1.43,acc(train)=0.67,err(valid)=1.73,acc(valid)=0.49,
# End epoch 71 (49.107 secs):err(train)=1.43,acc(train)=0.67,err(valid)=1.73,acc(valid)=0.49,
# End epoch 72 (49.030 secs):err(train)=1.42,acc(train)=0.67,err(valid)=1.74,acc(valid)=0.49,
# End epoch 73 (48.967 secs):err(train)=1.42,acc(train)=0.68,err(valid)=1.73,acc(valid)=0.49,
# End epoch 74 (49.036 secs):err(train)=1.42,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 75 (48.936 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.73,acc(valid)=0.50,
# End epoch 76 (48.956 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 77 (49.041 secs):err(train)=1.42,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 78 (48.943 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 79 (48.981 secs):err(train)=1.40,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 80 (48.993 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 81 (48.998 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 82 (48.960 secs):err(train)=1.41,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 83 (48.933 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 84 (49.002 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 85 (48.884 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.74,acc(valid)=0.49,
# End epoch 86 (48.988 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 87 (48.941 secs):err(train)=1.38,acc(train)=0.69,err(valid)=1.75,acc(valid)=0.49,
# End epoch 88 (48.934 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.50,
# End epoch 89 (48.966 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 90 (49.234 secs):err(train)=1.39,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 91 (49.115 secs):err(train)=1.38,acc(train)=0.68,err(valid)=1.75,acc(valid)=0.49,
# End epoch 92 (48.986 secs):err(train)=1.39,acc(train)=0.69,err(valid)=1.75,acc(valid)=0.49,
# End epoch 93 (49.019 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.75,acc(valid)=0.49,
# End epoch 94 (48.985 secs):err(train)=1.38,acc(train)=0.69,err(valid)=1.76,acc(valid)=0.49,
# End epoch 95 (48.965 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.75,acc(valid)=0.49,
# End epoch 96 (49.058 secs):err(train)=1.38,acc(train)=0.69,err(valid)=1.76,acc(valid)=0.49,
# End epoch 97 (49.019 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.77,acc(valid)=0.49,
# End epoch 98 (49.023 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.76,acc(valid)=0.49,
# End epoch 99 (48.937 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.77,acc(valid)=0.49,
# End epoch 100 (49.253 secs):err(train)=1.37,acc(train)=0.69,err(valid)=1.76,acc(valid)=0.49,
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:74: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax_1.hold(True)
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:78: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax_1.hold(False)
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:87: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax_2.hold(True)
# /home/studenthp/pligor.george@gmail.com/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical/mylibs/jupyter_notebook_helper.py:91: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax_2.hold(False)

# %% [markdown]
# ## TESTING
