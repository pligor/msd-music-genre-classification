# %% [markdown]
# # Machine Learning Practical: Coursework 2
# ## Experiment 3/3: Stacked Autoencoders
#
# **Due date: 16:00 Thursday 24th November 2016**

# %% [markdown]
# # Georgios Pligoropoulos - s1687568

# %%
import sys
mlpdir = '/home/student/Dropbox/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical'
sys.path.append(mlpdir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import logging
import itertools

#%matplotlib notebook
# %matplotlib inline

# %%
from mlp.data_providers import MNISTDataProvider, MNISTAutoencoderDataProvider, StackedAutoEncoderDataProvider

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, MaxPoolingLayer, DropoutLayer, ReluLayer

from mlp.errors import CrossEntropySoftmaxError, SumOfSquaredDiffsError

from mlp.models import MultipleLayerModel

from mlp.initialisers import ConstantInit, GlorotUniformInit

from mlp.optimisers import Optimiser

from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule, AdamLearningRule, \
    AdaGradLearningRule, RmsPropLearningRule
    
from mlp.schedulers import AnnealedDropoutScheduler, MomentumCoefficientScheduler, ConstantLearningRateScheduler,\
    ReciprocalLearningRateScheduler, ExponentialLearningRateScheduler

# %%
def trainModel(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, schedulers=[]):
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, schedulers = schedulers)

    # Run the optimiser for some number of epochs (full passes through the training set)
    # printing statistics every epoch
    stats, keys, runTime = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
    #stats = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    return stats, keys, runTime

# %%
def plotStats(stats, keys, stats_interval):
    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return fig_1, ax_1, fig_2, ax_2

# %%
def getFinalValues(statistics):
    lastStats = statistics[-1]
    return {
        "Final Training Error": lastStats[0],
        "Final Training Accuracy": lastStats[1],
        "Final Testing Error": lastStats[2],
        "Final Testing Accuracy": lastStats[3],
    }

# %%
# Seed a random number generator
seed = 16011984
rng = np.random.RandomState(seed)

# %%
batchSize = 50

# %% [markdown]
# Note: When in our explanations refer to **accuracy** we mean the final validation accuracy and when we refer to **performance** we mean how fast we reached the optimal accuracy for the current experiment

# %%
figcount = 0

# %% [markdown]
# # Grand Experiment 3: Stacked Autoencoders Pretraining
#
# In this experiment we are going to use stacked autoencoders to optimize the pretraining of our neural network.
#
# Our intentions is a pretraining that is going to have two positive effects:
#
# 1) For large architectures with many layers there is the issue that the backpropagation is more "slow". This is understandable because we have many layers and in order for the error to propagate properly backwards and set the weights at a good level we might have saturations or other effects that cause very slow learning at the first epochs.
# We are going to test that by running an experiment with six or more layers where the slow-learning effect is apparent and then repeat the experiment with our stacked autoencoders pretraining. The expectation is that our pretraining will not go through this phase of slow learning and the learning process is converge more quickly.
#
# 2) We should get a very good performance always in comparison to random initialization of the weights.
# We are going to test that by repeating the same experiment a few times for various random initializations of the weights. Then for the same architecture we are going to pretrain the network using stacked autoencoders and run to see the final error and accuracy of both training and validation set. We must see that this pretraining yields better or equally good results as the best of the cases with the random initializations.

# %%
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# %%
statsInterval = 5

# %% [markdown]
# ### Implementing both Linear and Non-Linear Stacked Autoencoders

# %% [markdown]
# In Autoencoders we need the error to be the difference between output and input. We are not doing classification that is why we are going to use as error the Sum of Squared Differences

# %% [markdown]
# We are going to use the best implementation of our adaptive learning rule which is Adam Learning Rule with default parameters

# %% [markdown]
# We are implementing both a linear and a non-linear autoencoder.
#
# Our Linear autoencoder is going to have a ReLU layer for the output of the first Affine layer and a Sigmoid layer for the output of the second Affine layer

# %%
def executeNonLinearAutoencoder(inputOutputDim, hiddenDim, dataProvider,
                                numEpochs=30, error = SumOfSquaredDiffsError(),
                               nonLinearLayer1 = SigmoidLayer(), nonLinearLayer2=SigmoidLayer()):
    learningRule = AdamLearningRule() # default params
    
    model = MultipleLayerModel([
        AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
        nonLinearLayer1, #ReluLayer(),
        AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
        nonLinearLayer2 #SigmoidLayer()
    ])
    
    stats, keys, runTime = trainModel(
        model=model,
        error=error, 
        learning_rule = learningRule,
        train_data = dataProvider,
        valid_data = None,
        num_epochs = numEpochs,
        stats_interval = statsInterval
    )
    
    def dropUnnecessaryAutoencoderLayers(model):
        return MultipleLayerModel(model.layers[:-2])
    #dropUnnecessaryAutoencoderLayers = lambda model: MultipleLayerModel(model.layers[:-2]) #one liner

    return dropUnnecessaryAutoencoderLayers(model), stats, keys, runTime

# %%
def executeLinearAutoencoder(inputOutputDim, hiddenDim, dataProvider,
                             numEpochs=30, error = SumOfSquaredDiffsError()):
    learningRule = AdamLearningRule() # default params
    
    model = MultipleLayerModel([
        AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
        AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit)
    ])
    
    stats, keys, runTime = trainModel(
        model=model,
        error=error, 
        learning_rule = learningRule,
        train_data = dataProvider,
        valid_data = None,
        num_epochs = numEpochs,
        stats_interval = statsInterval
    )
    
    def dropUnnecessaryAutoencoderLayers(model):
        return MultipleLayerModel(model.layers[:-1])

    return dropUnnecessaryAutoencoderLayers(model), stats, keys, runTime

# %%
def concatenateModels(models):
    layersCollection = [model.layers for model in models]
    flattenLayers = sum(layersCollection, []) #np.array(layersCollection).flatten()
    return MultipleLayerModel(flattenLayers)

# %%
def constructModelFromPretrainedByAutoEncoderStack(hiddenDimLayers, autoencoder, inputDim = 784,
                                                   batchSize=batchSize, rng=rng):
    #preTrainedModels = []
    curInputDim = inputDim
    curModel = None
    for hiddenDimLayer in hiddenDimLayers:
        dataProvider = StackedAutoEncoderDataProvider('train', batch_size=batchSize, rng=rng, model=curModel)
        preTrainedModel, stats, keys, runTime = autoencoder(curInputDim, hiddenDimLayer, dataProvider)

        curInputDim = hiddenDimLayer
        curModel = preTrainedModel if curModel is None else concatenateModels([curModel, preTrainedModel])
        #preTrainedModels.append(model)
        
    return curModel

# %% [markdown]
# StackedAutoEncoderDataProvider is a special data provider which extends the MNISTDataProvider with one extra parameter: the model
#
# Recall that for autoencoders we need only the input data therefore the output classificaiton is neglected, ignored.
#
# If model is None then the StackedAutoEncoderDataProvider falls back to a simple MNISTDataProvider which returns the inputs as inputs and ouputs.
#
# When model is set then the inputs are transformed. The inputs are passing through all the layers of the model with the *fprop* method and this representation is returned as both inputs and outputs.
#
# Therefore we are capable to use this implementation for any layer of our stacked autoencoder.

# %% [markdown]
# ## Experiment A: avoiding slow learning effects on multi-layer neural networks with many layers

# %%
weightsInit = GlorotUniformInit(rng=rng)
biasesInit = ConstantInit(0.)

# %%
# Create data provider objects for the MNIST data set
trainData = MNISTDataProvider('train', batch_size=batchSize, rng=rng)
validData = MNISTDataProvider('valid', batch_size=batchSize, rng=rng)

# %% [markdown]
# ### Six Layers

# %%
num_epochs = 40

input_dim, output_dim, hidden_dim = 784, 10, 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weightsInit, biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weightsInit, biasesInit)
])

learning_rate = 1.1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_6_layers_100_per_layer_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_6_layers_100_per_layer_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.67e+00, acc(train)=9.68e-02, error(valid)=2.66e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 5: 2.29s to complete
#   error(train)=4.20e-01, acc(train)=8.88e-01, error(valid)=4.00e-01, acc(valid)=8.92e-01, params_penalty=0.00e+00
# Epoch 10: 2.40s to complete
#   error(train)=1.04e-01, acc(train)=9.71e-01, error(valid)=1.41e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 15: 2.12s to complete
#   error(train)=4.90e-02, acc(train)=9.86e-01, error(valid)=1.14e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 20: 2.19s to complete
#   error(train)=2.61e-02, acc(train)=9.93e-01, error(valid)=1.10e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 25: 2.24s to complete
#   error(train)=1.62e-02, acc(train)=9.96e-01, error(valid)=1.16e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 30: 2.90s to complete
#   error(train)=1.40e-02, acc(train)=9.96e-01, error(valid)=1.31e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 3.02s to complete
#   error(train)=8.89e-03, acc(train)=9.98e-01, error(valid)=1.39e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 2.28s to complete
#   error(train)=6.99e-03, acc(train)=9.98e-01, error(valid)=1.36e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# figcount: 1
# Run Time:
# 111.428107977
# {'Final Testing Accuracy': 0.97249999999999903,
#  'Final Testing Error': 0.13592290449311858,
#  'Final Training Accuracy': 0.99816000000000116,
#  'Final Training Error': 0.0069894214987917744}

# %% [markdown]
# Now let's construct a model of six layers with 100 dimensionality in each hidden layer via a Linear Stacked AutoEncoder

# %%
#hiddenDims = np.repeat(100, 5)
hiddenDims = np.concatenate( (np.repeat(100, 5), np.array([10])) )
hiddenDims
# Out:
# array([100, 100, 100, 100, 100,  10])

# %%
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=6.21e+01, acc(train)=8.60e-04, params_penalty=0.00e+00
# Epoch 5: 3.65s to complete
#   error(train)=2.31e+00, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 10: 3.68s to complete
#   error(train)=2.31e+00, acc(train)=1.41e-02, params_penalty=0.00e+00
# Epoch 15: 3.74s to complete
#   error(train)=2.31e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 20: 4.92s to complete
#   error(train)=2.31e+00, acc(train)=1.49e-02, params_penalty=0.00e+00
# Epoch 25: 5.50s to complete
#   error(train)=2.30e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 30: 4.85s to complete
#   error(train)=2.29e+00, acc(train)=1.49e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.95e+00, acc(train)=5.66e-03, params_penalty=0.00e+00
# Epoch 5: 0.82s to complete
#   error(train)=1.99e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.76s to complete
#   error(train)=3.15e-04, acc(train)=9.90e-01, params_penalty=0.00e+00
# Epoch 15: 0.94s to complete
#   error(train)=3.52e-04, acc(train)=9.91e-01, params_penalty=0.00e+00
# Epoch 20: 1.52s to complete
#   error(train)=1.92e-04, acc(train)=9.93e-01, params_penalty=0.00e+00
# Epoch 25: 0.78s to complete
#   error(train)=2.58e-04, acc(train)=9.92e-01, params_penalty=0.00e+00
# Epoch 30: 0.87s to complete
#   error(train)=2.55e-04, acc(train)=9.94e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.64e+00, acc(train)=7.80e-03, params_penalty=0.00e+00
# Epoch 5: 0.89s to complete
#   error(train)=2.18e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 0.83s to complete
#   error(train)=3.74e-04, acc(train)=9.84e-01, params_penalty=0.00e+00
# Epoch 15: 0.99s to complete
#   error(train)=2.40e-04, acc(train)=9.88e-01, params_penalty=0.00e+00
# Epoch 20: 0.94s to complete
#   error(train)=5.95e-04, acc(train)=9.81e-01, params_penalty=0.00e+00
# Epoch 25: 1.42s to complete
#   error(train)=3.80e-04, acc(train)=9.85e-01, params_penalty=0.00e+00
# Epoch 30: 0.83s to complete
#   error(train)=3.37e-04, acc(train)=9.86e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.53e+00, acc(train)=1.12e-02, params_penalty=0.00e+00
# Epoch 5: 0.89s to complete
#   error(train)=2.29e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.79s to complete
#   error(train)=9.00e-04, acc(train)=9.77e-01, params_penalty=0.00e+00
# Epoch 15: 0.90s to complete
#   error(train)=5.79e-04, acc(train)=9.82e-01, params_penalty=0.00e+00
# Epoch 20: 1.69s to complete
#   error(train)=3.09e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 25: 0.91s to complete
#   error(train)=3.11e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 30: 1.15s to complete
#   error(train)=5.09e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.80e+00, acc(train)=1.08e-02, params_penalty=0.00e+00
# Epoch 5: 0.94s to complete
#   error(train)=2.02e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.14s to complete
#   error(train)=7.89e-04, acc(train)=9.77e-01, params_penalty=0.00e+00
# Epoch 15: 1.81s to complete
#   error(train)=4.29e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 20: 0.94s to complete
#   error(train)=2.65e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 25: 1.39s to complete
#   error(train)=3.14e-04, acc(train)=9.84e-01, params_penalty=0.00e+00
# Epoch 30: 0.96s to complete
#   error(train)=2.28e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=4.18e+00, acc(train)=8.50e-03, params_penalty=0.00e+00
# Epoch 5: 0.68s to complete
#   error(train)=2.14e+00, acc(train)=1.46e-01, params_penalty=0.00e+00
# Epoch 10: 1.05s to complete
#   error(train)=2.13e+00, acc(train)=1.47e-01, params_penalty=0.00e+00
# Epoch 15: 0.68s to complete
#   error(train)=2.13e+00, acc(train)=1.50e-01, params_penalty=0.00e+00
# Epoch 20: 1.46s to complete
#   error(train)=2.13e+00, acc(train)=1.47e-01, params_penalty=0.00e+00
# Epoch 25: 0.65s to complete
#   error(train)=2.13e+00, acc(train)=1.46e-01, params_penalty=0.00e+00
# Epoch 30: 0.70s to complete
#   error(train)=2.13e+00, acc(train)=1.45e-01, params_penalty=0.00e+00

# %% [markdown]
# Constructing layer by layer our model by including Sigmoid Layers for non-linearities among our stacked layers from the stacked autoencoder process

# %%
reconstructedModel = MultipleLayerModel([
    model.layers[0],
    SigmoidLayer(),
    model.layers[1], 
    SigmoidLayer(),
    model.layers[2], 
    SigmoidLayer(),
    model.layers[3], 
    SigmoidLayer(),
    model.layers[4],
    SigmoidLayer(),
    model.layers[5]
])

# %%
num_epochs = 40

learningRate = 1.1

learningRule = GradientDescentLearningRule(learning_rate=learningRate)

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1.1
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(
    reconstructedModel,
    error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_6_layers_100_per_layer_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_6_layers_100_per_layer_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02, params_penalty=0.00e+00
# Epoch 5: 3.96s to complete
#   error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 10: 2.22s to complete
#   error(train)=2.31e+00, acc(train)=9.90e-02, error(valid)=2.31e+00, acc(valid)=9.67e-02, params_penalty=0.00e+00
# Epoch 15: 2.18s to complete
#   error(train)=1.48e+00, acc(train)=3.64e-01, error(valid)=1.47e+00, acc(valid)=3.60e-01, params_penalty=0.00e+00
# Epoch 20: 2.61s to complete
#   error(train)=1.17e-01, acc(train)=9.67e-01, error(valid)=1.45e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 25: 2.19s to complete
#   error(train)=5.38e-02, acc(train)=9.85e-01, error(valid)=1.19e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 2.44s to complete
#   error(train)=3.14e-02, acc(train)=9.91e-01, error(valid)=1.14e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 2.05s to complete
#   error(train)=1.64e-02, acc(train)=9.96e-01, error(valid)=1.17e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 2.17s to complete
#   error(train)=1.55e-02, acc(train)=9.95e-01, error(valid)=1.35e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# figcount: 2
# Run Time:
# 110.861319065
# {'Final Testing Accuracy': 0.9709999999999992,
#  'Final Testing Error': 0.135004313417807,
#  'Final Training Accuracy': 0.99542000000000253,
#  'Final Training Error': 0.015544239697404282}

# %% [markdown]
# Gladly the experiment is in consice with our original intentions. Here we don't see a slow learning rate at the beginning but rather an immediate increase of the accuracy and decrease of the error.
#
# In other words we don't see a flat line in the plot. The pretraining has yield a neural network which is more appropriate for our final classification
#
# Let’s try and repeat the same experiment using the Non-Linear Stacked Autoencoder for Pretraining

# %%
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeNonLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=9.24e+01, acc(train)=5.40e-04, params_penalty=0.00e+00
# Epoch 5: 6.17s to complete
#   error(train)=4.12e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 10: 7.24s to complete
#   error(train)=2.22e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 15: 6.60s to complete
#   error(train)=1.32e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 20: 6.24s to complete
#   error(train)=1.11e+00, acc(train)=1.51e-02, params_penalty=0.00e+00
# Epoch 25: 5.06s to complete
#   error(train)=9.99e-01, acc(train)=1.52e-02, params_penalty=0.00e+00
# Epoch 30: 5.08s to complete
#   error(train)=9.46e-01, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.66e+00, acc(train)=7.42e-03, params_penalty=0.00e+00
# Epoch 5: 1.27s to complete
#   error(train)=1.26e-01, acc(train)=4.34e-01, params_penalty=0.00e+00
# Epoch 10: 1.27s to complete
#   error(train)=5.43e-02, acc(train)=5.75e-01, params_penalty=0.00e+00
# Epoch 15: 1.20s to complete
#   error(train)=4.28e-02, acc(train)=6.11e-01, params_penalty=0.00e+00
# Epoch 20: 1.19s to complete
#   error(train)=3.71e-02, acc(train)=6.51e-01, params_penalty=0.00e+00
# Epoch 25: 3.32s to complete
#   error(train)=3.39e-02, acc(train)=6.92e-01, params_penalty=0.00e+00
# Epoch 30: 1.44s to complete
#   error(train)=3.19e-02, acc(train)=6.79e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.74e+00, acc(train)=9.32e-03, params_penalty=0.00e+00
# Epoch 5: 2.54s to complete
#   error(train)=4.42e-02, acc(train)=6.39e-01, params_penalty=0.00e+00
# Epoch 10: 1.95s to complete
#   error(train)=1.03e-02, acc(train)=8.25e-01, params_penalty=0.00e+00
# Epoch 15: 1.45s to complete
#   error(train)=8.49e-03, acc(train)=8.44e-01, params_penalty=0.00e+00
# Epoch 20: 1.45s to complete
#   error(train)=7.34e-03, acc(train)=8.60e-01, params_penalty=0.00e+00
# Epoch 25: 1.49s to complete
#   error(train)=6.69e-03, acc(train)=8.69e-01, params_penalty=0.00e+00
# Epoch 30: 1.47s to complete
#   error(train)=6.04e-03, acc(train)=8.79e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.65e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 5: 1.89s to complete
#   error(train)=4.08e-02, acc(train)=6.45e-01, params_penalty=0.00e+00
# Epoch 10: 1.62s to complete
#   error(train)=6.69e-03, acc(train)=8.56e-01, params_penalty=0.00e+00
# Epoch 15: 1.62s to complete
#   error(train)=5.65e-03, acc(train)=8.72e-01, params_penalty=0.00e+00
# Epoch 20: 1.62s to complete
#   error(train)=5.06e-03, acc(train)=8.78e-01, params_penalty=0.00e+00
# Epoch 25: 1.86s to complete
#   error(train)=4.49e-03, acc(train)=8.90e-01, params_penalty=0.00e+00
# Epoch 30: 1.64s to complete
#   error(train)=4.20e-03, acc(train)=8.95e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.58e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 5: 1.78s to complete
#   error(train)=3.96e-02, acc(train)=6.60e-01, params_penalty=0.00e+00
# Epoch 10: 2.54s to complete
#   error(train)=5.69e-03, acc(train)=8.67e-01, params_penalty=0.00e+00
# Epoch 15: 1.76s to complete
#   error(train)=5.05e-03, acc(train)=8.76e-01, params_penalty=0.00e+00
# Epoch 20: 1.69s to complete
#   error(train)=4.44e-03, acc(train)=8.87e-01, params_penalty=0.00e+00
# Epoch 25: 1.80s to complete
#   error(train)=4.15e-03, acc(train)=8.91e-01, params_penalty=0.00e+00
# Epoch 30: 1.81s to complete
#   error(train)=3.70e-03, acc(train)=9.01e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.04e+00, acc(train)=7.96e-03, params_penalty=0.00e+00
# Epoch 5: 1.49s to complete
#   error(train)=7.46e-01, acc(train)=4.97e-02, params_penalty=0.00e+00
# Epoch 10: 1.46s to complete
#   error(train)=7.34e-01, acc(train)=4.97e-02, params_penalty=0.00e+00
# Epoch 15: 1.53s to complete
#   error(train)=7.31e-01, acc(train)=5.02e-02, params_penalty=0.00e+00
# Epoch 20: 1.46s to complete
#   error(train)=7.29e-01, acc(train)=4.88e-02, params_penalty=0.00e+00
# Epoch 25: 2.05s to complete
#   error(train)=7.28e-01, acc(train)=4.76e-02, params_penalty=0.00e+00
# Epoch 30: 1.45s to complete
#   error(train)=7.28e-01, acc(train)=4.59e-02, params_penalty=0.00e+00

# %% [markdown]
# Constructing layer by layer our model by including Sigmoid Layers for non-linearities among our stacked layers from the stacked autoencoder process

# %%
reconstructedModel = MultipleLayerModel(model.layers[:-1])
len(reconstructedModel.layers)
# Out:
# 11

# %%
num_epochs = 40

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1.1
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(
    reconstructedModel,
    error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_6_layers_100_per_layer_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_6_layers_100_per_layer_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.50e+00, acc(train)=1.07e-01, error(valid)=2.48e+00, acc(valid)=1.17e-01, params_penalty=0.00e+00
# Epoch 5: 2.27s to complete
#   error(train)=1.78e-01, acc(train)=9.47e-01, error(valid)=1.79e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# Epoch 10: 2.03s to complete
#   error(train)=1.08e-01, acc(train)=9.68e-01, error(valid)=1.28e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 15: 2.18s to complete
#   error(train)=7.12e-02, acc(train)=9.80e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 20: 2.01s to complete
#   error(train)=4.88e-02, acc(train)=9.87e-01, error(valid)=9.76e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 25: 2.16s to complete
#   error(train)=3.75e-02, acc(train)=9.90e-01, error(valid)=9.78e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 30: 2.06s to complete
#   error(train)=2.63e-02, acc(train)=9.94e-01, error(valid)=9.95e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 35: 2.26s to complete
#   error(train)=1.74e-02, acc(train)=9.97e-01, error(valid)=9.77e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 3.89s to complete
#   error(train)=1.37e-02, acc(train)=9.97e-01, error(valid)=1.05e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# figcount: 16
# Run Time:
# 110.105275154
# {'Final Testing Accuracy': 0.97239999999999904,
#  'Final Testing Error': 0.10528195949162089,
#  'Final Training Accuracy': 0.99748000000000137,
#  'Final Training Error': 0.01367461917368043}

# %% [markdown]
# Gladly the experiment is in consice with our original intentions. Here we don't see a slow learning rate at the beginning but rather an immediate increase of the accuracy and decrease of the error.
#
# In other words we don't see a flat line in the plot. The pretraining has yield a neural network which is more appropriate for our final classification

# %% [markdown]
# ### Seven Layers

# %%
num_epochs = 100

learningRate = 1.1
learningRule = GradientDescentLearningRule(learning_rate=learningRate)

input_dim, output_dim, hidden_dim = 784, 10, 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weightsInit, biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weightsInit, biasesInit), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weightsInit, biasesInit)
])

stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_7_layers_100_per_layer_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_7_layers_100_per_layer_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.41e+00, acc(train)=9.86e-02, error(valid)=2.40e+00, acc(valid)=9.91e-02, params_penalty=0.00e+00
# Epoch 5: 2.43s to complete
#   error(train)=2.31e+00, acc(train)=9.98e-02, error(valid)=2.31e+00, acc(valid)=9.61e-02, params_penalty=0.00e+00
# Epoch 10: 3.62s to complete
#   error(train)=2.31e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 15: 2.45s to complete
#   error(train)=2.31e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 20: 3.28s to complete
#   error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 25: 2.49s to complete
#   error(train)=2.31e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 30: 3.35s to complete
#   error(train)=2.98e-01, acc(train)=9.23e-01, error(valid)=2.92e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Epoch 35: 2.81s to complete
#   error(train)=1.21e-01, acc(train)=9.67e-01, error(valid)=1.58e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 40: 3.07s to complete
#   error(train)=4.92e-02, acc(train)=9.87e-01, error(valid)=1.24e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 45: 2.41s to complete
#   error(train)=3.16e-02, acc(train)=9.92e-01, error(valid)=1.27e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 50: 3.74s to complete
#   error(train)=2.56e-02, acc(train)=9.93e-01, error(valid)=1.27e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 55: 2.33s to complete
#   error(train)=1.55e-02, acc(train)=9.96e-01, error(valid)=1.30e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 60: 2.32s to complete
#   error(train)=1.28e-02, acc(train)=9.97e-01, error(valid)=1.38e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 65: 2.48s to complete
#   error(train)=2.05e-02, acc(train)=9.94e-01, error(valid)=1.51e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 70: 3.22s to complete
#   error(train)=9.45e-03, acc(train)=9.98e-01, error(valid)=1.46e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 75: 2.57s to complete
#   error(train)=6.61e-03, acc(train)=9.99e-01, error(valid)=1.56e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 80: 2.60s to complete
#   error(train)=5.36e-03, acc(train)=9.99e-01, error(valid)=1.55e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 85: 2.94s to complete
#   error(train)=8.57e-03, acc(train)=9.98e-01, error(valid)=1.62e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 90: 2.34s to complete
#   error(train)=6.84e-03, acc(train)=9.98e-01, error(valid)=1.64e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 95: 2.70s to complete
#   error(train)=8.99e-03, acc(train)=9.97e-01, error(valid)=1.46e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 100: 2.93s to complete
#   error(train)=2.22e-03, acc(train)=9.99e-01, error(valid)=1.58e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# figcount: 3
# Run Time:
# 319.806434155
# {'Final Testing Accuracy': 0.97459999999999836,
#  'Final Testing Error': 0.15829059585158961,
#  'Final Training Accuracy': 0.99946000000000024,
#  'Final Training Error': 0.002222706411481464}

# %% [markdown]
# With 7 layers the effect is more severe. The learning is really slow in the beginning and we have to go to more than 50 epochs so that the neural network really starts learning
#
# Now let's construct a model of seven layers with 100 dimensionality in each hidden layer via a Linear Stacked AutoEncoder and see if we are going to alieviate this unwanted effect

# %%
#hiddenDims = np.repeat(100, 5)
hiddenDims = np.concatenate( (np.repeat(100, 6), np.array([10])) )
hiddenDims
# Out:
# array([100, 100, 100, 100, 100, 100,  10])

# %%
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=6.18e+01, acc(train)=2.48e-03, params_penalty=0.00e+00
# Epoch 5: 3.52s to complete
#   error(train)=2.32e+00, acc(train)=1.46e-02, params_penalty=0.00e+00
# Epoch 10: 3.56s to complete
#   error(train)=2.33e+00, acc(train)=1.45e-02, params_penalty=0.00e+00
# Epoch 15: 3.84s to complete
#   error(train)=2.29e+00, acc(train)=1.46e-02, params_penalty=0.00e+00
# Epoch 20: 3.72s to complete
#   error(train)=2.33e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 25: 5.15s to complete
#   error(train)=2.34e+00, acc(train)=1.43e-02, params_penalty=0.00e+00
# Epoch 30: 3.58s to complete
#   error(train)=2.30e+00, acc(train)=1.46e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=6.52e+00, acc(train)=5.98e-03, params_penalty=0.00e+00
# Epoch 5: 0.81s to complete
#   error(train)=2.18e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.39s to complete
#   error(train)=3.57e-04, acc(train)=9.96e-01, params_penalty=0.00e+00
# Epoch 15: 0.82s to complete
#   error(train)=2.17e-04, acc(train)=9.97e-01, params_penalty=0.00e+00
# Epoch 20: 1.53s to complete
#   error(train)=2.27e-04, acc(train)=9.96e-01, params_penalty=0.00e+00
# Epoch 25: 0.79s to complete
#   error(train)=3.90e-04, acc(train)=9.97e-01, params_penalty=0.00e+00
# Epoch 30: 0.81s to complete
#   error(train)=3.61e-04, acc(train)=9.95e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.91e+00, acc(train)=7.82e-03, params_penalty=0.00e+00
# Epoch 5: 0.86s to complete
#   error(train)=2.12e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 0.82s to complete
#   error(train)=5.24e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 15: 0.86s to complete
#   error(train)=2.89e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 20: 0.98s to complete
#   error(train)=2.81e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 25: 1.01s to complete
#   error(train)=5.33e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 30: 1.01s to complete
#   error(train)=3.26e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.66e+00, acc(train)=1.09e-02, params_penalty=0.00e+00
# Epoch 5: 1.03s to complete
#   error(train)=2.47e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 0.90s to complete
#   error(train)=2.78e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 15: 1.35s to complete
#   error(train)=4.32e-04, acc(train)=9.84e-01, params_penalty=0.00e+00
# Epoch 20: 0.90s to complete
#   error(train)=3.64e-04, acc(train)=9.86e-01, params_penalty=0.00e+00
# Epoch 25: 1.42s to complete
#   error(train)=3.21e-04, acc(train)=9.86e-01, params_penalty=0.00e+00
# Epoch 30: 0.91s to complete
#   error(train)=4.03e-04, acc(train)=9.84e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=5.95e+00, acc(train)=8.20e-03, params_penalty=0.00e+00
# Epoch 5: 1.32s to complete
#   error(train)=1.99e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 0.97s to complete
#   error(train)=4.68e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 15: 1.48s to complete
#   error(train)=3.55e-04, acc(train)=9.85e-01, params_penalty=0.00e+00
# Epoch 20: 0.94s to complete
#   error(train)=3.87e-04, acc(train)=9.85e-01, params_penalty=0.00e+00
# Epoch 25: 1.04s to complete
#   error(train)=2.98e-04, acc(train)=9.88e-01, params_penalty=0.00e+00
# Epoch 30: 0.99s to complete
#   error(train)=3.15e-04, acc(train)=9.86e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=6.48e+00, acc(train)=9.10e-03, params_penalty=0.00e+00
# Epoch 5: 1.88s to complete
#   error(train)=1.86e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.13s to complete
#   error(train)=6.26e-04, acc(train)=9.81e-01, params_penalty=0.00e+00
# Epoch 15: 0.93s to complete
#   error(train)=5.20e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 20: 0.99s to complete
#   error(train)=3.05e-04, acc(train)=9.87e-01, params_penalty=0.00e+00
# Epoch 25: 0.99s to complete
#   error(train)=5.04e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 30: 1.87s to complete
#   error(train)=5.19e-04, acc(train)=9.83e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=4.40e+00, acc(train)=7.70e-03, params_penalty=0.00e+00
# Epoch 5: 1.37s to complete
#   error(train)=2.32e+00, acc(train)=1.19e-01, params_penalty=0.00e+00
# Epoch 10: 0.68s to complete
#   error(train)=2.32e+00, acc(train)=1.22e-01, params_penalty=0.00e+00
# Epoch 15: 0.74s to complete
#   error(train)=2.32e+00, acc(train)=1.22e-01, params_penalty=0.00e+00
# Epoch 20: 0.75s to complete
#   error(train)=2.32e+00, acc(train)=1.25e-01, params_penalty=0.00e+00
# Epoch 25: 0.81s to complete
#   error(train)=2.32e+00, acc(train)=1.22e-01, params_penalty=0.00e+00
# Epoch 30: 0.75s to complete
#   error(train)=2.32e+00, acc(train)=1.25e-01, params_penalty=0.00e+00

# %% [markdown]
# Constructing layer by layer our model by including Sigmoid Layers for non-linearities among our stacked layers from the stacked autoencoder process

# %%
for l in model.layers:
    print l.params[0].shape
# Out:
# (100, 784)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (100, 100)
# (10, 100)

# %%
reconstructedModel = MultipleLayerModel([
    model.layers[0],
    SigmoidLayer(),
    model.layers[1], 
    SigmoidLayer(),
    model.layers[2], 
    SigmoidLayer(),
    model.layers[3], 
    SigmoidLayer(),
    model.layers[4],
    SigmoidLayer(),
    model.layers[5],
    SigmoidLayer(),
    model.layers[6]
])

# %%
num_epochs = 100

learningRate = 1.1
learningRule = GradientDescentLearningRule(learning_rate=learningRate)

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

stats, keys, runTime = trainModel(
    reconstructedModel,
    error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_7_layers_100_per_layer_linear_pretrain_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_7_layers_100_per_layer_linear_pretrain_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02, params_penalty=0.00e+00
# Epoch 5: 2.66s to complete
#   error(train)=2.30e+00, acc(train)=1.03e-01, error(valid)=2.30e+00, acc(valid)=1.09e-01, params_penalty=0.00e+00
# Epoch 10: 2.56s to complete
#   error(train)=2.30e+00, acc(train)=9.90e-02, error(valid)=2.30e+00, acc(valid)=9.67e-02, params_penalty=0.00e+00
# Epoch 15: 2.97s to complete
#   error(train)=2.30e+00, acc(train)=9.90e-02, error(valid)=2.31e+00, acc(valid)=9.67e-02, params_penalty=0.00e+00
# Epoch 20: 2.63s to complete
#   error(train)=2.31e+00, acc(train)=1.04e-01, error(valid)=2.31e+00, acc(valid)=1.09e-01, params_penalty=0.00e+00
# Epoch 25: 2.52s to complete
#   error(train)=2.31e+00, acc(train)=9.86e-02, error(valid)=2.31e+00, acc(valid)=9.91e-02, params_penalty=0.00e+00
# Epoch 30: 4.28s to complete
#   error(train)=2.31e+00, acc(train)=9.72e-02, error(valid)=2.31e+00, acc(valid)=9.83e-02, params_penalty=0.00e+00
# Epoch 35: 4.16s to complete
#   error(train)=2.31e+00, acc(train)=9.86e-02, error(valid)=2.31e+00, acc(valid)=9.91e-02, params_penalty=0.00e+00
# Epoch 40: 2.45s to complete
#   error(train)=2.30e+00, acc(train)=1.04e-01, error(valid)=2.30e+00, acc(valid)=1.09e-01, params_penalty=0.00e+00
# Epoch 45: 4.16s to complete
#   error(train)=2.31e+00, acc(train)=9.90e-02, error(valid)=2.31e+00, acc(valid)=9.67e-02, params_penalty=0.00e+00
# Epoch 50: 2.48s to complete
#   error(train)=2.31e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 55: 2.36s to complete
#   error(train)=2.31e+00, acc(train)=9.94e-02, error(valid)=2.31e+00, acc(valid)=9.90e-02, params_penalty=0.00e+00
# Epoch 60: 2.51s to complete
#   error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 65: 4.06s to complete
#   error(train)=2.31e+00, acc(train)=9.86e-02, error(valid)=2.31e+00, acc(valid)=9.91e-02, params_penalty=0.00e+00
# Epoch 70: 2.41s to complete
#   error(train)=2.31e+00, acc(train)=9.98e-02, error(valid)=2.31e+00, acc(valid)=9.61e-02, params_penalty=0.00e+00
# Epoch 75: 3.36s to complete
#   error(train)=2.31e+00, acc(train)=9.98e-02, error(valid)=2.31e+00, acc(valid)=9.61e-02, params_penalty=0.00e+00
# Epoch 80: 2.58s to complete
#   error(train)=2.30e+00, acc(train)=1.03e-01, error(valid)=2.30e+00, acc(valid)=1.09e-01, params_penalty=0.00e+00
# Epoch 85: 3.94s to complete
#   error(train)=2.30e+00, acc(train)=9.68e-02, error(valid)=2.30e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 90: 2.75s to complete
#   error(train)=2.30e+00, acc(train)=9.94e-02, error(valid)=2.30e+00, acc(valid)=9.90e-02, params_penalty=0.00e+00
# Epoch 95: 4.14s to complete
#   error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 100: 2.80s to complete
#   error(train)=2.30e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# figcount: 4
# Run Time:
# 345.946224928
# {'Final Testing Accuracy': 0.10639999999999988,
#  'Final Testing Error': 2.3065173136848172,
#  'Final Training Accuracy': 0.11355999999999987,
#  'Final Training Error': 2.3046307375203297}

# %% [markdown]
# Here having 7 layer the effect is so severe that our pretraining with the linear stacked autoencoder is not enough to bring the pretraining to an optimal state.
#
# However comparing this experiment and the previous one we see that we did better. Previous at 50 epochs we had done no real progress on learning. In the current experiment after 40 epochs the system has already gone through that slow-learning phase and it is learning in a fast rate.

# %% [markdown]
# Let's try with the non linear stacked autoencoder to see if we can yield better results

# %%
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeNonLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=9.20e+01, acc(train)=3.54e-03, params_penalty=0.00e+00
# Epoch 5: 6.79s to complete
#   error(train)=3.94e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 10: 5.13s to complete
#   error(train)=2.17e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 15: 5.10s to complete
#   error(train)=1.32e+00, acc(train)=1.50e-02, params_penalty=0.00e+00
# Epoch 20: 7.10s to complete
#   error(train)=1.10e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 25: 7.62s to complete
#   error(train)=1.00e+00, acc(train)=1.43e-02, params_penalty=0.00e+00
# Epoch 30: 7.22s to complete
#   error(train)=9.45e-01, acc(train)=1.39e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.85e+00, acc(train)=1.89e-02, params_penalty=0.00e+00
# Epoch 5: 1.31s to complete
#   error(train)=1.28e-01, acc(train)=4.44e-01, params_penalty=0.00e+00
# Epoch 10: 1.26s to complete
#   error(train)=5.90e-02, acc(train)=5.50e-01, params_penalty=0.00e+00
# Epoch 15: 1.21s to complete
#   error(train)=4.25e-02, acc(train)=6.26e-01, params_penalty=0.00e+00
# Epoch 20: 2.51s to complete
#   error(train)=3.62e-02, acc(train)=6.62e-01, params_penalty=0.00e+00
# Epoch 25: 1.31s to complete
#   error(train)=3.35e-02, acc(train)=6.82e-01, params_penalty=0.00e+00
# Epoch 30: 1.25s to complete
#   error(train)=3.17e-02, acc(train)=6.99e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.95e+00, acc(train)=1.00e-02, params_penalty=0.00e+00
# Epoch 5: 3.35s to complete
#   error(train)=4.94e-02, acc(train)=6.14e-01, params_penalty=0.00e+00
# Epoch 10: 1.79s to complete
#   error(train)=1.03e-02, acc(train)=8.24e-01, params_penalty=0.00e+00
# Epoch 15: 1.46s to complete
#   error(train)=8.65e-03, acc(train)=8.41e-01, params_penalty=0.00e+00
# Epoch 20: 1.43s to complete
#   error(train)=7.41e-03, acc(train)=8.57e-01, params_penalty=0.00e+00
# Epoch 25: 1.63s to complete
#   error(train)=6.81e-03, acc(train)=8.65e-01, params_penalty=0.00e+00
# Epoch 30: 1.89s to complete
#   error(train)=6.28e-03, acc(train)=8.75e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.65e+00, acc(train)=1.13e-02, params_penalty=0.00e+00
# Epoch 5: 1.76s to complete
#   error(train)=4.91e-02, acc(train)=6.18e-01, params_penalty=0.00e+00
# Epoch 10: 1.90s to complete
#   error(train)=6.81e-03, acc(train)=8.51e-01, params_penalty=0.00e+00
# Epoch 15: 1.58s to complete
#   error(train)=5.86e-03, acc(train)=8.64e-01, params_penalty=0.00e+00
# Epoch 20: 1.56s to complete
#   error(train)=5.14e-03, acc(train)=8.78e-01, params_penalty=0.00e+00
# Epoch 25: 1.59s to complete
#   error(train)=4.59e-03, acc(train)=8.87e-01, params_penalty=0.00e+00
# Epoch 30: 1.56s to complete
#   error(train)=4.20e-03, acc(train)=8.94e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.54e+00, acc(train)=7.06e-03, params_penalty=0.00e+00
# Epoch 5: 2.42s to complete
#   error(train)=4.10e-02, acc(train)=6.43e-01, params_penalty=0.00e+00
# Epoch 10: 2.14s to complete
#   error(train)=5.89e-03, acc(train)=8.68e-01, params_penalty=0.00e+00
# Epoch 15: 1.90s to complete
#   error(train)=5.21e-03, acc(train)=8.78e-01, params_penalty=0.00e+00
# Epoch 20: 1.95s to complete
#   error(train)=4.46e-03, acc(train)=8.89e-01, params_penalty=0.00e+00
# Epoch 25: 1.91s to complete
#   error(train)=4.15e-03, acc(train)=8.95e-01, params_penalty=0.00e+00
# Epoch 30: 1.82s to complete
#   error(train)=3.73e-03, acc(train)=9.03e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.65e+00, acc(train)=7.26e-03, params_penalty=0.00e+00
# Epoch 5: 2.02s to complete
#   error(train)=4.22e-02, acc(train)=6.43e-01, params_penalty=0.00e+00
# Epoch 10: 2.08s to complete
#   error(train)=5.50e-03, acc(train)=8.74e-01, params_penalty=0.00e+00
# Epoch 15: 3.74s to complete
#   error(train)=4.91e-03, acc(train)=8.83e-01, params_penalty=0.00e+00
# Epoch 20: 2.25s to complete
#   error(train)=4.27e-03, acc(train)=8.91e-01, params_penalty=0.00e+00
# Epoch 25: 2.26s to complete
#   error(train)=3.94e-03, acc(train)=8.98e-01, params_penalty=0.00e+00
# Epoch 30: 1.98s to complete
#   error(train)=3.57e-03, acc(train)=9.05e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.03e+00, acc(train)=1.19e-02, params_penalty=0.00e+00
# Epoch 5: 1.61s to complete
#   error(train)=7.46e-01, acc(train)=4.44e-02, params_penalty=0.00e+00
# Epoch 10: 1.63s to complete
#   error(train)=7.32e-01, acc(train)=4.46e-02, params_penalty=0.00e+00
# Epoch 15: 1.64s to complete
#   error(train)=7.29e-01, acc(train)=4.60e-02, params_penalty=0.00e+00
# Epoch 20: 1.64s to complete
#   error(train)=7.27e-01, acc(train)=4.58e-02, params_penalty=0.00e+00
# Epoch 25: 2.46s to complete
#   error(train)=7.26e-01, acc(train)=4.73e-02, params_penalty=0.00e+00
# Epoch 30: 1.94s to complete
#   error(train)=7.26e-01, acc(train)=4.88e-02, params_penalty=0.00e+00

# %% [markdown]
# Let's drop the last sigmoid layer that we don't need it (we use Softmax instead)

# %%
# for l in model.layers:
#     print l.params[0].shape
reconstructedModel = MultipleLayerModel(model.layers[:-1])
len(reconstructedModel.layers)
# Out:
# 13

# %%
num_epochs = 100

learningRate = 1.1
learningRule = GradientDescentLearningRule(learning_rate=learningRate)

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

stats, keys, runTime = trainModel(
    reconstructedModel,
    error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_7_layers_100_per_layer_nonlinear_pretrain_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_7_layers_100_per_layer_nonlinear_pretrain_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.57e+00, acc(train)=1.26e-01, error(valid)=2.60e+00, acc(valid)=1.25e-01, params_penalty=0.00e+00
# Epoch 5: 2.38s to complete
#   error(train)=6.45e-02, acc(train)=9.80e-01, error(valid)=9.79e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 10: 3.69s to complete
#   error(train)=3.06e-02, acc(train)=9.90e-01, error(valid)=9.92e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 15: 2.36s to complete
#   error(train)=1.43e-02, acc(train)=9.96e-01, error(valid)=9.82e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 20: 2.50s to complete
#   error(train)=1.17e-02, acc(train)=9.96e-01, error(valid)=1.13e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 25: 2.96s to complete
#   error(train)=4.88e-03, acc(train)=9.99e-01, error(valid)=1.08e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 30: 2.61s to complete
#   error(train)=6.92e-03, acc(train)=9.98e-01, error(valid)=1.10e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 35: 2.37s to complete
#   error(train)=3.13e-03, acc(train)=9.99e-01, error(valid)=1.20e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 40: 2.91s to complete
#   error(train)=1.86e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 45: 2.49s to complete
#   error(train)=1.03e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 50: 3.22s to complete
#   error(train)=7.82e-05, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 55: 2.50s to complete
#   error(train)=6.27e-05, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 60: 2.71s to complete
#   error(train)=5.27e-05, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 65: 4.56s to complete
#   error(train)=4.53e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 70: 2.40s to complete
#   error(train)=3.98e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 75: 4.69s to complete
#   error(train)=3.55e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 80: 2.75s to complete
#   error(train)=3.20e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 85: 3.83s to complete
#   error(train)=2.91e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 90: 2.53s to complete
#   error(train)=2.67e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 95: 4.44s to complete
#   error(train)=2.47e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 100: 2.46s to complete
#   error(train)=2.29e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# figcount: 5
# Run Time:
# 337.20222497
# {'Final Testing Accuracy': 0.97899999999999876,
#  'Final Testing Error': 0.13459701113216441,
#  'Final Training Accuracy': 1.0,
#  'Final Training Error': 2.2924539333227827e-05}

# %% [markdown]
# We see that the non linear stacked autoencoder yields better results. Even with 7 layers there is no phase where we have slow-training. The training reachs optimal error and accuracy at around 30 epochs. We have seen that indeed this pretraining brings the initial state of the neural network at a place that is suitable for our classification task.

# %% [markdown]
# ## Experiment B: yielding smaller error and higher accuracy by pretraining instead of randomly initializing weights

# %% [markdown]
# Our goal is to initialize the randomly generated weights with different seeds and see what kind of results we are getting. Then use Pretraining with Stacked Autoencoder and see the final performance

# %%
getWeightsInit = lambda theSeed: GlorotUniformInit(rng = np.random.RandomState(theSeed))

# %% [markdown]
# ## Two Layer Model with random initialization of weights with Glorot Uniform Initialization

# %% [markdown]
# Let's see how our two layer model behaves within 100 epochs

# %%
curSeed = 0

# %%
num_epochs = 100

input_dim, output_dim, hidden_dim = 784, 10, 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, getWeightsInit(curSeed), biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, getWeightsInit(curSeed), biasesInit)
])

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_2_layers_100_per_layer_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_2_layers_100_per_layer_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.39e+00, acc(train)=1.14e-01, error(valid)=2.39e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 5: 1.02s to complete
#   error(train)=2.43e-01, acc(train)=9.31e-01, error(valid)=2.30e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Epoch 10: 0.88s to complete
#   error(train)=1.77e-01, acc(train)=9.49e-01, error(valid)=1.75e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.85s to complete
#   error(train)=1.38e-01, acc(train)=9.60e-01, error(valid)=1.46e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 1.38s to complete
#   error(train)=1.11e-01, acc(train)=9.69e-01, error(valid)=1.25e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.82s to complete
#   error(train)=9.33e-02, acc(train)=9.75e-01, error(valid)=1.12e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 1.20s to complete
#   error(train)=8.04e-02, acc(train)=9.78e-01, error(valid)=1.05e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 35: 0.83s to complete
#   error(train)=6.96e-02, acc(train)=9.82e-01, error(valid)=9.79e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 1.66s to complete
#   error(train)=6.13e-02, acc(train)=9.84e-01, error(valid)=9.22e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 0.84s to complete
#   error(train)=5.44e-02, acc(train)=9.86e-01, error(valid)=8.85e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.94s to complete
#   error(train)=4.80e-02, acc(train)=9.88e-01, error(valid)=8.60e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 0.85s to complete
#   error(train)=4.36e-02, acc(train)=9.90e-01, error(valid)=8.37e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.67s to complete
#   error(train)=3.89e-02, acc(train)=9.92e-01, error(valid)=8.09e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 0.86s to complete
#   error(train)=3.52e-02, acc(train)=9.93e-01, error(valid)=8.04e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.77s to complete
#   error(train)=3.20e-02, acc(train)=9.93e-01, error(valid)=7.84e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 0.90s to complete
#   error(train)=2.90e-02, acc(train)=9.95e-01, error(valid)=7.77e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 80: 1.12s to complete
#   error(train)=2.66e-02, acc(train)=9.96e-01, error(valid)=7.67e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 0.90s to complete
#   error(train)=2.43e-02, acc(train)=9.96e-01, error(valid)=7.62e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 0.88s to complete
#   error(train)=2.24e-02, acc(train)=9.97e-01, error(valid)=7.65e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 0.91s to complete
#   error(train)=2.03e-02, acc(train)=9.98e-01, error(valid)=7.59e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 0.83s to complete
#   error(train)=1.90e-02, acc(train)=9.98e-01, error(valid)=7.57e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# figcount: 6
# Run Time:
# 126.894783974
# {'Final Testing Accuracy': 0.97789999999999777,
#  'Final Testing Error': 0.075733012679254696,
#  'Final Training Accuracy': 0.99764000000000153,
#  'Final Training Error': 0.018958982953952288}

# %% [markdown]
# After 100 epochs we have reached at ~97.78% of accuracy for our classification task
#
# Let's repeat that for various seeds and see what we are getting

# %%
def fitAndScoreTwoLayer(theSeed):
    num_epochs = 100

    input_dim, output_dim, hidden_dim = 784, 10, 100

    # Multiclass classification therefore use cross-entropy + softmax error
    error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, getWeightsInit(theSeed), biasesInit),
        SigmoidLayer(),
        AffineLayer(hidden_dim, output_dim, getWeightsInit(theSeed), biasesInit)
    ])

    learning_rate = 1e-1
    learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

    stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

    return getFinalValues(stats)

# %%
seeds = range(10)

finalValuesCollection = []

for curSeed in seeds:
    finalValuesCollection.append(
        fitAndScoreTwoLayer(curSeed)
    )
# Out:
# Epoch 0:
#   error(train)=2.39e+00, acc(train)=1.14e-01, error(valid)=2.39e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 5: 1.69s to complete
#   error(train)=2.41e-01, acc(train)=9.31e-01, error(valid)=2.29e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Epoch 10: 0.84s to complete
#   error(train)=1.75e-01, acc(train)=9.49e-01, error(valid)=1.74e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 1.68s to complete
#   error(train)=1.38e-01, acc(train)=9.61e-01, error(valid)=1.45e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 20: 0.84s to complete
#   error(train)=1.11e-01, acc(train)=9.68e-01, error(valid)=1.25e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 1.68s to complete
#   error(train)=9.43e-02, acc(train)=9.74e-01, error(valid)=1.15e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 1.18s to complete
#   error(train)=7.96e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 1.92s to complete
#   error(train)=7.08e-02, acc(train)=9.82e-01, error(valid)=9.73e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 0.90s to complete
#   error(train)=6.26e-02, acc(train)=9.84e-01, error(valid)=9.46e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 1.50s to complete
#   error(train)=5.41e-02, acc(train)=9.87e-01, error(valid)=8.78e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 0.91s to complete
#   error(train)=4.90e-02, acc(train)=9.88e-01, error(valid)=8.48e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 1.40s to complete
#   error(train)=4.36e-02, acc(train)=9.90e-01, error(valid)=8.27e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 0.91s to complete
#   error(train)=3.91e-02, acc(train)=9.92e-01, error(valid)=8.08e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.06s to complete
#   error(train)=3.59e-02, acc(train)=9.92e-01, error(valid)=8.02e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 0.98s to complete
#   error(train)=3.18e-02, acc(train)=9.94e-01, error(valid)=7.79e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 0.83s to complete
#   error(train)=2.91e-02, acc(train)=9.95e-01, error(valid)=7.69e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 0.89s to complete
#   error(train)=2.65e-02, acc(train)=9.96e-01, error(valid)=7.69e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 0.84s to complete
#   error(train)=2.43e-02, acc(train)=9.96e-01, error(valid)=7.57e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.23s to complete
#   error(train)=2.24e-02, acc(train)=9.97e-01, error(valid)=7.55e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 95: 0.85s to complete
#   error(train)=2.04e-02, acc(train)=9.97e-01, error(valid)=7.56e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 0.90s to complete
#   error(train)=1.89e-02, acc(train)=9.98e-01, error(valid)=7.50e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.47e+00, acc(train)=9.94e-02, error(valid)=2.47e+00, acc(valid)=9.90e-02, params_penalty=0.00e+00
# Epoch 5: 0.83s to complete
#   error(train)=2.38e-01, acc(train)=9.32e-01, error(valid)=2.25e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# Epoch 10: 1.20s to complete
#   error(train)=1.72e-01, acc(train)=9.50e-01, error(valid)=1.71e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Epoch 15: 0.83s to complete
#   error(train)=1.35e-01, acc(train)=9.62e-01, error(valid)=1.41e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 1.34s to complete
#   error(train)=1.11e-01, acc(train)=9.69e-01, error(valid)=1.24e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 25: 0.85s to complete
#   error(train)=9.28e-02, acc(train)=9.74e-01, error(valid)=1.11e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 1.52s to complete
#   error(train)=8.09e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 0.83s to complete
#   error(train)=7.05e-02, acc(train)=9.81e-01, error(valid)=9.82e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 1.85s to complete
#   error(train)=6.09e-02, acc(train)=9.84e-01, error(valid)=9.21e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 0.85s to complete
#   error(train)=5.43e-02, acc(train)=9.86e-01, error(valid)=8.81e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.01s to complete
#   error(train)=4.90e-02, acc(train)=9.88e-01, error(valid)=8.66e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 55: 0.91s to complete
#   error(train)=4.32e-02, acc(train)=9.90e-01, error(valid)=8.31e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 0.85s to complete
#   error(train)=3.93e-02, acc(train)=9.91e-01, error(valid)=8.28e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.09s to complete
#   error(train)=3.52e-02, acc(train)=9.93e-01, error(valid)=7.98e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 0.93s to complete
#   error(train)=3.20e-02, acc(train)=9.94e-01, error(valid)=7.78e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.74s to complete
#   error(train)=2.94e-02, acc(train)=9.94e-01, error(valid)=7.86e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 0.86s to complete
#   error(train)=2.69e-02, acc(train)=9.95e-01, error(valid)=7.68e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 85: 1.77s to complete
#   error(train)=2.45e-02, acc(train)=9.96e-01, error(valid)=7.71e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 90: 0.89s to complete
#   error(train)=2.25e-02, acc(train)=9.97e-01, error(valid)=7.67e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.71s to complete
#   error(train)=2.05e-02, acc(train)=9.97e-01, error(valid)=7.54e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 0.90s to complete
#   error(train)=1.89e-02, acc(train)=9.98e-01, error(valid)=7.49e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.72e+00, acc(train)=8.70e-02, error(valid)=2.72e+00, acc(valid)=9.11e-02, params_penalty=0.00e+00
# Epoch 5: 0.92s to complete
#   error(train)=2.46e-01, acc(train)=9.30e-01, error(valid)=2.34e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Epoch 10: 0.91s to complete
#   error(train)=1.76e-01, acc(train)=9.49e-01, error(valid)=1.75e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Epoch 15: 0.84s to complete
#   error(train)=1.37e-01, acc(train)=9.61e-01, error(valid)=1.44e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Epoch 20: 0.90s to complete
#   error(train)=1.11e-01, acc(train)=9.69e-01, error(valid)=1.24e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.84s to complete
#   error(train)=9.41e-02, acc(train)=9.74e-01, error(valid)=1.12e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 30: 0.93s to complete
#   error(train)=8.08e-02, acc(train)=9.78e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 1.10s to complete
#   error(train)=7.00e-02, acc(train)=9.81e-01, error(valid)=9.67e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 1.15s to complete
#   error(train)=6.10e-02, acc(train)=9.84e-01, error(valid)=9.12e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 0.96s to complete
#   error(train)=5.42e-02, acc(train)=9.87e-01, error(valid)=8.75e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.66s to complete
#   error(train)=4.86e-02, acc(train)=9.88e-01, error(valid)=8.50e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 0.87s to complete
#   error(train)=4.39e-02, acc(train)=9.90e-01, error(valid)=8.27e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.73s to complete
#   error(train)=3.98e-02, acc(train)=9.91e-01, error(valid)=8.05e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 0.88s to complete
#   error(train)=3.58e-02, acc(train)=9.93e-01, error(valid)=7.94e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.93s to complete
#   error(train)=3.25e-02, acc(train)=9.94e-01, error(valid)=7.79e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 0.96s to complete
#   error(train)=2.97e-02, acc(train)=9.94e-01, error(valid)=7.60e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.44s to complete
#   error(train)=2.70e-02, acc(train)=9.95e-01, error(valid)=7.52e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 0.90s to complete
#   error(train)=2.47e-02, acc(train)=9.96e-01, error(valid)=7.44e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 0.92s to complete
#   error(train)=2.28e-02, acc(train)=9.97e-01, error(valid)=7.48e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 95: 0.90s to complete
#   error(train)=2.12e-02, acc(train)=9.97e-01, error(valid)=7.38e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 0.94s to complete
#   error(train)=1.94e-02, acc(train)=9.97e-01, error(valid)=7.41e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.50e+00, acc(train)=9.69e-02, error(valid)=2.50e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 5: 0.92s to complete
#   error(train)=2.46e-01, acc(train)=9.29e-01, error(valid)=2.35e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Epoch 10: 0.82s to complete
#   error(train)=1.77e-01, acc(train)=9.49e-01, error(valid)=1.76e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Epoch 15: 0.90s to complete
#   error(train)=1.38e-01, acc(train)=9.61e-01, error(valid)=1.45e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# Epoch 20: 0.85s to complete
#   error(train)=1.11e-01, acc(train)=9.69e-01, error(valid)=1.25e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 25: 1.20s to complete
#   error(train)=9.32e-02, acc(train)=9.75e-01, error(valid)=1.13e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 0.85s to complete
#   error(train)=7.97e-02, acc(train)=9.78e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 1.21s to complete
#   error(train)=6.96e-02, acc(train)=9.81e-01, error(valid)=9.70e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 0.85s to complete
#   error(train)=6.16e-02, acc(train)=9.84e-01, error(valid)=9.19e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 1.49s to complete
#   error(train)=5.43e-02, acc(train)=9.87e-01, error(valid)=8.78e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 0.84s to complete
#   error(train)=4.83e-02, acc(train)=9.88e-01, error(valid)=8.45e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 1.74s to complete
#   error(train)=4.34e-02, acc(train)=9.90e-01, error(valid)=8.20e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 0.87s to complete
#   error(train)=3.88e-02, acc(train)=9.91e-01, error(valid)=7.99e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.92s to complete
#   error(train)=3.55e-02, acc(train)=9.92e-01, error(valid)=7.78e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 70: 0.89s to complete
#   error(train)=3.23e-02, acc(train)=9.93e-01, error(valid)=7.76e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.74s to complete
#   error(train)=2.93e-02, acc(train)=9.95e-01, error(valid)=7.63e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 0.89s to complete
#   error(train)=2.65e-02, acc(train)=9.96e-01, error(valid)=7.48e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 1.79s to complete
#   error(train)=2.47e-02, acc(train)=9.96e-01, error(valid)=7.48e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 0.92s to complete
#   error(train)=2.24e-02, acc(train)=9.96e-01, error(valid)=7.36e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 95: 0.85s to complete
#   error(train)=2.06e-02, acc(train)=9.97e-01, error(valid)=7.33e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 100: 0.92s to complete
#   error(train)=1.89e-02, acc(train)=9.98e-01, error(valid)=7.32e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.53e+00, acc(train)=9.64e-02, error(valid)=2.54e+00, acc(valid)=9.82e-02, params_penalty=0.00e+00
# Epoch 5: 0.84s to complete
#   error(train)=2.42e-01, acc(train)=9.31e-01, error(valid)=2.29e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# Epoch 10: 0.89s to complete
#   error(train)=1.74e-01, acc(train)=9.50e-01, error(valid)=1.74e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.84s to complete
#   error(train)=1.35e-01, acc(train)=9.62e-01, error(valid)=1.42e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 20: 0.95s to complete
#   error(train)=1.10e-01, acc(train)=9.70e-01, error(valid)=1.24e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.84s to complete
#   error(train)=9.14e-02, acc(train)=9.75e-01, error(valid)=1.11e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 0.90s to complete
#   error(train)=7.84e-02, acc(train)=9.79e-01, error(valid)=1.02e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 1.00s to complete
#   error(train)=6.84e-02, acc(train)=9.82e-01, error(valid)=9.68e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 1.68s to complete
#   error(train)=5.98e-02, acc(train)=9.85e-01, error(valid)=9.21e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 0.83s to complete
#   error(train)=5.32e-02, acc(train)=9.87e-01, error(valid)=8.91e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 50: 0.84s to complete
#   error(train)=4.80e-02, acc(train)=9.89e-01, error(valid)=8.66e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 0.91s to complete
#   error(train)=4.33e-02, acc(train)=9.90e-01, error(valid)=8.34e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 60: 0.86s to complete
#   error(train)=3.81e-02, acc(train)=9.92e-01, error(valid)=8.16e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 0.90s to complete
#   error(train)=3.49e-02, acc(train)=9.93e-01, error(valid)=7.97e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 0.87s to complete
#   error(train)=3.10e-02, acc(train)=9.94e-01, error(valid)=7.94e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 75: 1.03s to complete
#   error(train)=2.84e-02, acc(train)=9.95e-01, error(valid)=7.88e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.24s to complete
#   error(train)=2.58e-02, acc(train)=9.96e-01, error(valid)=7.82e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.69s to complete
#   error(train)=2.38e-02, acc(train)=9.96e-01, error(valid)=7.84e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.04s to complete
#   error(train)=2.20e-02, acc(train)=9.97e-01, error(valid)=7.76e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.59s to complete
#   error(train)=1.99e-02, acc(train)=9.97e-01, error(valid)=7.77e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 1.02s to complete
#   error(train)=1.87e-02, acc(train)=9.98e-01, error(valid)=7.73e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.50e+00, acc(train)=1.02e-01, error(valid)=2.51e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 0.88s to complete
#   error(train)=2.47e-01, acc(train)=9.29e-01, error(valid)=2.34e-01, acc(valid)=9.31e-01, params_penalty=0.00e+00
# Epoch 10: 1.09s to complete
#   error(train)=1.77e-01, acc(train)=9.49e-01, error(valid)=1.75e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.84s to complete
#   error(train)=1.38e-01, acc(train)=9.61e-01, error(valid)=1.45e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 20: 0.90s to complete
#   error(train)=1.13e-01, acc(train)=9.68e-01, error(valid)=1.25e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.83s to complete
#   error(train)=9.36e-02, acc(train)=9.74e-01, error(valid)=1.12e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 30: 1.01s to complete
#   error(train)=7.98e-02, acc(train)=9.78e-01, error(valid)=1.03e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 0.84s to complete
#   error(train)=6.95e-02, acc(train)=9.81e-01, error(valid)=9.74e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 0.89s to complete
#   error(train)=6.15e-02, acc(train)=9.84e-01, error(valid)=9.22e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 0.95s to complete
#   error(train)=5.37e-02, acc(train)=9.86e-01, error(valid)=8.75e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.45s to complete
#   error(train)=4.82e-02, acc(train)=9.88e-01, error(valid)=8.40e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 0.83s to complete
#   error(train)=4.33e-02, acc(train)=9.90e-01, error(valid)=8.31e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.37s to complete
#   error(train)=3.88e-02, acc(train)=9.91e-01, error(valid)=8.10e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 0.97s to complete
#   error(train)=3.51e-02, acc(train)=9.93e-01, error(valid)=7.94e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 1.66s to complete
#   error(train)=3.19e-02, acc(train)=9.94e-01, error(valid)=7.84e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 0.86s to complete
#   error(train)=2.91e-02, acc(train)=9.95e-01, error(valid)=7.78e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.67s to complete
#   error(train)=2.66e-02, acc(train)=9.96e-01, error(valid)=7.69e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 0.97s to complete
#   error(train)=2.43e-02, acc(train)=9.96e-01, error(valid)=7.60e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.92s to complete
#   error(train)=2.21e-02, acc(train)=9.97e-01, error(valid)=7.61e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 0.90s to complete
#   error(train)=2.03e-02, acc(train)=9.97e-01, error(valid)=7.57e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 1.29s to complete
#   error(train)=1.89e-02, acc(train)=9.98e-01, error(valid)=7.63e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.54e+00, acc(train)=1.02e-01, error(valid)=2.53e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 1.00s to complete
#   error(train)=2.40e-01, acc(train)=9.31e-01, error(valid)=2.26e-01, acc(valid)=9.37e-01, params_penalty=0.00e+00
# Epoch 10: 0.88s to complete
#   error(train)=1.76e-01, acc(train)=9.49e-01, error(valid)=1.74e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Epoch 15: 0.83s to complete
#   error(train)=1.36e-01, acc(train)=9.61e-01, error(valid)=1.43e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# Epoch 20: 0.90s to complete
#   error(train)=1.10e-01, acc(train)=9.68e-01, error(valid)=1.23e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.83s to complete
#   error(train)=9.26e-02, acc(train)=9.75e-01, error(valid)=1.09e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 1.50s to complete
#   error(train)=7.95e-02, acc(train)=9.79e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 0.84s to complete
#   error(train)=6.86e-02, acc(train)=9.82e-01, error(valid)=9.36e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 1.88s to complete
#   error(train)=6.04e-02, acc(train)=9.85e-01, error(valid)=8.92e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 45: 0.87s to complete
#   error(train)=5.34e-02, acc(train)=9.86e-01, error(valid)=8.57e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.96s to complete
#   error(train)=4.73e-02, acc(train)=9.88e-01, error(valid)=8.16e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 0.91s to complete
#   error(train)=4.27e-02, acc(train)=9.90e-01, error(valid)=8.05e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.78s to complete
#   error(train)=3.81e-02, acc(train)=9.92e-01, error(valid)=7.70e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 0.90s to complete
#   error(train)=3.43e-02, acc(train)=9.93e-01, error(valid)=7.57e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 1.02s to complete
#   error(train)=3.10e-02, acc(train)=9.94e-01, error(valid)=7.45e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 0.89s to complete
#   error(train)=2.83e-02, acc(train)=9.95e-01, error(valid)=7.39e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 0.87s to complete
#   error(train)=2.57e-02, acc(train)=9.96e-01, error(valid)=7.22e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 0.95s to complete
#   error(train)=2.41e-02, acc(train)=9.96e-01, error(valid)=7.30e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 0.84s to complete
#   error(train)=2.17e-02, acc(train)=9.97e-01, error(valid)=7.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.84s to complete
#   error(train)=1.99e-02, acc(train)=9.97e-01, error(valid)=7.15e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 0.88s to complete
#   error(train)=1.85e-02, acc(train)=9.98e-01, error(valid)=7.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.42e+00, acc(train)=8.90e-02, error(valid)=2.42e+00, acc(valid)=8.54e-02, params_penalty=0.00e+00
# Epoch 5: 1.34s to complete
#   error(train)=2.39e-01, acc(train)=9.31e-01, error(valid)=2.27e-01, acc(valid)=9.37e-01, params_penalty=0.00e+00
# Epoch 10: 0.91s to complete
#   error(train)=1.75e-01, acc(train)=9.50e-01, error(valid)=1.73e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Epoch 15: 0.83s to complete
#   error(train)=1.37e-01, acc(train)=9.61e-01, error(valid)=1.44e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 20: 0.89s to complete
#   error(train)=1.11e-01, acc(train)=9.69e-01, error(valid)=1.23e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 25: 0.83s to complete
#   error(train)=9.43e-02, acc(train)=9.74e-01, error(valid)=1.12e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 0.91s to complete
#   error(train)=8.04e-02, acc(train)=9.78e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 0.88s to complete
#   error(train)=6.98e-02, acc(train)=9.82e-01, error(valid)=9.57e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 40: 0.95s to complete
#   error(train)=6.04e-02, acc(train)=9.84e-01, error(valid)=9.02e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 0.85s to complete
#   error(train)=5.33e-02, acc(train)=9.87e-01, error(valid)=8.65e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.67s to complete
#   error(train)=4.74e-02, acc(train)=9.89e-01, error(valid)=8.40e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 0.91s to complete
#   error(train)=4.26e-02, acc(train)=9.90e-01, error(valid)=8.10e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.70s to complete
#   error(train)=3.85e-02, acc(train)=9.91e-01, error(valid)=8.10e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 0.92s to complete
#   error(train)=3.43e-02, acc(train)=9.93e-01, error(valid)=7.81e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 1.31s to complete
#   error(train)=3.12e-02, acc(train)=9.94e-01, error(valid)=7.67e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 0.89s to complete
#   error(train)=2.82e-02, acc(train)=9.95e-01, error(valid)=7.61e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 80: 0.86s to complete
#   error(train)=2.60e-02, acc(train)=9.96e-01, error(valid)=7.49e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 0.93s to complete
#   error(train)=2.35e-02, acc(train)=9.96e-01, error(valid)=7.43e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.45s to complete
#   error(train)=2.16e-02, acc(train)=9.97e-01, error(valid)=7.41e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 95: 1.24s to complete
#   error(train)=1.97e-02, acc(train)=9.97e-01, error(valid)=7.35e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 2.40s to complete
#   error(train)=1.82e-02, acc(train)=9.98e-01, error(valid)=7.41e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.46e+00, acc(train)=9.68e-02, error(valid)=2.45e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 5: 1.07s to complete
#   error(train)=2.40e-01, acc(train)=9.31e-01, error(valid)=2.29e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# Epoch 10: 0.84s to complete
#   error(train)=1.74e-01, acc(train)=9.51e-01, error(valid)=1.73e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.90s to complete
#   error(train)=1.36e-01, acc(train)=9.61e-01, error(valid)=1.44e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 0.85s to complete
#   error(train)=1.12e-01, acc(train)=9.69e-01, error(valid)=1.27e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.89s to complete
#   error(train)=9.29e-02, acc(train)=9.75e-01, error(valid)=1.13e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 0.84s to complete
#   error(train)=8.09e-02, acc(train)=9.78e-01, error(valid)=1.05e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 1.55s to complete
#   error(train)=6.96e-02, acc(train)=9.81e-01, error(valid)=9.87e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 0.83s to complete
#   error(train)=6.23e-02, acc(train)=9.83e-01, error(valid)=9.56e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 45: 1.54s to complete
#   error(train)=5.38e-02, acc(train)=9.86e-01, error(valid)=8.94e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 50: 0.83s to complete
#   error(train)=4.81e-02, acc(train)=9.88e-01, error(valid)=8.68e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 1.66s to complete
#   error(train)=4.25e-02, acc(train)=9.90e-01, error(valid)=8.44e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 0.83s to complete
#   error(train)=3.81e-02, acc(train)=9.92e-01, error(valid)=8.29e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.67s to complete
#   error(train)=3.48e-02, acc(train)=9.93e-01, error(valid)=8.21e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 0.83s to complete
#   error(train)=3.12e-02, acc(train)=9.94e-01, error(valid)=7.99e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 0.84s to complete
#   error(train)=2.84e-02, acc(train)=9.95e-01, error(valid)=7.85e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 0.90s to complete
#   error(train)=2.61e-02, acc(train)=9.96e-01, error(valid)=7.87e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 85: 0.84s to complete
#   error(train)=2.38e-02, acc(train)=9.96e-01, error(valid)=7.76e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 0.90s to complete
#   error(train)=2.18e-02, acc(train)=9.97e-01, error(valid)=7.67e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.18s to complete
#   error(train)=2.00e-02, acc(train)=9.98e-01, error(valid)=7.66e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.96s to complete
#   error(train)=1.84e-02, acc(train)=9.98e-01, error(valid)=7.65e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.42e+00, acc(train)=1.25e-01, error(valid)=2.43e+00, acc(valid)=1.15e-01, params_penalty=0.00e+00
# Epoch 5: 0.90s to complete
#   error(train)=2.45e-01, acc(train)=9.30e-01, error(valid)=2.33e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# Epoch 10: 1.73s to complete
#   error(train)=1.78e-01, acc(train)=9.49e-01, error(valid)=1.77e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.90s to complete
#   error(train)=1.38e-01, acc(train)=9.61e-01, error(valid)=1.46e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# Epoch 20: 1.69s to complete
#   error(train)=1.13e-01, acc(train)=9.68e-01, error(valid)=1.26e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# Epoch 25: 0.92s to complete
#   error(train)=9.41e-02, acc(train)=9.74e-01, error(valid)=1.13e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 30: 0.97s to complete
#   error(train)=8.10e-02, acc(train)=9.78e-01, error(valid)=1.05e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 0.93s to complete
#   error(train)=7.00e-02, acc(train)=9.82e-01, error(valid)=9.77e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 40: 0.83s to complete
#   error(train)=6.20e-02, acc(train)=9.84e-01, error(valid)=9.39e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 45: 1.04s to complete
#   error(train)=5.45e-02, acc(train)=9.86e-01, error(valid)=8.95e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 50: 0.90s to complete
#   error(train)=4.88e-02, acc(train)=9.88e-01, error(valid)=8.73e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 0.84s to complete
#   error(train)=4.32e-02, acc(train)=9.90e-01, error(valid)=8.35e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 60: 0.90s to complete
#   error(train)=3.90e-02, acc(train)=9.92e-01, error(valid)=8.22e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 0.92s to complete
#   error(train)=3.52e-02, acc(train)=9.93e-01, error(valid)=8.12e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 70: 2.14s to complete
#   error(train)=3.19e-02, acc(train)=9.94e-01, error(valid)=7.99e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 0.87s to complete
#   error(train)=2.88e-02, acc(train)=9.95e-01, error(valid)=7.83e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.81s to complete
#   error(train)=2.64e-02, acc(train)=9.96e-01, error(valid)=7.74e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 85: 0.92s to complete
#   error(train)=2.42e-02, acc(train)=9.96e-01, error(valid)=7.70e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.05s to complete
#   error(train)=2.20e-02, acc(train)=9.97e-01, error(valid)=7.58e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 0.91s to complete
#   error(train)=2.03e-02, acc(train)=9.97e-01, error(valid)=7.65e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.20s to complete
#   error(train)=1.87e-02, acc(train)=9.98e-01, error(valid)=7.55e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00

# %%
print "max training accuracy"
max([x['Final Training Accuracy'] for x in finalValuesCollection])
# Out:
# max training accuracy
# 0.99794000000000116

# %%
accuracies = [x['Final Testing Accuracy'] for x in finalValuesCollection]
accuracies
# Out:
# [0.97819999999999896,
#  0.97659999999999914,
#  0.97829999999999917,
#  0.97859999999999903,
#  0.97769999999999868,
#  0.97659999999999936,
#  0.97749999999999926,
#  0.9771999999999994,
#  0.9769999999999992,
#  0.977799999999999]

# %%
fig = plt.figure()
plt.title('Final Testing Accuracies for various randomly initialized weights')
plt.plot(range(len(finalValuesCollection)), accuracies, 'b.-')
plt.xlabel('seed of random generator')
plt.ylabel('Final Testing Accuracy')
plt.show()
figcount += 1
fig.savefig('experiment3_%02d.svg' % figcount)
print "figcount: " + str(figcount)
# Out:
# figcount: 7

# %%
{
 "mean value of accuracies is": np.mean(accuracies),
 "max value of accuracies is": np.max(accuracies),
 "min value of accuracies is": np.min(accuracies)
}
# Out:
# {'max value of accuracies is': 0.97859999999999903,
#  'mean value of accuracies is': 0.97754999999999903,
#  'min value of accuracies is': 0.97659999999999914}

# %%
errors = [x['Final Testing Error'] for x in finalValuesCollection]
errors
# Out:
# [0.074950895248583449,
#  0.074919634361364063,
#  0.074074745649138227,
#  0.073163579742858281,
#  0.077343073407462298,
#  0.076283362312939751,
#  0.071047685963312984,
#  0.074060706531042048,
#  0.076492233452106539,
#  0.075492128936248321]

# %%
fig = plt.figure()
plt.title('Final Testing Errors for various randomly initialized weights')
plt.plot(range(len(finalValuesCollection)), errors, 'r.-')
plt.xlabel('seed of random generator')
plt.ylabel('Final Testing Error')
plt.show()
figcount += 1
fig.savefig('experiment3_%02d.svg' % figcount)
print "figcount: " + str(figcount)
# Out:
# figcount: 8

# %%
{
 "mean value of errors is": np.mean(errors),
 "max value of errors is": np.max(errors),
 "min value of errors is": np.min(errors)
}
# Out:
# {'max value of errors is': 0.077343073407462298,
#  'mean value of errors is': 0.074782804560505595,
#  'min value of errors is': 0.071047685963312984}

# %% [markdown]
# ### Pretraining with Linear Stacked AutoEncoder for 2 layers model

# %%
hiddenDims = np.array([100, 10])
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=5.92e+01, acc(train)=8.80e-04, params_penalty=0.00e+00
# Epoch 5: 4.67s to complete
#   error(train)=2.32e+00, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 10: 5.27s to complete
#   error(train)=2.32e+00, acc(train)=1.54e-02, params_penalty=0.00e+00
# Epoch 15: 5.57s to complete
#   error(train)=2.36e+00, acc(train)=1.50e-02, params_penalty=0.00e+00
# Epoch 20: 4.90s to complete
#   error(train)=2.29e+00, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 25: 4.20s to complete
#   error(train)=2.30e+00, acc(train)=1.49e-02, params_penalty=0.00e+00
# Epoch 30: 3.78s to complete
#   error(train)=2.30e+00, acc(train)=1.49e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.97e+00, acc(train)=7.60e-03, params_penalty=0.00e+00
# Epoch 5: 0.50s to complete
#   error(train)=1.52e+00, acc(train)=3.00e-01, params_penalty=0.00e+00
# Epoch 10: 0.80s to complete
#   error(train)=1.52e+00, acc(train)=3.02e-01, params_penalty=0.00e+00
# Epoch 15: 0.48s to complete
#   error(train)=1.52e+00, acc(train)=2.99e-01, params_penalty=0.00e+00
# Epoch 20: 0.49s to complete
#   error(train)=1.52e+00, acc(train)=3.01e-01, params_penalty=0.00e+00
# Epoch 25: 0.53s to complete
#   error(train)=1.52e+00, acc(train)=3.02e-01, params_penalty=0.00e+00
# Epoch 30: 0.88s to complete
#   error(train)=1.52e+00, acc(train)=3.02e-01, params_penalty=0.00e+00

# %%
reconstructedModel = MultipleLayerModel([
        model.layers[0],
        SigmoidLayer(),
        model.layers[1]
    ])

# %%
num_epochs = 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(reconstructedModel,
                                  error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_2_layers_100_per_layer_linear_pretraining_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_2_layers_100_per_layer_linear_pretraining_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.32e+00, acc(train)=1.17e-01, error(valid)=2.32e+00, acc(valid)=1.15e-01, params_penalty=0.00e+00
# Epoch 5: 0.91s to complete
#   error(train)=2.50e-01, acc(train)=9.27e-01, error(valid)=2.37e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 10: 0.84s to complete
#   error(train)=1.82e-01, acc(train)=9.48e-01, error(valid)=1.80e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Epoch 15: 0.90s to complete
#   error(train)=1.45e-01, acc(train)=9.58e-01, error(valid)=1.51e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# Epoch 20: 0.86s to complete
#   error(train)=1.17e-01, acc(train)=9.67e-01, error(valid)=1.31e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# Epoch 25: 1.08s to complete
#   error(train)=9.81e-02, acc(train)=9.73e-01, error(valid)=1.16e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 30: 0.90s to complete
#   error(train)=8.42e-02, acc(train)=9.77e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 0.90s to complete
#   error(train)=7.38e-02, acc(train)=9.81e-01, error(valid)=9.94e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 0.86s to complete
#   error(train)=6.42e-02, acc(train)=9.83e-01, error(valid)=9.32e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 45: 1.31s to complete
#   error(train)=5.69e-02, acc(train)=9.86e-01, error(valid)=8.93e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 50: 0.87s to complete
#   error(train)=5.03e-02, acc(train)=9.88e-01, error(valid)=8.59e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 1.71s to complete
#   error(train)=4.50e-02, acc(train)=9.89e-01, error(valid)=8.36e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.29s to complete
#   error(train)=4.08e-02, acc(train)=9.91e-01, error(valid)=8.20e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 1.16s to complete
#   error(train)=3.72e-02, acc(train)=9.92e-01, error(valid)=7.90e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 70: 0.92s to complete
#   error(train)=3.31e-02, acc(train)=9.94e-01, error(valid)=7.84e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 75: 1.11s to complete
#   error(train)=3.00e-02, acc(train)=9.94e-01, error(valid)=7.59e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 0.94s to complete
#   error(train)=2.72e-02, acc(train)=9.95e-01, error(valid)=7.46e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 0.87s to complete
#   error(train)=2.49e-02, acc(train)=9.96e-01, error(valid)=7.39e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 0.92s to complete
#   error(train)=2.26e-02, acc(train)=9.97e-01, error(valid)=7.40e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 0.97s to complete
#   error(train)=2.13e-02, acc(train)=9.97e-01, error(valid)=7.38e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.58s to complete
#   error(train)=1.91e-02, acc(train)=9.97e-01, error(valid)=7.16e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# figcount: 9
# Run Time:
# 129.11024189
# {'Final Testing Accuracy': 0.9778999999999991,
#  'Final Testing Error': 0.071578519487560929,
#  'Final Training Accuracy': 0.99748000000000137,
#  'Final Training Error': 0.019062135396377036}

# %% [markdown]
# For the pretraining with the linear stacked autoencoder yielded a little bit higher final testing error and the accuracy is not spectacular it is only 97.5 percent which is lower than the minimum value of our previous experiment.
#
# We cannot make any conclusions based on this data. The result of this experiment is that random or pretraining is the same.
#
# Below we are going to try again but using our Non-Linear Stacked AutoEncoder this time.

# %% [markdown]
# ### Pretraining with Non Linear Stacked AutoEncoder for 2 layers model

# %%
hiddenDims = np.array([100, 10])
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeNonLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=9.16e+01, acc(train)=8.20e-04, params_penalty=0.00e+00
# Epoch 5: 5.30s to complete
#   error(train)=4.04e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 10: 6.53s to complete
#   error(train)=2.16e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 15: 6.33s to complete
#   error(train)=1.31e+00, acc(train)=1.45e-02, params_penalty=0.00e+00
# Epoch 20: 7.19s to complete
#   error(train)=1.10e+00, acc(train)=1.41e-02, params_penalty=0.00e+00
# Epoch 25: 8.35s to complete
#   error(train)=1.00e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 30: 6.78s to complete
#   error(train)=9.40e-01, acc(train)=1.38e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.10e+00, acc(train)=1.68e-02, params_penalty=0.00e+00
# Epoch 5: 1.02s to complete
#   error(train)=2.18e+00, acc(train)=4.30e-02, params_penalty=0.00e+00
# Epoch 10: 1.13s to complete
#   error(train)=2.15e+00, acc(train)=4.19e-02, params_penalty=0.00e+00
# Epoch 15: 2.41s to complete
#   error(train)=2.14e+00, acc(train)=4.12e-02, params_penalty=0.00e+00
# Epoch 20: 1.06s to complete
#   error(train)=2.13e+00, acc(train)=4.21e-02, params_penalty=0.00e+00
# Epoch 25: 0.81s to complete
#   error(train)=2.13e+00, acc(train)=4.31e-02, params_penalty=0.00e+00
# Epoch 30: 1.37s to complete
#   error(train)=2.12e+00, acc(train)=4.26e-02, params_penalty=0.00e+00

# %%
reconstructedModel = MultipleLayerModel(model.layers[:-1])

# %%
num_epochs = 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(reconstructedModel,
                                  error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_2_layers_100_per_layer_nonlinear_pretraining_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_2_layers_100_per_layer_nonlinear_pretraining_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.81e+00, acc(train)=7.13e-02, error(valid)=2.80e+00, acc(valid)=6.97e-02, params_penalty=0.00e+00
# Epoch 5: 0.98s to complete
#   error(train)=2.40e-01, acc(train)=9.31e-01, error(valid)=2.28e-01, acc(valid)=9.36e-01, params_penalty=0.00e+00
# Epoch 10: 1.39s to complete
#   error(train)=1.79e-01, acc(train)=9.49e-01, error(valid)=1.78e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 0.91s to complete
#   error(train)=1.39e-01, acc(train)=9.61e-01, error(valid)=1.49e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# Epoch 20: 0.92s to complete
#   error(train)=1.14e-01, acc(train)=9.68e-01, error(valid)=1.34e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Epoch 25: 1.00s to complete
#   error(train)=9.55e-02, acc(train)=9.74e-01, error(valid)=1.21e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 30: 0.95s to complete
#   error(train)=8.46e-02, acc(train)=9.78e-01, error(valid)=1.16e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 35: 0.89s to complete
#   error(train)=7.15e-02, acc(train)=9.82e-01, error(valid)=1.07e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 40: 1.09s to complete
#   error(train)=6.31e-02, acc(train)=9.85e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 45: 1.13s to complete
#   error(train)=5.56e-02, acc(train)=9.87e-01, error(valid)=9.85e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 50: 0.94s to complete
#   error(train)=4.99e-02, acc(train)=9.89e-01, error(valid)=9.59e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 55: 1.05s to complete
#   error(train)=4.49e-02, acc(train)=9.90e-01, error(valid)=9.30e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 60: 1.08s to complete
#   error(train)=4.01e-02, acc(train)=9.92e-01, error(valid)=9.09e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 65: 0.89s to complete
#   error(train)=3.61e-02, acc(train)=9.93e-01, error(valid)=8.95e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 70: 1.61s to complete
#   error(train)=3.30e-02, acc(train)=9.94e-01, error(valid)=8.83e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 75: 1.41s to complete
#   error(train)=2.99e-02, acc(train)=9.95e-01, error(valid)=8.74e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.44s to complete
#   error(train)=2.78e-02, acc(train)=9.95e-01, error(valid)=8.79e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 85: 1.00s to complete
#   error(train)=2.52e-02, acc(train)=9.96e-01, error(valid)=8.63e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 90: 1.50s to complete
#   error(train)=2.30e-02, acc(train)=9.97e-01, error(valid)=8.54e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 95: 1.55s to complete
#   error(train)=2.11e-02, acc(train)=9.97e-01, error(valid)=8.53e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 100: 1.23s to complete
#   error(train)=1.96e-02, acc(train)=9.98e-01, error(valid)=8.57e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# figcount: 10
# Run Time:
# 131.107201099
# {'Final Testing Accuracy': 0.97589999999999943,
#  'Final Testing Error': 0.085712887076613342,
#  'Final Training Accuracy': 0.99770000000000147,
#  'Final Training Error': 0.019567442932861615}

# %% [markdown]
# We see again that for two layers the pretraining did not yield any spectacular results.
#
# So for two layers we can conclude that pretraining either with linear or non-linear stacked autoencoder does not yield any better results

# %% [markdown]
# ## Three Layer Model with random initialization of weights with Glorot Uniform Initialization

# %% [markdown]
# Let's see how our three layer model behaves within 100 epochs

# %%
curSeed = 0

# %%
num_epochs = 100

input_dim, output_dim, hidden_dim = 784, 10, 100

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, getWeightsInit(curSeed), biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, getWeightsInit(curSeed), biasesInit),
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, getWeightsInit(curSeed), biasesInit)
])

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_3_layers_100_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_3_layers_100_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.40e+00, acc(train)=1.17e-01, error(valid)=2.40e+00, acc(valid)=1.10e-01, params_penalty=0.00e+00
# Epoch 5: 1.40s to complete
#   error(train)=2.58e-01, acc(train)=9.25e-01, error(valid)=2.42e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 10: 1.35s to complete
#   error(train)=1.77e-01, acc(train)=9.48e-01, error(valid)=1.73e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Epoch 15: 1.37s to complete
#   error(train)=1.32e-01, acc(train)=9.61e-01, error(valid)=1.39e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 1.58s to complete
#   error(train)=9.99e-02, acc(train)=9.72e-01, error(valid)=1.16e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 25: 1.21s to complete
#   error(train)=8.09e-02, acc(train)=9.77e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 1.37s to complete
#   error(train)=6.28e-02, acc(train)=9.83e-01, error(valid)=9.48e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 35: 1.42s to complete
#   error(train)=5.09e-02, acc(train)=9.87e-01, error(valid)=8.93e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.16s to complete
#   error(train)=4.20e-02, acc(train)=9.89e-01, error(valid)=8.64e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.94s to complete
#   error(train)=3.34e-02, acc(train)=9.92e-01, error(valid)=8.23e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.66s to complete
#   error(train)=2.97e-02, acc(train)=9.94e-01, error(valid)=8.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 55: 1.19s to complete
#   error(train)=2.25e-02, acc(train)=9.96e-01, error(valid)=7.95e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.57s to complete
#   error(train)=1.88e-02, acc(train)=9.97e-01, error(valid)=7.97e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 2.10s to complete
#   error(train)=1.62e-02, acc(train)=9.98e-01, error(valid)=8.05e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 1.96s to complete
#   error(train)=1.33e-02, acc(train)=9.99e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.20s to complete
#   error(train)=1.11e-02, acc(train)=9.99e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.45s to complete
#   error(train)=9.58e-03, acc(train)=9.99e-01, error(valid)=8.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 2.27s to complete
#   error(train)=8.20e-03, acc(train)=1.00e+00, error(valid)=8.24e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.36s to complete
#   error(train)=7.41e-03, acc(train)=1.00e+00, error(valid)=8.50e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.46s to complete
#   error(train)=6.56e-03, acc(train)=1.00e+00, error(valid)=8.42e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 1.22s to complete
#   error(train)=5.58e-03, acc(train)=1.00e+00, error(valid)=8.47e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# figcount: 11
# Run Time:
# 173.823220015
# {'Final Testing Accuracy': 0.9778999999999991,
#  'Final Testing Error': 0.084736826625688905,
#  'Final Training Accuracy': 0.99982000000000015,
#  'Final Training Error': 0.0055768883911021475}

# %% [markdown]
# After 100 epochs we have reached at ~97.78% of accuracy for our classification task
#
# Let's repeat that for various seeds and see what we are getting

# %%
num_epochs = 100

# %%
def fitAndScoreThreeLayer(theSeed):
    input_dim, output_dim, hidden_dim = 784, 10, 100

    # Multiclass classification therefore use cross-entropy + softmax error
    error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, getWeightsInit(theSeed), biasesInit),
        SigmoidLayer(),
        AffineLayer(hidden_dim, hidden_dim, getWeightsInit(theSeed), biasesInit),
        SigmoidLayer(),
        AffineLayer(hidden_dim, output_dim, getWeightsInit(theSeed), biasesInit)
    ])

    learning_rate = 1e-1
    learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

    stats, keys, runTime = trainModel(model, error, learningRule, trainData, validData, num_epochs, statsInterval)

    return getFinalValues(stats)

# %%
seeds = range(10)

finalValuesCollection = []

for curSeed in seeds:
    finalValuesCollection.append(
        fitAndScoreThreeLayer(curSeed)
    )
# Out:
# Epoch 0:
#   error(train)=2.40e+00, acc(train)=1.17e-01, error(valid)=2.40e+00, acc(valid)=1.10e-01, params_penalty=0.00e+00
# Epoch 5: 1.13s to complete
#   error(train)=2.57e-01, acc(train)=9.25e-01, error(valid)=2.40e-01, acc(valid)=9.31e-01, params_penalty=0.00e+00
# Epoch 10: 1.14s to complete
#   error(train)=1.76e-01, acc(train)=9.49e-01, error(valid)=1.70e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 1.17s to complete
#   error(train)=1.30e-01, acc(train)=9.62e-01, error(valid)=1.37e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 1.20s to complete
#   error(train)=1.00e-01, acc(train)=9.71e-01, error(valid)=1.16e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 25: 1.75s to complete
#   error(train)=7.99e-02, acc(train)=9.78e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 1.60s to complete
#   error(train)=6.29e-02, acc(train)=9.83e-01, error(valid)=9.47e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 1.25s to complete
#   error(train)=5.39e-02, acc(train)=9.85e-01, error(valid)=9.02e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.22s to complete
#   error(train)=4.24e-02, acc(train)=9.89e-01, error(valid)=8.76e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 1.20s to complete
#   error(train)=3.50e-02, acc(train)=9.91e-01, error(valid)=8.34e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.26s to complete
#   error(train)=2.87e-02, acc(train)=9.94e-01, error(valid)=8.35e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 2.48s to complete
#   error(train)=2.34e-02, acc(train)=9.96e-01, error(valid)=8.08e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.21s to complete
#   error(train)=1.90e-02, acc(train)=9.97e-01, error(valid)=8.07e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.27s to complete
#   error(train)=1.60e-02, acc(train)=9.98e-01, error(valid)=8.20e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 1.20s to complete
#   error(train)=1.33e-02, acc(train)=9.99e-01, error(valid)=8.22e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.34s to complete
#   error(train)=1.12e-02, acc(train)=9.99e-01, error(valid)=8.30e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.16s to complete
#   error(train)=1.03e-02, acc(train)=9.99e-01, error(valid)=8.52e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 2.01s to complete
#   error(train)=8.17e-03, acc(train)=1.00e+00, error(valid)=8.36e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.20s to complete
#   error(train)=7.24e-03, acc(train)=1.00e+00, error(valid)=8.57e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.16s to complete
#   error(train)=6.33e-03, acc(train)=1.00e+00, error(valid)=8.67e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 2.53s to complete
#   error(train)=5.47e-03, acc(train)=1.00e+00, error(valid)=8.68e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.51e+00, acc(train)=9.94e-02, error(valid)=2.50e+00, acc(valid)=9.90e-02, params_penalty=0.00e+00
# Epoch 5: 1.23s to complete
#   error(train)=2.62e-01, acc(train)=9.24e-01, error(valid)=2.48e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Epoch 10: 1.27s to complete
#   error(train)=1.76e-01, acc(train)=9.49e-01, error(valid)=1.75e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Epoch 15: 1.34s to complete
#   error(train)=1.25e-01, acc(train)=9.64e-01, error(valid)=1.34e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# Epoch 20: 1.20s to complete
#   error(train)=9.89e-02, acc(train)=9.73e-01, error(valid)=1.17e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 25: 1.17s to complete
#   error(train)=7.65e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 30: 1.14s to complete
#   error(train)=6.09e-02, acc(train)=9.84e-01, error(valid)=9.30e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 3.00s to complete
#   error(train)=4.93e-02, acc(train)=9.87e-01, error(valid)=8.87e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 40: 2.86s to complete
#   error(train)=4.28e-02, acc(train)=9.89e-01, error(valid)=8.72e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 1.99s to complete
#   error(train)=3.32e-02, acc(train)=9.92e-01, error(valid)=8.45e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.72s to complete
#   error(train)=2.71e-02, acc(train)=9.94e-01, error(valid)=8.29e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 55: 1.13s to complete
#   error(train)=2.38e-02, acc(train)=9.95e-01, error(valid)=8.32e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.64s to complete
#   error(train)=1.95e-02, acc(train)=9.97e-01, error(valid)=8.25e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.93s to complete
#   error(train)=1.62e-02, acc(train)=9.98e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.20s to complete
#   error(train)=1.43e-02, acc(train)=9.99e-01, error(valid)=8.48e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.22s to complete
#   error(train)=1.14e-02, acc(train)=9.99e-01, error(valid)=8.15e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 80: 1.13s to complete
#   error(train)=9.39e-03, acc(train)=9.99e-01, error(valid)=8.30e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 2.27s to complete
#   error(train)=8.21e-03, acc(train)=1.00e+00, error(valid)=8.43e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.20s to complete
#   error(train)=7.14e-03, acc(train)=1.00e+00, error(valid)=8.48e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.16s to complete
#   error(train)=6.34e-03, acc(train)=1.00e+00, error(valid)=8.45e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.96s to complete
#   error(train)=5.56e-03, acc(train)=1.00e+00, error(valid)=8.69e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.72e+00, acc(train)=9.72e-02, error(valid)=2.72e+00, acc(valid)=9.83e-02, params_penalty=0.00e+00
# Epoch 5: 1.34s to complete
#   error(train)=2.60e-01, acc(train)=9.24e-01, error(valid)=2.46e-01, acc(valid)=9.29e-01, params_penalty=0.00e+00
# Epoch 10: 1.24s to complete
#   error(train)=1.72e-01, acc(train)=9.50e-01, error(valid)=1.71e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Epoch 15: 1.17s to complete
#   error(train)=1.25e-01, acc(train)=9.64e-01, error(valid)=1.37e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 1.20s to complete
#   error(train)=9.40e-02, acc(train)=9.73e-01, error(valid)=1.14e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 25: 2.81s to complete
#   error(train)=7.38e-02, acc(train)=9.80e-01, error(valid)=1.01e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 30: 1.54s to complete
#   error(train)=6.19e-02, acc(train)=9.83e-01, error(valid)=9.43e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 35: 1.34s to complete
#   error(train)=4.95e-02, acc(train)=9.87e-01, error(valid)=8.94e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.31s to complete
#   error(train)=4.04e-02, acc(train)=9.90e-01, error(valid)=8.57e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.18s to complete
#   error(train)=3.41e-02, acc(train)=9.92e-01, error(valid)=8.33e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.86s to complete
#   error(train)=2.74e-02, acc(train)=9.94e-01, error(valid)=8.03e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 55: 1.37s to complete
#   error(train)=2.25e-02, acc(train)=9.96e-01, error(valid)=8.00e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.16s to complete
#   error(train)=1.90e-02, acc(train)=9.97e-01, error(valid)=8.05e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.21s to complete
#   error(train)=1.55e-02, acc(train)=9.98e-01, error(valid)=8.11e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 70: 2.43s to complete
#   error(train)=1.40e-02, acc(train)=9.98e-01, error(valid)=8.11e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.20s to complete
#   error(train)=1.18e-02, acc(train)=9.99e-01, error(valid)=8.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.15s to complete
#   error(train)=9.44e-03, acc(train)=9.99e-01, error(valid)=8.28e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.18s to complete
#   error(train)=8.18e-03, acc(train)=1.00e+00, error(valid)=8.34e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.35s to complete
#   error(train)=7.15e-03, acc(train)=1.00e+00, error(valid)=8.37e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.20s to complete
#   error(train)=6.29e-03, acc(train)=1.00e+00, error(valid)=8.46e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.16s to complete
#   error(train)=5.64e-03, acc(train)=1.00e+00, error(valid)=8.60e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.53e+00, acc(train)=9.68e-02, error(valid)=2.53e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 5: 1.73s to complete
#   error(train)=2.63e-01, acc(train)=9.22e-01, error(valid)=2.49e-01, acc(valid)=9.27e-01, params_penalty=0.00e+00
# Epoch 10: 1.42s to complete
#   error(train)=1.70e-01, acc(train)=9.50e-01, error(valid)=1.68e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Epoch 15: 1.23s to complete
#   error(train)=1.24e-01, acc(train)=9.64e-01, error(valid)=1.33e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 1.20s to complete
#   error(train)=9.49e-02, acc(train)=9.73e-01, error(valid)=1.13e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 25: 1.40s to complete
#   error(train)=7.85e-02, acc(train)=9.78e-01, error(valid)=1.07e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 2.01s to complete
#   error(train)=6.00e-02, acc(train)=9.83e-01, error(valid)=9.50e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 35: 2.93s to complete
#   error(train)=4.92e-02, acc(train)=9.86e-01, error(valid)=9.10e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.36s to complete
#   error(train)=4.13e-02, acc(train)=9.89e-01, error(valid)=8.62e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.51s to complete
#   error(train)=3.24e-02, acc(train)=9.93e-01, error(valid)=8.40e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 50: 1.29s to complete
#   error(train)=2.83e-02, acc(train)=9.94e-01, error(valid)=8.31e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 55: 2.30s to complete
#   error(train)=2.24e-02, acc(train)=9.96e-01, error(valid)=8.15e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 60: 1.33s to complete
#   error(train)=1.82e-02, acc(train)=9.97e-01, error(valid)=8.12e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 65: 1.16s to complete
#   error(train)=1.55e-02, acc(train)=9.98e-01, error(valid)=8.05e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.15s to complete
#   error(train)=1.33e-02, acc(train)=9.99e-01, error(valid)=8.19e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.76s to complete
#   error(train)=1.11e-02, acc(train)=9.99e-01, error(valid)=8.20e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.21s to complete
#   error(train)=9.65e-03, acc(train)=9.99e-01, error(valid)=8.20e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.21s to complete
#   error(train)=8.87e-03, acc(train)=9.99e-01, error(valid)=8.32e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.20s to complete
#   error(train)=7.14e-03, acc(train)=1.00e+00, error(valid)=8.28e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 2.17s to complete
#   error(train)=6.17e-03, acc(train)=1.00e+00, error(valid)=8.34e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 100: 1.21s to complete
#   error(train)=5.58e-03, acc(train)=1.00e+00, error(valid)=8.38e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.54e+00, acc(train)=1.16e-01, error(valid)=2.54e+00, acc(valid)=1.11e-01, params_penalty=0.00e+00
# Epoch 5: 1.20s to complete
#   error(train)=2.58e-01, acc(train)=9.25e-01, error(valid)=2.42e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 10: 1.54s to complete
#   error(train)=1.72e-01, acc(train)=9.50e-01, error(valid)=1.72e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 1.42s to complete
#   error(train)=1.30e-01, acc(train)=9.61e-01, error(valid)=1.39e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 1.17s to complete
#   error(train)=9.50e-02, acc(train)=9.73e-01, error(valid)=1.16e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 2.33s to complete
#   error(train)=7.60e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 30: 1.33s to complete
#   error(train)=6.13e-02, acc(train)=9.83e-01, error(valid)=9.58e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 1.45s to complete
#   error(train)=5.00e-02, acc(train)=9.87e-01, error(valid)=9.21e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.53s to complete
#   error(train)=3.97e-02, acc(train)=9.91e-01, error(valid)=8.70e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.64s to complete
#   error(train)=3.25e-02, acc(train)=9.93e-01, error(valid)=8.51e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.21s to complete
#   error(train)=2.69e-02, acc(train)=9.94e-01, error(valid)=8.47e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 55: 1.23s to complete
#   error(train)=2.27e-02, acc(train)=9.95e-01, error(valid)=8.54e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.22s to complete
#   error(train)=1.89e-02, acc(train)=9.97e-01, error(valid)=8.48e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 2.26s to complete
#   error(train)=1.47e-02, acc(train)=9.98e-01, error(valid)=8.29e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.20s to complete
#   error(train)=1.29e-02, acc(train)=9.99e-01, error(valid)=8.54e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.13s to complete
#   error(train)=1.04e-02, acc(train)=9.99e-01, error(valid)=8.46e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.20s to complete
#   error(train)=9.40e-03, acc(train)=9.99e-01, error(valid)=8.77e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 2.13s to complete
#   error(train)=8.11e-03, acc(train)=1.00e+00, error(valid)=8.71e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.49s to complete
#   error(train)=6.68e-03, acc(train)=1.00e+00, error(valid)=8.72e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.32s to complete
#   error(train)=5.99e-03, acc(train)=1.00e+00, error(valid)=8.78e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.42s to complete
#   error(train)=5.15e-03, acc(train)=1.00e+00, error(valid)=8.87e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.52e+00, acc(train)=1.02e-01, error(valid)=2.53e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 2.32s to complete
#   error(train)=2.61e-01, acc(train)=9.25e-01, error(valid)=2.46e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# Epoch 10: 1.21s to complete
#   error(train)=1.74e-01, acc(train)=9.48e-01, error(valid)=1.73e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# Epoch 15: 1.14s to complete
#   error(train)=1.24e-01, acc(train)=9.63e-01, error(valid)=1.31e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Epoch 20: 2.05s to complete
#   error(train)=9.34e-02, acc(train)=9.74e-01, error(valid)=1.11e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 1.20s to complete
#   error(train)=7.39e-02, acc(train)=9.79e-01, error(valid)=1.01e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 30: 1.49s to complete
#   error(train)=5.90e-02, acc(train)=9.84e-01, error(valid)=9.12e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 2.97s to complete
#   error(train)=4.91e-02, acc(train)=9.87e-01, error(valid)=8.62e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 40: 1.39s to complete
#   error(train)=4.06e-02, acc(train)=9.90e-01, error(valid)=8.46e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 1.43s to complete
#   error(train)=3.22e-02, acc(train)=9.93e-01, error(valid)=8.02e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 50: 2.05s to complete
#   error(train)=2.63e-02, acc(train)=9.94e-01, error(valid)=7.82e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 55: 1.49s to complete
#   error(train)=2.19e-02, acc(train)=9.96e-01, error(valid)=7.71e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 60: 1.20s to complete
#   error(train)=1.85e-02, acc(train)=9.97e-01, error(valid)=8.00e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 65: 1.16s to complete
#   error(train)=1.55e-02, acc(train)=9.98e-01, error(valid)=8.02e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.13s to complete
#   error(train)=1.28e-02, acc(train)=9.99e-01, error(valid)=7.78e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 75: 1.23s to complete
#   error(train)=1.08e-02, acc(train)=9.99e-01, error(valid)=7.86e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 80: 1.36s to complete
#   error(train)=9.55e-03, acc(train)=9.99e-01, error(valid)=8.07e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 1.22s to complete
#   error(train)=7.82e-03, acc(train)=1.00e+00, error(valid)=7.97e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 90: 1.26s to complete
#   error(train)=6.96e-03, acc(train)=1.00e+00, error(valid)=8.09e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 95: 1.50s to complete
#   error(train)=6.12e-03, acc(train)=1.00e+00, error(valid)=8.15e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 100: 1.25s to complete
#   error(train)=5.32e-03, acc(train)=1.00e+00, error(valid)=8.28e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.59e+00, acc(train)=1.02e-01, error(valid)=2.58e+00, acc(valid)=1.03e-01, params_penalty=0.00e+00
# Epoch 5: 1.57s to complete
#   error(train)=2.54e-01, acc(train)=9.25e-01, error(valid)=2.39e-01, acc(valid)=9.31e-01, params_penalty=0.00e+00
# Epoch 10: 1.36s to complete
#   error(train)=1.71e-01, acc(train)=9.50e-01, error(valid)=1.69e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# Epoch 15: 1.55s to complete
#   error(train)=1.22e-01, acc(train)=9.65e-01, error(valid)=1.32e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Epoch 20: 1.47s to complete
#   error(train)=9.26e-02, acc(train)=9.74e-01, error(valid)=1.12e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 1.33s to complete
#   error(train)=7.51e-02, acc(train)=9.79e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 30: 1.21s to complete
#   error(train)=5.93e-02, acc(train)=9.84e-01, error(valid)=9.32e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 35: 1.14s to complete
#   error(train)=5.04e-02, acc(train)=9.87e-01, error(valid)=9.16e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 2.64s to complete
#   error(train)=3.90e-02, acc(train)=9.91e-01, error(valid)=8.65e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.38s to complete
#   error(train)=3.33e-02, acc(train)=9.92e-01, error(valid)=8.46e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 50: 1.27s to complete
#   error(train)=2.74e-02, acc(train)=9.94e-01, error(valid)=8.42e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 55: 1.26s to complete
#   error(train)=2.24e-02, acc(train)=9.96e-01, error(valid)=8.45e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.47s to complete
#   error(train)=1.84e-02, acc(train)=9.97e-01, error(valid)=8.19e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 65: 1.36s to complete
#   error(train)=1.54e-02, acc(train)=9.98e-01, error(valid)=8.20e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.28s to complete
#   error(train)=1.27e-02, acc(train)=9.99e-01, error(valid)=8.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.29s to complete
#   error(train)=1.08e-02, acc(train)=9.99e-01, error(valid)=8.27e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.39s to complete
#   error(train)=9.22e-03, acc(train)=9.99e-01, error(valid)=8.52e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.48s to complete
#   error(train)=7.91e-03, acc(train)=1.00e+00, error(valid)=8.40e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 1.70s to complete
#   error(train)=6.61e-03, acc(train)=1.00e+00, error(valid)=8.41e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 95: 1.47s to complete
#   error(train)=5.90e-03, acc(train)=1.00e+00, error(valid)=8.55e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.46s to complete
#   error(train)=5.17e-03, acc(train)=1.00e+00, error(valid)=8.56e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.40e+00, acc(train)=9.61e-02, error(valid)=2.39e+00, acc(valid)=9.43e-02, params_penalty=0.00e+00
# Epoch 5: 1.61s to complete
#   error(train)=2.53e-01, acc(train)=9.26e-01, error(valid)=2.40e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 10: 1.86s to complete
#   error(train)=1.74e-01, acc(train)=9.50e-01, error(valid)=1.73e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Epoch 15: 1.47s to complete
#   error(train)=1.26e-01, acc(train)=9.64e-01, error(valid)=1.37e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# Epoch 20: 1.46s to complete
#   error(train)=9.94e-02, acc(train)=9.71e-01, error(valid)=1.22e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 25: 1.52s to complete
#   error(train)=7.77e-02, acc(train)=9.78e-01, error(valid)=1.07e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 30: 1.37s to complete
#   error(train)=6.60e-02, acc(train)=9.82e-01, error(valid)=1.04e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 35: 1.34s to complete
#   error(train)=5.28e-02, acc(train)=9.86e-01, error(valid)=9.80e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 1.34s to complete
#   error(train)=4.15e-02, acc(train)=9.89e-01, error(valid)=9.12e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.34s to complete
#   error(train)=3.48e-02, acc(train)=9.92e-01, error(valid)=9.04e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.35s to complete
#   error(train)=3.31e-02, acc(train)=9.92e-01, error(valid)=9.39e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 55: 1.37s to complete
#   error(train)=2.42e-02, acc(train)=9.96e-01, error(valid)=8.62e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.58s to complete
#   error(train)=1.97e-02, acc(train)=9.97e-01, error(valid)=8.72e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.39s to complete
#   error(train)=1.61e-02, acc(train)=9.98e-01, error(valid)=8.73e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.35s to complete
#   error(train)=1.40e-02, acc(train)=9.99e-01, error(valid)=8.78e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.39s to complete
#   error(train)=1.18e-02, acc(train)=9.99e-01, error(valid)=8.93e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 80: 1.43s to complete
#   error(train)=1.04e-02, acc(train)=9.99e-01, error(valid)=9.03e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 85: 1.61s to complete
#   error(train)=8.55e-03, acc(train)=9.99e-01, error(valid)=8.93e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 90: 1.46s to complete
#   error(train)=7.72e-03, acc(train)=1.00e+00, error(valid)=9.09e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 95: 1.32s to complete
#   error(train)=6.49e-03, acc(train)=1.00e+00, error(valid)=9.13e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 100: 1.44s to complete
#   error(train)=5.75e-03, acc(train)=1.00e+00, error(valid)=9.24e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.43e+00, acc(train)=9.68e-02, error(valid)=2.43e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# Epoch 5: 1.30s to complete
#   error(train)=2.54e-01, acc(train)=9.27e-01, error(valid)=2.40e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# Epoch 10: 1.73s to complete
#   error(train)=1.69e-01, acc(train)=9.50e-01, error(valid)=1.67e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# Epoch 15: 1.38s to complete
#   error(train)=1.23e-01, acc(train)=9.64e-01, error(valid)=1.32e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# Epoch 20: 1.34s to complete
#   error(train)=9.30e-02, acc(train)=9.73e-01, error(valid)=1.11e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 1.45s to complete
#   error(train)=7.44e-02, acc(train)=9.79e-01, error(valid)=9.95e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 30: 1.41s to complete
#   error(train)=5.86e-02, acc(train)=9.84e-01, error(valid)=9.06e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 1.39s to complete
#   error(train)=4.88e-02, acc(train)=9.87e-01, error(valid)=8.72e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 40: 1.33s to complete
#   error(train)=3.91e-02, acc(train)=9.91e-01, error(valid)=8.27e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.36s to complete
#   error(train)=3.26e-02, acc(train)=9.93e-01, error(valid)=8.09e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.70s to complete
#   error(train)=2.70e-02, acc(train)=9.95e-01, error(valid)=7.92e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 55: 1.35s to complete
#   error(train)=2.30e-02, acc(train)=9.96e-01, error(valid)=8.21e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.45s to complete
#   error(train)=1.89e-02, acc(train)=9.97e-01, error(valid)=8.10e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 1.99s to complete
#   error(train)=1.53e-02, acc(train)=9.98e-01, error(valid)=7.86e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 70: 1.34s to complete
#   error(train)=1.35e-02, acc(train)=9.98e-01, error(valid)=8.03e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 1.75s to complete
#   error(train)=1.14e-02, acc(train)=9.99e-01, error(valid)=7.98e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.66s to complete
#   error(train)=9.39e-03, acc(train)=9.99e-01, error(valid)=7.99e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.33s to complete
#   error(train)=8.04e-03, acc(train)=9.99e-01, error(valid)=8.13e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 1.39s to complete
#   error(train)=7.09e-03, acc(train)=1.00e+00, error(valid)=8.14e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.27s to complete
#   error(train)=6.24e-03, acc(train)=1.00e+00, error(valid)=8.22e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 100: 1.59s to complete
#   error(train)=5.41e-03, acc(train)=1.00e+00, error(valid)=8.28e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=2.46e+00, acc(train)=1.14e-01, error(valid)=2.47e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 5: 1.46s to complete
#   error(train)=2.56e-01, acc(train)=9.26e-01, error(valid)=2.43e-01, acc(valid)=9.29e-01, params_penalty=0.00e+00
# Epoch 10: 1.39s to complete
#   error(train)=1.71e-01, acc(train)=9.51e-01, error(valid)=1.70e-01, acc(valid)=9.53e-01, params_penalty=0.00e+00
# Epoch 15: 1.27s to complete
#   error(train)=1.26e-01, acc(train)=9.64e-01, error(valid)=1.36e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 3.33s to complete
#   error(train)=9.60e-02, acc(train)=9.73e-01, error(valid)=1.12e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 25: 1.24s to complete
#   error(train)=7.44e-02, acc(train)=9.80e-01, error(valid)=1.00e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 30: 1.25s to complete
#   error(train)=6.26e-02, acc(train)=9.82e-01, error(valid)=9.61e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 35: 1.29s to complete
#   error(train)=5.17e-02, acc(train)=9.86e-01, error(valid)=8.89e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 1.23s to complete
#   error(train)=4.20e-02, acc(train)=9.89e-01, error(valid)=8.71e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 45: 1.55s to complete
#   error(train)=3.36e-02, acc(train)=9.92e-01, error(valid)=8.22e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 50: 1.35s to complete
#   error(train)=2.72e-02, acc(train)=9.95e-01, error(valid)=8.18e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 55: 1.45s to complete
#   error(train)=2.25e-02, acc(train)=9.96e-01, error(valid)=8.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 60: 1.20s to complete
#   error(train)=1.87e-02, acc(train)=9.97e-01, error(valid)=7.95e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 65: 1.41s to complete
#   error(train)=1.54e-02, acc(train)=9.98e-01, error(valid)=8.02e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 70: 1.21s to complete
#   error(train)=1.33e-02, acc(train)=9.98e-01, error(valid)=8.07e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 75: 1.20s to complete
#   error(train)=1.13e-02, acc(train)=9.99e-01, error(valid)=8.05e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 80: 1.30s to complete
#   error(train)=9.53e-03, acc(train)=9.99e-01, error(valid)=8.03e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 85: 1.22s to complete
#   error(train)=8.18e-03, acc(train)=9.99e-01, error(valid)=8.16e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 1.21s to complete
#   error(train)=7.15e-03, acc(train)=1.00e+00, error(valid)=8.24e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 95: 1.49s to complete
#   error(train)=6.12e-03, acc(train)=1.00e+00, error(valid)=8.20e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 100: 1.21s to complete
#   error(train)=5.61e-03, acc(train)=1.00e+00, error(valid)=8.25e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00

# %%
print "max training accuracy"
max([x['Final Training Accuracy'] for x in finalValuesCollection])
# Out:
# max training accuracy
# 0.99986000000000008

# %%
accuracies = [x['Final Testing Accuracy'] for x in finalValuesCollection]
accuracies
# Out:
# [0.97749999999999859,
#  0.97699999999999931,
#  0.97799999999999909,
#  0.97779999999999945,
#  0.9780999999999993,
#  0.97899999999999876,
#  0.97789999999999866,
#  0.97479999999999867,
#  0.97729999999999861,
#  0.9778999999999991]

# %%
fig = plt.figure()
plt.title('Final Testing Accuracies for various randomly initialized weights')
plt.plot(range(len(finalValuesCollection)), accuracies, 'b.-')
plt.xlabel('seed of random generator')
plt.ylabel('Final Testing Accuracy')
plt.show()
figcount += 1
fig.savefig('experiment3_%02d.svg' % figcount)
print "figcount: " + str(figcount)
# Out:
# figcount: 1

# %%
{
 "mean value of accuracies is": np.mean(accuracies),
 "max value of accuracies is": np.max(accuracies),
 "min value of accuracies is": np.min(accuracies)
}
# Out:
# {'max value of accuracies is': 0.97899999999999876,
#  'mean value of accuracies is': 0.97752999999999912,
#  'min value of accuracies is': 0.97479999999999867}

# %%
errors = [x['Final Testing Error'] for x in finalValuesCollection]
errors
# Out:
# [0.086800304070268411,
#  0.08691057637593945,
#  0.085977853703645121,
#  0.083804383497683335,
#  0.088716209473591837,
#  0.082767986087188133,
#  0.085635032442229295,
#  0.092384759482505838,
#  0.082788565764792821,
#  0.082530967717292694]

# %%
fig = plt.figure()
plt.title('Final Testing Errors for various randomly initialized weights')
plt.plot(range(len(finalValuesCollection)), errors, 'r.-')
plt.xlabel('seed of random generator')
plt.ylabel('Final Testing Error')
plt.show()
figcount += 1
fig.savefig('experiment3_%02d.svg' % figcount)
print "figcount: " + str(figcount)
# Out:
# figcount: 2

# %%
{
 "mean value of errors is": np.mean(errors),
 "max value of errors is": np.max(errors),
 "min value of errors is": np.min(errors)
}
# Out:
# {'max value of errors is': 0.092384759482505838,
#  'mean value of errors is': 0.08583166386151371,
#  'min value of errors is': 0.082530967717292694}

# %% [markdown]
# ### Pretraining with Linear Stacked AutoEncoder for 3 layers model

# %%
hiddenDims = np.array([100, 100, 10])
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=6.15e+01, acc(train)=7.60e-04, params_penalty=0.00e+00
# Epoch 5: 4.67s to complete
#   error(train)=2.32e+00, acc(train)=1.46e-02, params_penalty=0.00e+00
# Epoch 10: 5.30s to complete
#   error(train)=2.30e+00, acc(train)=1.42e-02, params_penalty=0.00e+00
# Epoch 15: 4.61s to complete
#   error(train)=2.33e+00, acc(train)=1.49e-02, params_penalty=0.00e+00
# Epoch 20: 3.75s to complete
#   error(train)=2.32e+00, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 25: 3.57s to complete
#   error(train)=2.29e+00, acc(train)=1.47e-02, params_penalty=0.00e+00
# Epoch 30: 3.87s to complete
#   error(train)=2.30e+00, acc(train)=1.51e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=6.01e+00, acc(train)=2.17e-02, params_penalty=0.00e+00
# Epoch 5: 0.78s to complete
#   error(train)=2.80e-30, acc(train)=1.00e+00, params_penalty=0.00e+00
# Epoch 10: 1.50s to complete
#   error(train)=1.56e-04, acc(train)=9.97e-01, params_penalty=0.00e+00
# Epoch 15: 0.76s to complete
#   error(train)=4.34e-04, acc(train)=9.93e-01, params_penalty=0.00e+00
# Epoch 20: 0.80s to complete
#   error(train)=3.30e-04, acc(train)=9.93e-01, params_penalty=0.00e+00
# Epoch 25: 1.02s to complete
#   error(train)=2.33e-04, acc(train)=9.95e-01, params_penalty=0.00e+00
# Epoch 30: 0.82s to complete
#   error(train)=4.16e-04, acc(train)=9.94e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.81e+00, acc(train)=9.96e-03, params_penalty=0.00e+00
# Epoch 5: 0.54s to complete
#   error(train)=1.72e+00, acc(train)=2.01e-01, params_penalty=0.00e+00
# Epoch 10: 1.03s to complete
#   error(train)=1.72e+00, acc(train)=2.02e-01, params_penalty=0.00e+00
# Epoch 15: 0.51s to complete
#   error(train)=1.72e+00, acc(train)=2.02e-01, params_penalty=0.00e+00
# Epoch 20: 0.55s to complete
#   error(train)=1.72e+00, acc(train)=2.02e-01, params_penalty=0.00e+00
# Epoch 25: 1.05s to complete
#   error(train)=1.72e+00, acc(train)=2.02e-01, params_penalty=0.00e+00
# Epoch 30: 0.56s to complete
#   error(train)=1.72e+00, acc(train)=2.01e-01, params_penalty=0.00e+00

# %%
reconstructedModel = MultipleLayerModel([
        model.layers[0],
        SigmoidLayer(),
        model.layers[1],
        SigmoidLayer(),
        model.layers[2]
    ])

# %%
# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(reconstructedModel,
                                  error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_3_layers_100_linear_pretraining_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_3_layers_100_linear_pretraining_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.32e+00, acc(train)=7.61e-02, error(valid)=2.32e+00, acc(valid)=6.54e-02, params_penalty=0.00e+00
# Epoch 5: 2.23s to complete
#   error(train)=2.91e-01, acc(train)=9.16e-01, error(valid)=2.72e-01, acc(valid)=9.23e-01, params_penalty=0.00e+00
# Epoch 10: 1.19s to complete
#   error(train)=1.85e-01, acc(train)=9.46e-01, error(valid)=1.78e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# Epoch 15: 1.38s to complete
#   error(train)=1.31e-01, acc(train)=9.62e-01, error(valid)=1.37e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 20: 1.57s to complete
#   error(train)=1.01e-01, acc(train)=9.71e-01, error(valid)=1.19e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 25: 1.56s to complete
#   error(train)=7.83e-02, acc(train)=9.78e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 30: 1.20s to complete
#   error(train)=6.35e-02, acc(train)=9.83e-01, error(valid)=9.62e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 35: 1.12s to complete
#   error(train)=5.26e-02, acc(train)=9.86e-01, error(valid)=9.06e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 40: 1.85s to complete
#   error(train)=4.36e-02, acc(train)=9.89e-01, error(valid)=8.91e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 1.26s to complete
#   error(train)=3.65e-02, acc(train)=9.91e-01, error(valid)=8.68e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 50: 1.48s to complete
#   error(train)=2.91e-02, acc(train)=9.93e-01, error(valid)=8.08e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 55: 1.19s to complete
#   error(train)=2.40e-02, acc(train)=9.95e-01, error(valid)=8.08e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 60: 1.18s to complete
#   error(train)=2.03e-02, acc(train)=9.96e-01, error(valid)=7.93e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 65: 2.24s to complete
#   error(train)=1.76e-02, acc(train)=9.97e-01, error(valid)=8.00e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 1.19s to complete
#   error(train)=1.46e-02, acc(train)=9.98e-01, error(valid)=8.26e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 1.57s to complete
#   error(train)=1.25e-02, acc(train)=9.99e-01, error(valid)=8.10e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 1.12s to complete
#   error(train)=1.07e-02, acc(train)=9.99e-01, error(valid)=8.36e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 85: 1.99s to complete
#   error(train)=8.92e-03, acc(train)=9.99e-01, error(valid)=8.20e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 90: 1.88s to complete
#   error(train)=7.89e-03, acc(train)=1.00e+00, error(valid)=8.40e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 1.19s to complete
#   error(train)=6.98e-03, acc(train)=1.00e+00, error(valid)=8.27e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 100: 1.12s to complete
#   error(train)=5.89e-03, acc(train)=1.00e+00, error(valid)=8.43e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# figcount: 3
# Run Time:
# 168.464905977
# {'Final Testing Accuracy': 0.977799999999999,
#  'Final Testing Error': 0.084256629397097479,
#  'Final Training Accuracy': 0.99974000000000007,
#  'Final Training Error': 0.0058863214910023351}

# %% [markdown]
# We have similar results as with the experiment with 2 layers. The final result seems not to be better than the random weights

# %% [markdown]
# ### Pretraining with Non Linear Stacked AutoEncoder for 3 layers model

# %%
hiddenDims = np.array([100, 100, 10])
model = constructModelFromPretrainedByAutoEncoderStack(hiddenDims, executeNonLinearAutoencoder)
# Out:
# Epoch 0:
#   error(train)=9.23e+01, acc(train)=3.00e-04, params_penalty=0.00e+00
# Epoch 5: 6.92s to complete
#   error(train)=4.06e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 10: 4.89s to complete
#   error(train)=2.13e+00, acc(train)=1.38e-02, params_penalty=0.00e+00
# Epoch 15: 6.51s to complete
#   error(train)=1.31e+00, acc(train)=1.44e-02, params_penalty=0.00e+00
# Epoch 20: 5.31s to complete
#   error(train)=1.10e+00, acc(train)=1.44e-02, params_penalty=0.00e+00
# Epoch 25: 4.99s to complete
#   error(train)=1.00e+00, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 30: 4.84s to complete
#   error(train)=9.43e-01, acc(train)=1.44e-02, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=3.80e+00, acc(train)=9.58e-03, params_penalty=0.00e+00
# Epoch 5: 2.21s to complete
#   error(train)=1.25e-01, acc(train)=4.20e-01, params_penalty=0.00e+00
# Epoch 10: 1.25s to complete
#   error(train)=5.35e-02, acc(train)=5.65e-01, params_penalty=0.00e+00
# Epoch 15: 1.25s to complete
#   error(train)=4.20e-02, acc(train)=6.22e-01, params_penalty=0.00e+00
# Epoch 20: 1.56s to complete
#   error(train)=3.66e-02, acc(train)=6.53e-01, params_penalty=0.00e+00
# Epoch 25: 1.19s to complete
#   error(train)=3.31e-02, acc(train)=6.74e-01, params_penalty=0.00e+00
# Epoch 30: 2.28s to complete
#   error(train)=3.11e-02, acc(train)=6.95e-01, params_penalty=0.00e+00
# Epoch 0:
#   error(train)=1.31e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 5: 0.99s to complete
#   error(train)=9.57e-01, acc(train)=4.16e-02, params_penalty=0.00e+00
# Epoch 10: 0.93s to complete
#   error(train)=9.40e-01, acc(train)=4.31e-02, params_penalty=0.00e+00
# Epoch 15: 1.88s to complete
#   error(train)=9.36e-01, acc(train)=4.17e-02, params_penalty=0.00e+00
# Epoch 20: 0.99s to complete
#   error(train)=9.35e-01, acc(train)=4.25e-02, params_penalty=0.00e+00
# Epoch 25: 1.46s to complete
#   error(train)=9.34e-01, acc(train)=4.37e-02, params_penalty=0.00e+00
# Epoch 30: 1.03s to complete
#   error(train)=9.34e-01, acc(train)=4.34e-02, params_penalty=0.00e+00

# %%
reconstructedModel = MultipleLayerModel(model.layers[:-1])

# %%
# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

learning_rate = 1e-1
learningRule = GradientDescentLearningRule(learning_rate=learning_rate)

stats, keys, runTime = trainModel(reconstructedModel,
                                  error, learningRule, trainData, validData, num_epochs, statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, statsInterval)
figcount += 1
fig_1.savefig('experiment3_%02d_3_layers_100_nonlinear_pretraining_fig1.svg' % figcount)
fig_2.savefig('experiment3_%02d_3_layers_100_nonlinear_pretraining_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "Run Time:"
print runTime

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.39e+00, acc(train)=1.47e-01, error(valid)=2.39e+00, acc(valid)=1.48e-01, params_penalty=0.00e+00
# Epoch 5: 1.75s to complete
#   error(train)=2.17e-01, acc(train)=9.36e-01, error(valid)=2.10e-01, acc(valid)=9.41e-01, params_penalty=0.00e+00
# Epoch 10: 1.19s to complete
#   error(train)=1.45e-01, acc(train)=9.58e-01, error(valid)=1.50e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# Epoch 15: 1.47s to complete
#   error(train)=1.08e-01, acc(train)=9.70e-01, error(valid)=1.26e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# Epoch 20: 2.23s to complete
#   error(train)=8.15e-02, acc(train)=9.77e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 1.18s to complete
#   error(train)=6.46e-02, acc(train)=9.83e-01, error(valid)=1.01e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 30: 1.24s to complete
#   error(train)=5.25e-02, acc(train)=9.86e-01, error(valid)=9.73e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 35: 2.23s to complete
#   error(train)=4.31e-02, acc(train)=9.89e-01, error(valid)=9.47e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 1.19s to complete
#   error(train)=3.55e-02, acc(train)=9.92e-01, error(valid)=9.21e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 1.12s to complete
#   error(train)=2.94e-02, acc(train)=9.94e-01, error(valid)=9.26e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 1.93s to complete
#   error(train)=2.51e-02, acc(train)=9.95e-01, error(valid)=9.17e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 1.19s to complete
#   error(train)=2.02e-02, acc(train)=9.97e-01, error(valid)=9.10e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 1.26s to complete
#   error(train)=1.71e-02, acc(train)=9.98e-01, error(valid)=9.20e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 65: 1.23s to complete
#   error(train)=1.44e-02, acc(train)=9.98e-01, error(valid)=9.15e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 70: 1.22s to complete
#   error(train)=1.31e-02, acc(train)=9.99e-01, error(valid)=9.33e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 75: 1.17s to complete
#   error(train)=1.08e-02, acc(train)=9.99e-01, error(valid)=9.45e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 80: 1.12s to complete
#   error(train)=9.26e-03, acc(train)=9.99e-01, error(valid)=9.39e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 85: 2.26s to complete
#   error(train)=8.05e-03, acc(train)=1.00e+00, error(valid)=9.50e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 90: 1.19s to complete
#   error(train)=7.26e-03, acc(train)=1.00e+00, error(valid)=9.69e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 95: 1.39s to complete
#   error(train)=6.34e-03, acc(train)=1.00e+00, error(valid)=9.66e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 100: 1.74s to complete
#   error(train)=5.59e-03, acc(train)=1.00e+00, error(valid)=9.76e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# figcount: 4
# Run Time:
# 163.474694967
# {'Final Testing Accuracy': 0.97539999999999893,
#  'Final Testing Error': 0.09755379924948486,
#  'Final Training Accuracy': 0.9998800000000001,
#  'Final Training Error': 0.0055896778343472566}

# %% [markdown]
# We have similar results as with the experiment with 2 layers. The final result seems not to be better than the random weights
