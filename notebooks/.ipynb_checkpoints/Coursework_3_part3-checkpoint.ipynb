# %% [markdown]
# ## Genre classification with the Million Song Dataset
#
# The [Million Song Dataset](http://labrosa.ee.columbia.edu/millionsong/) is a
#
# >  freely-available collection of audio features and metadata for a million contemporary popular music tracks
#
# originally collected and compiled by Thierry Bertin-Mahieux, Daniel P.W. Ellis, Brian Whitman, and Paul Lamere.
#
# The dataset is intended to encourage development of algorithms in the field of [music information retrieval](https://en.wikipedia.org/wiki/Music_information_retrieval). The [data for each track](http://labrosa.ee.columbia.edu/millionsong/pages/example-track-description) includes both textual features such as artist and album names, numerical descriptors such as duration and various audio features derived using a music analysis platform provided by [The Echo Nest](https://en.wikipedia.org/wiki/The_Echo_Nest) (since acquired by Spotify). Of the various audio features and segmentations included in the full dataset, the most detailed information is included at a 'segment' level: each segment corresponds to an automatically identified 'quasi-stable music event' - roughly contiguous sections of the audio with similar perceptual quality. The number of segments per track is variable and each segment can itself be of variable length - typically they seem to be around 0.2 - 0.4 seconds but can be as long as 10 seconds or more.
#
# For each segment of the track various extracted audio features are available - a 12 dimensional vector of [chroma features](https://en.wikipedia.org/wiki/Chroma_feature), a 12 dimensional vector of ['MFCC-like'](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum) timbre features and various measures of the loudness of the segment, including loudness at the segment start and maximum loudness.
#
# #### EACH SEGMENT IS REPRESENTED BY THIS:
# In the version of the data we provide, we include a 25 dimensional vector for each included segment, consisting of the 12 timbre features, 12 chroma features and loudness at start of segment concatenated in that order.
#
# #### FEEDFORWARD
# To allow easier integration in to standard feedforward models, the basic version of the data we provide includes features only for a fixed length crop of the central 120 segments of each track (with tracks with less than 120 segments therefore not being included).
# This gives an overall input dimension per track of 120×25=3000.
#
# #### ALREADY NORMALIZED
# Each of the 3000 input dimensions has been been preprocessed by subtracting the per-dimension mean across the training data and dividing by the per-dimension standard deviation across the training data.
#
# We provide data providers for the fixed length crops versions of the input features, with the inputs being returned in batches of 3000 dimensional vectors (these can be reshaped to (120, 25) to get the per-segment features). To allow for more complex variable-length sequence modelling with for example recurrent neural networks, we also provide a variable length version of the data. This is only provided as compressed NumPy (`.npz`) data files rather than data provider objects - you will need to write your own data provider if you wish to use this version of the data. As the inputs are of variable number of segments they have been ['bucketed'](https://www.tensorflow.org/tutorials/seq2seq/#bucketing_and_padding) into groups of similar maximum length, with the following binning scheme used:
#
#      120 - 250  segments
#      251 - 500  segments
#      501 - 650  segments
#      651 - 800  segments
#      801 - 950  segments
#      951 - 1200 segments
#     1201 - 2000 segments
#     2000 - 4000 segments
#
# For each bucket the NumPy data files include inputs and targets arrays with second dimension equal to the maximum segment size in the bucket (e.g. 250 for the bucket) and first dimension equal to the number of tracks with number of segments in that bucket. These are named `inputs_{n}` and `targets_{n}` in the data file where `{n}` is the maximal number of segments in the bucket e.g. `inputs_250` and `targets_250` for the first bucket. For tracks with less segments than the maximum size in the bucket, the features for the track have been padded with `NaN` values. For tracks with more segments than the maximum bucket size of 4000, only the first 4000 segments have been included.
#
# To allow you to match tracks between the fixed length and variable length datasets, the data files also include an array for each bucket giving the indices of the corresponding track in the fixed length input arrays. For example the array `indices_250` will be an array of the same size as the first dimension of `inputs_250` and `targets_250` with the first element of `indices_250` giving the index into the `inputs` and `targets` array of the fixed length data corresponding to first element of `inputs_250` and `targets_250`.
#
# The Million Song Dataset in its original form does not provide any genre labels, however various external groups have proposed genre labels for portions of the data by cross-referencing the track IDs against external music tagging databases. Analagously to the provision of both simpler and more complex classifications tasks for the CIFAR-10 / CIFAR-100 datasets, we provide two classification task datasets derived from the Million Song Dataset - one with 10 coarser level genre classes, and another with 25 finer-grained genre / style classifications.
#
# The 10-genre classification task uses the [*CD2C tagtraum genre annotations*](http://www.tagtraum.com/msd_genre_datasets.html) derived from multiple source databases (beaTunes genre dataset, Last.fm dataset, Top-MAGD dataset), with the *CD2C* variant using only non-ambiguous annotations (i.e. not including tracks with multiple genre labels). Of the 15 genre labels provided in the CD2C annotations, 5 (World, Latin, Punk, Folk and New Age) were not included due to having fewer than 5000 examples available. This left 10 remaining genre classes:
#
#     Rap
#     Rock
#     RnB
#     Electronic
#     Metal
#     Blues
#     Pop
#     Jazz
#     Country
#     Reggae
#
# For each of these 10 classes, 5000 labelled examples have been collected for training / validation (i.e. 50000 example in total) and a further 1000 example per class for testing, with the exception of the `Blues` class for which only 991 testing examples are provided due to there being insufficient labelled tracks of the minimum required length (i.e. a total of 9991 test examples).
#
# The 9991 test set examples have labels provided: however to avoid any accidental over-fitting to the test set **you should only use these for the final evaluation of your model(s)**. If you repeatedly evaluate models on the test set during model development it is easy to end up indirectly fitting to the test labels - for those who have not already read it see this [excellent cautionary note int the MLPR notes by Iain Murray](http://www.inf.ed.ac.uk/teaching/courses/mlpr/2016/notes/w2a_train_test_val.html#warning-dont-fool-yourself-or-make-a-fool-of-yourself).
#
#
# The 25-genre classification tasks uses the [*MSD Allmusic Style Dataset*](http://www.ifs.tuwien.ac.at/mir/msd/MASD.html) labels derived from the [AllMusic.com](http://www.allmusic.com/) database by [Alexander Schindler, Rudolf Mayer and Andreas Rauber of Vienna University of Technology](http://www.ifs.tuwien.ac.at/~schindler/pubs/ISMIR2012.pdf). The 25 genre / style labels used are:
#
#     Big Band
#     Blues Contemporary
#     Country Traditional
#     Dance
#     Electronica
#     Experimental
#     Folk International
#     Gospel
#     Grunge Emo
#     Hip Hop Rap
#     Jazz Classic
#     Metal Alternative
#     Metal Death
#     Metal Heavy
#     Pop Contemporary
#     Pop Indie
#     Pop Latin
#     Punk
#     Reggae
#     RnB Soul
#     Rock Alternative
#     Rock College
#     Rock Contemporary
#     Rock Hard
#     Rock Neo Psychedelia
#
# For each of these 25 classes, 2000 labelled examples have been collected for training / validation (i.e. 50000 example in total). A further 400 example per class have been collected for testing (i.e. 10000 examples in total), which you are provided inputs but not targets for. The optional Kaggle competition being run for this dataset (see email) is scored based on the 25-genre class label predictions on these unlabelled test inputs.
#
# The tracks used for the 25-genre classification task only partially overlap with those used for the 10-genre classification task and we do not provide any mapping between the two.
#
# For each of the two tasks, the 50000 examples collected for training have been pre-split in to a 40000 example training dataset and a 10000 example validation dataset. If you wish to use a more complex cross-fold validation scheme you may want to combine these two portions of the dataset and define your own functions / classes for separating out a validation set.
#
# Data provider classes for both fixed length input data for the 10 and 25 genre classification tasks in the `mlp.data_providers` module as `MSD10GenreDataProvider` and `MSD25GenreDataProvider`. Both have similar behaviour to the `MNISTDataProvider` used extensively last semester. A `which_set` argument can be used to specify whether to return a data provided for the training dataset (`which_set='train'`) or validation dataset (`which_set='valid'`).  Both data provider classes provide a `label_map` attribute which is a list of strings which are the class labels corresponding to the integer targets (i.e. prior to conversion to a 1-of-K encoded binary vector).
#
# The test dataset files for the 10 genre classification task are provided as two separate NumPy data files `msd-10-genre-test-inputs.npz` and `msd-10-genre-test-targets.npz`. These can be loaded using [`np.load`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.load.html) function. The inputs are stored as a $10000\times3000$ array under the key `inputs` in the file `msd-10-genre-test-inputs.npz` and the targets in a 10000 element array of integer labels under the key `targets` in `msd-10-genre-test-targets.npz`. A corresponding `msd-25-genre-test-inputs.npz` file is provided for the 25 genre task inputs.

# %% [markdown]
# ### Accessing the Million Song Dataset data
#
# Before using the data provider objects you will need to make sure the data files are accessible to the `mlp` package by existing under the directory specified by the `MLP_DATA_DIR` path.
#
# The fixed length input data and associated targets is available as compressed NumPy `.npz` files
#
#     msd-10-genre-train.npz          210MB
#     msd-10-genre-valid.npz           53MB
#     msd-10-genre-test-inputs.npz     53MB
#     msd-10-genre-test-targets.npz   5.2KB
#     msd-25-genre-train.npz          210MB
#     msd-25-genre-valid.npz           53MB
#     msd-25-genre-test-inputs.npz     53MB
#
# in the AFS directory `/afs/inf.ed.ac.uk/group/teaching/mlp/data`.
#
# If you are working on DICE one option is to redefine your `MLP_DATA_DIR` to directly point to the shared AFS data directory by editing the `env_vars.sh` start up file for your environment. This will avoid using up your DICE quota by storing the data files in your homespace but may involve slower initial loading of the data on initialising the data providers if many people are trying access the same files at once. The environment variable can be redefined by running
#
# ```
# gedit ~/miniconda2/envs/mlp/etc/conda/activate.d/env_vars.sh
# ```
#
# in a terminal window (assuming you installed `miniconda2` to your home directory), and changing the line
#
# ```
# export MLP_DATA_DIR=$HOME/mlpractical/data
# ```
#
# to
#
# ```
# export MLP_DATA_DIR="/afs/inf.ed.ac.uk/group/teaching/mlp/data"
# ```
#
# and then saving and closing the editor. You will need reload the `mlp` environment using `source activate mlp` and restart the Jupyter notebook server in the reloaded environment for the new environment variable definition to be available.
#
# For those working on DICE who have sufficient quota remaining or those using there own machine, an alternative option is to copy the data files in to your local `mlp/data` directory (or wherever your `MLP_DATA_DIR` environment variable currently points to if different).
#
#
# Assuming your local `mlpractical` repository is in your home directory you should be able to copy the required files on DICE by running
#
# ```
# cp /afs/inf.ed.ac.uk/group/teaching/mlp/data/msd-*-train.npz ~/mlpractical/data
# cp /afs/inf.ed.ac.uk/group/teaching/mlp/data/msd-*-valid.npz ~/mlpractical/data
# cp /afs/inf.ed.ac.uk/group/teaching/mlp/data/msd-*-test-*.npz ~/mlpractical/data
# ```
#
# On a non-DICE machine, you will need to either [set up local access to AFS](http://computing.help.inf.ed.ac.uk/informatics-filesystem), use a remote file transfer client like `scp` or you can alternatively download the files using the iFile web interface [here](https://ifile.inf.ed.ac.uk/?path=%2Fafs%2Finf.ed.ac.uk%2Fgroup%2Fteaching%2Fmlp%2Fdata&goChange=Go) (requires DICE credentials).
#
# As some of the files are quite large you may wish to copy only those you are using (e.g. only the files for one of the two tasks) to your local filespace to avoid filling up your quota. The `msd-25-genre-test-inputs.npz` files will only be needed by those intending to enter the associated optional Kaggle competition.
#
# In addition to the fixed length input files there are also corresponding files with the variable length input data in the same AFS directory
#
#     msd-10-genre-train-var-length.npz          1.6GB
#     msd-10-genre-valid-var-length.npz          403MB
#     msd-10-genre-test-inputs-var-length.npz    403MB
#     msd-10-genre-test-targets-var-length.npz   3.1KB
#     msd-25-genre-train-var-length.npz          1.5GB
#     msd-25-genre-valid-var-length.npz          367MB
#     msd-25-genre-test-inputs-var-length.npz    363MB
#
# As you can see some of these files, particularly the training sets, are very large so you will need to be careful if copying to your filespace to make sure you have sufficient quota available.

# %% [markdown]
# ### Imports, Inits, and helper functions

# %%
import sys
mlpdir = '/home/student/Dropbox/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical'
sys.path.append(mlpdir)

# %%
from mylibs.jupyter_notebook_helper import show_graph
import datetime
import os
import time
import tensorflow as tf
import numpy as np
from mlp.data_providers import MSD10GenreDataProvider, MSD25GenreDataProvider, MSD10Genre_Autoencoder_DataProvider,\
    MSD10Genre_StackedAutoEncoderDataProvider
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seed = 16011984
rng = np.random.RandomState(seed=seed)

# %%
config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)
config.gpu_options.allow_growth = True

# %%
figcount = 0

# %%
tensorboardLogdir = 'tf_cw3_3'

# %%
def getRunTime(function): #a = lambda _ = None : 3
    run_start_time = time.time()
    result = function()
    run_time = time.time() - run_start_time
    return result, run_time

# %%
def getNewSessionInitialized(graph=tf.get_default_graph()):
    #with graph.as_default():
    sess = tf.InteractiveSession(graph=graph)
    #sess = tf.Session(graph=graph)
    sess.run(tf.global_variables_initializer())
        
    return sess

# %%
def getWriter(key, graph):
    #tensorboard --logdir=...
    folder = tensorboardLogdir

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    return tf.summary.FileWriter(
        logdir=os.path.join(folder, timestamp, key),
        graph=graph
    )

# %%
def getTrainWriter():
    return getWriter('train', tf.get_default_graph())

# %%
def getValidWriter():
    return getWriter('valid', tf.get_default_graph())

# %%
def plotStats(stats, keys, stats_interval):
    # Plot the change in the validation and training set error over training.
    
    #stats[0:, keys[k]] #0 epoch number
    #stats[1:, keys[k]] #1 for training and validation
    #keys is from string to index
    #stats shape is [epochs, 4]
    
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return fig_1, ax_1, fig_2, ax_2

# %%
def fully_connected_layer(inputs, input_dim, output_dim, nonlinearity=tf.nn.relu, avoidDeadNeurons=0.,
                          w=None, b=None):
    weights = tf.Variable(
        tf.truncated_normal([input_dim, output_dim], stddev=2. / (input_dim + output_dim)**0.5) if w is None else w,
            'weights'
    )
    
    biases = tf.Variable(avoidDeadNeurons * tf.ones([output_dim]) if b is None else b, 'biases')
    outputs = nonlinearity(tf.matmul(inputs, weights) + biases)
    return outputs

# %%
def tfRMSE(outputs, targets):
    return tf.sqrt(tf.reduce_mean(tf.square(tf.sub(targets, outputs))))

# %%
def tfMSE(outputs, targets):
    return tf.reduce_mean(tf.square(tf.sub(targets, outputs)))

# %%
def initStats():
    stats = np.zeros( (epochs,4) )
    
    keys = {
        'error(train)': 0,
        'acc(train)': 1,
        'error(valid)': 2,
        'acc(valid)': 3
    }

    return stats, keys

# %%
def gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy):
    stats[e, 0] = train_error
    stats[e, 1] = train_accuracy
    stats[e, 2] = valid_error
    stats[e, 3] = valid_accuracy

# %%
def merge_dicts(*dict_args):
    """
    Given any number of dicts, shallow copy and merge into a new dict,
    precedence goes to key value pairs in latter dicts.
    """
    result = {}
    for dictionary in dict_args:
        result.update(dictionary)
    return result

# %%
curDtype = tf.float32

# %%
reluBias = 0.1

# %% [markdown]
# ### MSD 10 genre task

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %% [markdown]
# ### Larger dimensionality helps?

# %%
hidden_dims = [500, 500, 500, 500]
#tf.reset_default_graph() #kind of redundant statement
learningRate = 1e-4

graph = tf.Graph() #create new graph

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    

    with tf.name_scope('fullyConnected_1'):
        hidden_1 = fully_connected_layer(inputs, train_data.inputs.shape[1], hidden_dims[0], avoidDeadNeurons=reluBias)
    
    with tf.name_scope('fullyConnected_2'):
        hidden_2 = fully_connected_layer(hidden_1, hidden_dims[0], hidden_dims[1], avoidDeadNeurons=reluBias)
        
    with tf.name_scope('fullyConnected_3'):
        hidden_3 = fully_connected_layer(hidden_2, hidden_dims[1], hidden_dims[2], avoidDeadNeurons=reluBias)
        
    with tf.name_scope('fullyConnected_4'):
        hidden_4 = fully_connected_layer(hidden_3, hidden_dims[2], hidden_dims[3], avoidDeadNeurons=reluBias)
        

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_4, hidden_dims[3], train_data.num_classes, nonlinearity=tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)

    init = tf.global_variables_initializer()

#     tf.summary.scalar('error', error)
#     tf.summary.scalar('accuracy', accuracy)
#     summary_op = tf.summary.merge_all()

# %%
#show_graph(tf.get_default_graph())
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_20-24-34&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\270\\013\\000\\000\\364\\001\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0338061712682\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;fullyConnected_1/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;fullyConnected_1/truncated_normal/TruncatedNormal&quot;\n  input: &quot;fullyConnected_1/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;fullyConnected_1/truncated_normal/mul&quot;\n  input: &quot;fullyConnected_1/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/Variable&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 3000\n        }\n        dim {\n          size: 500\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected_1/Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;fullyConnected_1/Variable&quot;\n  input: &quot;fullyConnected_1/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@fullyConnected_1/Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnecte ...

# %%
# train_writer = getTrainWriter()
# valid_writer = getValidWriter()

# %%
def trainEpoch():
    train_error = 0.
    train_accuracy = 0.
    
    for step, (input_batch, target_batch) in enumerate(train_data):
#         _, batch_error, batch_acc, summary = sess.run(
#             [train_step, error, accuracy, summary_op],
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict={inputs: input_batch, targets: target_batch}
        )
        
        train_error += batch_error
        train_accuracy += batch_acc
        
        #train_writer.add_summary(summary, global_step= e * train_data.num_batches + step)
    
    train_error /= train_data.num_batches
    
    train_accuracy /= train_data.num_batches
    
    return train_error, train_accuracy

# %%
epochs = 20

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()
    valid_error = 0.
    valid_accuracy = 0.

    for e in range(epochs):    
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: trainEpoch())

        print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)

        if (e + 1) % 2 == 0:
            valid_error = 0.
            valid_accuracy = 0.
            for step, (input_batch, target_batch) in enumerate(valid_data):
#                 batch_error, batch_acc, summary = sess.run(
#                     [error, accuracy, summary_op],
                batch_error, batch_acc = sess.run(
                    [error, accuracy], 
                    feed_dict={inputs: input_batch, targets: target_batch})
                valid_error += batch_error
                valid_accuracy += batch_acc

                #valid_writer.add_summary(summary, global_step= e * valid_data.num_batches + step)

            valid_error /= valid_data.num_batches
            valid_accuracy /= valid_data.num_batches

            print((' ' * 27) + 'err(valid)={0:.2f} acc(valid)={1:.2f}'.format(valid_error, valid_accuracy))


        gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy)
            
# train_writer.flush()
# valid_writer.flush()

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (14.683 secs): err(train)=1.72 acc(train)=0.39
# End epoch 02 (13.960 secs): err(train)=1.28 acc(train)=0.56
#                            err(valid)=1.59 acc(valid)=0.44
# End epoch 03 (14.397 secs): err(train)=0.93 acc(train)=0.70
# End epoch 04 (14.538 secs): err(train)=0.55 acc(train)=0.84
#                            err(valid)=1.90 acc(valid)=0.42
# End epoch 05 (13.983 secs): err(train)=0.24 acc(train)=0.95
# End epoch 06 (13.789 secs): err(train)=0.08 acc(train)=0.99
#                            err(valid)=2.59 acc(valid)=0.41
# End epoch 07 (14.074 secs): err(train)=0.03 acc(train)=1.00
# End epoch 08 (14.294 secs): err(train)=0.01 acc(train)=1.00
#                            err(valid)=3.28 acc(valid)=0.42
# End epoch 09 (13.638 secs): err(train)=0.00 acc(train)=1.00
# End epoch 10 (13.598 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=3.81 acc(valid)=0.42
# End epoch 11 (13.530 secs): err(train)=0.00 acc(train)=1.00
# End epoch 12 (13.558 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=4.22 acc(valid)=0.42
# End epoch 13 (13.616 secs): err(train)=0.00 acc(train)=1.00
# End epoch 14 (13.592 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=4.64 acc(valid)=0.42
# End epoch 15 (13.572 secs): err(train)=0.00 acc(train)=1.00
# End epoch 16 (13.600 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=5.06 acc(valid)=0.42
# End epoch 17 (13.532 secs): err(train)=0.00 acc(train)=1.00
# End epoch 18 (13.552 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=5.47 acc(valid)=0.42
# End epoch 19 (13.536 secs): err(train)=0.00 acc(train)=1.00
# End epoch 20 (13.762 secs): err(train)=0.00 acc(train)=1.00
#                            err(valid)=5.88 acc(valid)=0.42

# %% [markdown]
# #### Conclusion
# Even though we have introduced a smaller learning rate we still get high overfitting effects, so no real conclusion can be derived until we amend the overfitting effect

# %% [markdown]
# ### Five Layer with 500 Hidden Dimensionality can be regularized with Dropout at inputs and readout layer?

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %%
hidden_dims = [500, 500, 500, 500]
learningRate = 1e-4

tf.reset_default_graph() #kind of redundant statement

graph = tf.Graph() #create new graph

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    
    
    with tf.name_scope("regularization0"):
        keep_prob_0 = tf.placeholder(curDtype)
        inputs_prob = tf.nn.dropout(inputs, keep_prob_0)
        
    with tf.name_scope('fullyConnected_1'):
        hidden_1 = fully_connected_layer(inputs_prob, train_data.inputs.shape[1], hidden_dims[0], avoidDeadNeurons=reluBias)
        
    
    with tf.name_scope('fullyConnected_2'):
        hidden_2 = fully_connected_layer(hidden_1, hidden_dims[0], hidden_dims[1], avoidDeadNeurons=reluBias)
        
    with tf.name_scope('fullyConnected_3'):
        hidden_3 = fully_connected_layer(hidden_2, hidden_dims[1], hidden_dims[2], avoidDeadNeurons=reluBias)
        
    with tf.name_scope('fullyConnected_4'):
        hidden_4 = fully_connected_layer(hidden_3, hidden_dims[2], hidden_dims[3], avoidDeadNeurons=reluBias)

        
    with tf.name_scope("regularization4"):
        keep_prob_4 = tf.placeholder(curDtype)
        hidden_4_prob = tf.nn.dropout(hidden_4, keep_prob_4)

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_4_prob, hidden_dims[3], train_data.num_classes, nonlinearity=tf.identity)

        
    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)

    init = tf.global_variables_initializer()

#     tf.summary.scalar('error', error)
#     tf.summary.scalar('accuracy', accuracy)
#     summary_op = tf.summary.merge_all()

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_20-24-48&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;inputs&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;regularization0/dropout/Shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;regularization0/dropout/random_uniform/max&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  input: &quot;regularization0/dropout/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/dropout/random_uniform/mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/add&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  input: &quot;regularization0/dropout/random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Floor&quot;\n  op: &quot;Floor&quot;\n  input: &quot;regularization0/dropout/add&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Div&quot;\n  op: &quot;Div&quot;\n  input: &quot;inputs&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name:  ...

# %%
def trainEpoch(e, train_data, train_step, error, accuracy, extraFeedDict):
    train_error = 0.
    train_accuracy = 0.
    
    num_batches = train_data.num_batches
    
    for step, (input_batch, target_batch) in enumerate(train_data):
        _, batch_error, batch_acc = sess.run(
            [train_step, error, accuracy], 
            feed_dict= merge_dicts({inputs: input_batch, targets: target_batch}, extraFeedDict)
        )
        
        train_error += batch_error
        train_accuracy += batch_acc
    
    train_error /= num_batches
    
    train_accuracy /= num_batches
    
    return train_error, train_accuracy

# %%
def validateEpoch(e, valid_data, error, accuracy, keep_prob_keys = []):
    valid_error = 0.
    valid_accuracy = 0.
    
    num_batches = valid_data.num_batches
    
    validationKeepProbability = 1. #it is always 100% for validation
    
    keep_prob_dict = dict()
    
    for keep_prob_key in keep_prob_keys:
        keep_prob_dict[keep_prob_key] = validationKeepProbability

    for step, (input_batch, target_batch) in enumerate(valid_data):
        batch_error, batch_acc = sess.run(
            [error, accuracy], 
            feed_dict= merge_dicts({inputs: input_batch, targets: target_batch}, keep_prob_dict)
        )
            
        valid_error += batch_error
        valid_accuracy += batch_acc

    valid_error /= valid_data.num_batches
    valid_accuracy /= valid_data.num_batches
    
    return valid_error, valid_accuracy

# %%
epochs = 20

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()

    for e in range(epochs):
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: 
                trainEpoch(e, train_data, train_step, error, accuracy,
                    extraFeedDict= {
                        keep_prob_0: 0.9,
                        keep_prob_4: 0.5
                    }
            ))

        print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)

        if (e + 1) % 2 == 0:
            valid_error, valid_accuracy = validateEpoch(e, valid_data, error, accuracy, [keep_prob_0, keep_prob_4])

            print((' ' * 27) + 'err(valid)={0:.2f} acc(valid)={1:.2f}'.format(valid_error, valid_accuracy))


        gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (14.839 secs): err(train)=1.94 acc(train)=0.33
# End epoch 02 (14.489 secs): err(train)=1.58 acc(train)=0.44
#                            err(valid)=1.53 acc(valid)=0.46
# End epoch 03 (14.530 secs): err(train)=1.43 acc(train)=0.49
# End epoch 04 (14.467 secs): err(train)=1.29 acc(train)=0.55
#                            err(valid)=1.51 acc(valid)=0.47
# End epoch 05 (14.476 secs): err(train)=1.15 acc(train)=0.60
# End epoch 06 (14.421 secs): err(train)=0.99 acc(train)=0.66
#                            err(valid)=1.61 acc(valid)=0.46
# End epoch 07 (14.481 secs): err(train)=0.82 acc(train)=0.72
# End epoch 08 (14.435 secs): err(train)=0.65 acc(train)=0.77
#                            err(valid)=1.84 acc(valid)=0.45
# End epoch 09 (14.575 secs): err(train)=0.50 acc(train)=0.83
# End epoch 10 (14.425 secs): err(train)=0.39 acc(train)=0.87
#                            err(valid)=2.24 acc(valid)=0.45
# End epoch 11 (14.459 secs): err(train)=0.30 acc(train)=0.90
# End epoch 12 (14.408 secs): err(train)=0.22 acc(train)=0.92
#                            err(valid)=2.64 acc(valid)=0.44
# End epoch 13 (14.502 secs): err(train)=0.18 acc(train)=0.94
# End epoch 14 (14.519 secs): err(train)=0.15 acc(train)=0.95
#                            err(valid)=2.99 acc(valid)=0.44
# End epoch 15 (14.523 secs): err(train)=0.14 acc(train)=0.96
# End epoch 16 (14.481 secs): err(train)=0.12 acc(train)=0.96
#                            err(valid)=3.30 acc(valid)=0.44
# End epoch 17 (14.580 secs): err(train)=0.11 acc(train)=0.96
# End epoch 18 (14.437 secs): err(train)=0.10 acc(train)=0.97
#                            err(valid)=3.36 acc(valid)=0.44
# End epoch 19 (14.477 secs): err(train)=0.09 acc(train)=0.97
# End epoch 20 (14.414 secs): err(train)=0.08 acc(train)=0.97
#                            err(valid)=3.53 acc(valid)=0.44

# %% [markdown]
# #### Conclusion
# Regularization has not worked. We are still experiencing severe overfitting.
#
# We will increase the learning rate to default and also use dropout for all layers

# %% [markdown]
# ### Five Layer with 500 Hidden Dimensionality can be regularized with Dropout at all layers?

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %%
hidden_dims = [500, 500, 500, 500]
learningRate = 1e-3
keep_probs = []

tf.reset_default_graph() #kind of redundant statement

graph = tf.Graph() #create new graph

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    
    
    with tf.name_scope("regularization0"):
        keep_probs.append( tf.placeholder(curDtype) )
        inputs_prob = tf.nn.dropout(inputs, keep_probs[0])
        
    with tf.name_scope('fullyConnected_1'):
        hidden_1 = fully_connected_layer(inputs_prob, train_data.inputs.shape[1], hidden_dims[0], avoidDeadNeurons=reluBias)
        
        
    with tf.name_scope("regularization1"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_1_prob = tf.nn.dropout(hidden_1, keep_probs[1])
    
    with tf.name_scope('fullyConnected_2'):
        hidden_2 = fully_connected_layer(hidden_1_prob, hidden_dims[0], hidden_dims[1], avoidDeadNeurons=reluBias)
        
    
    with tf.name_scope("regularization2"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_2_prob = tf.nn.dropout(hidden_2, keep_probs[2])
        
    with tf.name_scope('fullyConnected_3'):
        hidden_3 = fully_connected_layer(hidden_2_prob, hidden_dims[1], hidden_dims[2], avoidDeadNeurons=reluBias)
        
    
    with tf.name_scope("regularization3"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_3_prob = tf.nn.dropout(hidden_3, keep_probs[3])
        
    with tf.name_scope('fullyConnected_4'):
        hidden_4 = fully_connected_layer(hidden_3_prob, hidden_dims[2], hidden_dims[3], avoidDeadNeurons=reluBias)

        
    with tf.name_scope("regularization4"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_4_prob = tf.nn.dropout(hidden_4, keep_probs[4])

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_4_prob, hidden_dims[3], train_data.num_classes, nonlinearity=tf.identity)

        
    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)

    init = tf.global_variables_initializer()

#     tf.summary.scalar('error', error)
#     tf.summary.scalar('accuracy', accuracy)
#     summary_op = tf.summary.merge_all()

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_20-48-00&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;inputs&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;regularization0/dropout/Shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;regularization0/dropout/random_uniform/max&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  input: &quot;regularization0/dropout/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/dropout/random_uniform/mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/add&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  input: &quot;regularization0/dropout/random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Floor&quot;\n  op: &quot;Floor&quot;\n  input: &quot;regularization0/dropout/add&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Div&quot;\n  op: &quot;Div&quot;\n  input: &quot;inputs&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name:  ...

# %%
# %%time

epochs = 40

keep_prob_values = [0.9, 0.6, 0.6, 0.6, 0.6]

assert len(keep_probs) == len(keep_prob_values)

keep_prob_dict = dict()
for i, keep_prob_key in enumerate(keep_probs):
    keep_prob_dict[keep_prob_key] = keep_prob_values[i]

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()

    for e in range(epochs):
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: 
                trainEpoch(e, train_data, train_step, error, accuracy,
                    extraFeedDict= keep_prob_dict
            ))

        print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)

        if (e + 1) % 2 == 0:
            valid_error, valid_accuracy = validateEpoch(e, valid_data, error, accuracy, keep_probs)

            print((' ' * 27) + 'err(valid)={0:.2f} acc(valid)={1:.2f}'.format(valid_error, valid_accuracy))


        gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (15.391 secs): err(train)=2.06 acc(train)=0.30
# End epoch 02 (15.111 secs): err(train)=1.72 acc(train)=0.39
#                            err(valid)=1.60 acc(valid)=0.45
# End epoch 03 (15.108 secs): err(train)=1.66 acc(train)=0.42
# End epoch 04 (15.112 secs): err(train)=1.62 acc(train)=0.43
#                            err(valid)=1.61 acc(valid)=0.45
# End epoch 05 (15.206 secs): err(train)=1.58 acc(train)=0.45
# End epoch 06 (15.112 secs): err(train)=1.55 acc(train)=0.46
#                            err(valid)=1.58 acc(valid)=0.44
# End epoch 07 (15.116 secs): err(train)=1.52 acc(train)=0.47
# End epoch 08 (15.111 secs): err(train)=1.49 acc(train)=0.48
#                            err(valid)=1.57 acc(valid)=0.45
# End epoch 09 (15.653 secs): err(train)=1.46 acc(train)=0.49
# End epoch 10 (15.913 secs): err(train)=1.44 acc(train)=0.50
#                            err(valid)=1.58 acc(valid)=0.45
# End epoch 11 (15.597 secs): err(train)=1.40 acc(train)=0.51
# End epoch 12 (15.357 secs): err(train)=1.38 acc(train)=0.52
#                            err(valid)=1.61 acc(valid)=0.44
# End epoch 13 (15.207 secs): err(train)=1.36 acc(train)=0.53
# End epoch 14 (15.165 secs): err(train)=1.33 acc(train)=0.54
#                            err(valid)=1.64 acc(valid)=0.44
# End epoch 15 (15.150 secs): err(train)=1.33 acc(train)=0.54
# End epoch 16 (15.139 secs): err(train)=1.29 acc(train)=0.56
#                            err(valid)=1.61 acc(valid)=0.45
# End epoch 17 (15.349 secs): err(train)=1.28 acc(train)=0.56
# End epoch 18 (15.133 secs): err(train)=1.25 acc(train)=0.57
#                            err(valid)=1.66 acc(valid)=0.44
# End epoch 19 (15.157 secs): err(train)=1.24 acc(train)=0.58
# End epoch 20 (15.218 secs): err(train)=1.22 acc(train)=0.58
#                            err(valid)=1.65 acc(valid)=0.43
# End epoch 21 (15.113 secs): err(train)=1.21 acc(train)=0.59
# End epoch 22 (15.179 secs): err(train)=1.20 acc(train)=0.59
#                            err(valid)=1.66 acc(valid)=0.43
# End epoch 23 (15.193 secs): err(train)=1.18 acc(train)=0.60
# End epoch 24 (15.145 secs): err(train)=1.16 acc(train)=0.61
#                            err(valid)=1.67 acc(valid)=0.44
# End epoch 25 (15.160 secs): err(train)=1.14 acc(train)=0.61
# End epoch 26 (15.149 secs): err(train)=1.13 acc(train)=0.62
#                            err(valid)=1.72 acc(valid)=0.44
# End epoch 27 (15.140 secs): err(train)=1.12 acc(train)=0.62
# End epoch 28 (15.912 secs): err(train)=1.10 acc(train)=0.63
#                            err(valid)=1.70 acc(valid)=0.44
# End epoch 29 (15.561 secs): err(train)=1.11 acc(train)=0.63
# End epoch 30 (15.215 secs): err(train)=1.10 acc(train)=0.63
#                            err(valid)=1.75 acc(valid)=0.44
# End epoch 31 (15.101 secs): err(train)=1.09 acc(train)=0.64
# End epoch 32 (16.186 secs): err(train)=1.07 acc(train)=0.64
#                            err(valid)=1.75 acc(valid)=0.43
# End epoch 33 (16.247 secs): err(train)=1.07 acc(train)=0.64
# End epoch 34 (15.140 secs): err(train)=1.06 acc(train)=0.65
#                            err(valid)=1.80 acc(valid)=0.43
# End epoch 35 (15.221 secs): err(train)=1.04 acc(train)=0.65
# End epoch 36 (15.098 secs): err(train)=1.03 acc(train)=0.66
#                            err(valid)=1.88 acc(valid)=0.44
# End epoch 37 (15.753 secs): err(train)=1.03 acc(train)=0.66
# End epoch 38 (15.771 secs): err(train)=1.02 acc(train)=0.66
#                            err(valid)=1.74 acc(valid)=0.43
# End epoch 39 (15.110 secs): err(train)=1.02 acc(train)=0.67
# End epoch 40 (15.110 secs): err(train)=1.01 acc(train)=0.67
#                            err(valid)=1.83 acc(valid)=0.44
# CPU times: user 8min 38s, sys: 1min 20s, total: 9min 58s
# Wall time: 10min 35s

# %% [markdown]
# #### Conclusion
# We see that by using dropout on all layers and by setting dropout probabilities low enough we have not achieved a very good regularization and the training has become quite slow.
#
# One easy variation is to see how the system behaves by using tanh non-linearity

# %% [markdown]
# ### By substituting ReLU with Tanh for the above experiment do we get a better effect?

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %%
hidden_dims = [500, 500, 500, 500]
learningRate = 1e-3
keep_probs = []
#l2_regularization_penalty = 0.5

tf.reset_default_graph() #kind of redundant statement

graph = tf.Graph() #create new graph

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    
    
    with tf.name_scope("regularization0"):
        keep_probs.append( tf.placeholder(curDtype) )
        inputs_prob = tf.nn.dropout(inputs, keep_probs[0])
        
    with tf.name_scope('fullyConnected_1'):
        hidden_1 = fully_connected_layer(inputs_prob, train_data.inputs.shape[1], hidden_dims[0],
                                         nonlinearity=tf.nn.tanh)
        
        
    with tf.name_scope("regularization1"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_1_prob = tf.nn.dropout(hidden_1, keep_probs[1])
    
    with tf.name_scope('fullyConnected_2'):
        hidden_2 = fully_connected_layer(hidden_1_prob, hidden_dims[0], hidden_dims[1], nonlinearity=tf.nn.tanh)
        
    
    with tf.name_scope("regularization2"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_2_prob = tf.nn.dropout(hidden_2, keep_probs[2])
        
    with tf.name_scope('fullyConnected_3'):
        hidden_3 = fully_connected_layer(hidden_2_prob, hidden_dims[1], hidden_dims[2], nonlinearity=tf.nn.tanh)
        
    
    with tf.name_scope("regularization3"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_3_prob = tf.nn.dropout(hidden_3, keep_probs[3])
        
    with tf.name_scope('fullyConnected_4'):
        hidden_4 = fully_connected_layer(hidden_3_prob, hidden_dims[2], hidden_dims[3], nonlinearity=tf.nn.tanh)

        
    with tf.name_scope("regularization4"):
        keep_probs.append( tf.placeholder(curDtype) )
        hidden_4_prob = tf.nn.dropout(hidden_4, keep_probs[4])

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_4_prob, hidden_dims[3], train_data.num_classes, nonlinearity=tf.identity)


    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)

    init = tf.global_variables_initializer()

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_19-53-41&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/Placeholder&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Shape&quot;\n  op: &quot;Shape&quot;\n  input: &quot;inputs&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;out_type&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 1.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;regularization0/dropout/Shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;regularization0/dropout/random_uniform/max&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/RandomUniform&quot;\n  input: &quot;regularization0/dropout/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/dropout/random_uniform/mul&quot;\n  input: &quot;regularization0/dropout/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/add&quot;\n  op: &quot;Add&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  input: &quot;regularization0/dropout/random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Floor&quot;\n  op: &quot;Floor&quot;\n  input: &quot;regularization0/dropout/add&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;regularization0/dropout/Div&quot;\n  op: &quot;Div&quot;\n  input: &quot;inputs&quot;\n  input: &quot;regularization0/Placeholder&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name:  ...

# %%
# %%time

epochs = 20

keep_prob_values = [0.9, 0.6, 0.6, 0.6, 0.6]

assert len(keep_probs) == len(keep_prob_values)

keep_prob_dict = dict()
for i, keep_prob_key in enumerate(keep_probs):
    keep_prob_dict[keep_prob_key] = keep_prob_values[i]

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()

    for e in range(epochs):
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: 
                trainEpoch(e, train_data, train_step, error, accuracy,
                    extraFeedDict= keep_prob_dict
            ))
        
        #print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)

        if (e + 1) % 1 == 0:
            valid_error, valid_accuracy = validateEpoch(e, valid_data, error, accuracy, keep_probs)

            #print((' ' * 27) + 'err(valid)={0:.2f} acc(valid)={1:.2f}'.format(valid_error, valid_accuracy))

        print 'End epoch %02d (%.3f secs): err(train)=%.2f, acc(train)=%.2f, err(valid)=%.2f, acc(valid)=%.2f, ' %\
            (e+1, runTime, train_error, train_accuracy, valid_error, valid_accuracy)
        
        gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (15.360 secs): err(train)=2.04, acc(train)=0.33, err(valid)=1.70, acc(valid)=0.43,
# End epoch 02 (17.026 secs): err(train)=1.68, acc(train)=0.42, err(valid)=1.60, acc(valid)=0.45,
# End epoch 03 (16.260 secs): err(train)=1.59, acc(train)=0.44, err(valid)=1.62, acc(valid)=0.45,
# End epoch 04 (15.042 secs): err(train)=1.54, acc(train)=0.46, err(valid)=1.60, acc(valid)=0.45,
# End epoch 05 (15.085 secs): err(train)=1.51, acc(train)=0.48, err(valid)=1.63, acc(valid)=0.45,
# End epoch 06 (15.001 secs): err(train)=1.48, acc(train)=0.49, err(valid)=1.58, acc(valid)=0.46,
# End epoch 07 (15.005 secs): err(train)=1.45, acc(train)=0.50, err(valid)=1.58, acc(valid)=0.46,
# End epoch 08 (15.023 secs): err(train)=1.43, acc(train)=0.51, err(valid)=1.62, acc(valid)=0.46,
# End epoch 09 (15.091 secs): err(train)=1.42, acc(train)=0.51, err(valid)=1.59, acc(valid)=0.46,
# End epoch 10 (15.074 secs): err(train)=1.38, acc(train)=0.52, err(valid)=1.64, acc(valid)=0.45,
# End epoch 11 (15.014 secs): err(train)=1.37, acc(train)=0.53, err(valid)=1.62, acc(valid)=0.46,
# End epoch 12 (14.993 secs): err(train)=1.36, acc(train)=0.53, err(valid)=1.61, acc(valid)=0.46,
# End epoch 13 (14.995 secs): err(train)=1.33, acc(train)=0.54, err(valid)=1.62, acc(valid)=0.45,
# End epoch 14 (14.981 secs): err(train)=1.32, acc(train)=0.54, err(valid)=1.62, acc(valid)=0.46,
# End epoch 15 (15.002 secs): err(train)=1.31, acc(train)=0.55, err(valid)=1.61, acc(valid)=0.47,
# End epoch 16 (15.000 secs): err(train)=1.30, acc(train)=0.55, err(valid)=1.63, acc(valid)=0.46,
# End epoch 17 (15.089 secs): err(train)=1.29, acc(train)=0.56, err(valid)=1.63, acc(valid)=0.46,
# End epoch 18 (14.959 secs): err(train)=1.28, acc(train)=0.56, err(valid)=1.64, acc(valid)=0.46,
# End epoch 19 (14.959 secs): err(train)=1.27, acc(train)=0.57, err(valid)=1.63, acc(valid)=0.46,
# End epoch 20 (16.796 secs): err(train)=1.26, acc(train)=0.57, err(valid)=1.66, acc(valid)=0.46,
# CPU times: user 4min 29s, sys: 41.9 s, total: 5min 11s
# Wall time: 5min 27s

# %% [markdown]
# #### Conclusion
# The results are slightly better. The system seems more stable but the learning is still slow enough.
#
# Since the attempt to find the best regularization for a certain set of high dimensionality will take lots of manhours we should go back and test what would be the maximum number of layers and dimensionalities that would make sense for our classification problem.
#
# Since we do not have a solid metric to check how many layers are too many and how many are just enough we are going to base it on the training error rate. (We will not care about validation at this experiment).
# If the error is minimized and the training accuracy is close to 100% within only a few epochs then it means that we could introduce more complexity in the model with larger hidden dimensionalities and/or more hidden layers.
# On the other hand if we see that for a few epochs the error reaches at a plateau then we could consider that this architecture is too large and we should try and reduce the hidden dimensionalities and/or hidden layers.

# %% [markdown]
# ### How many hidden layers and how large hidden dimensionalities cause a plateau on the training error graph that is above zero ?

# %% [markdown]
# We are going to use GradientDescent to be able and spot that more easily

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %%
#hidden_dims = [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]
#no matter how many layers we add with dimensionality 1000 it seems that it behaves the same in terms
#of error and accuraycy, while of course it gets slower every time

#hidden_dims = [2000, 1000, 2000, 1000, 2000, 1000, 2000, 1500]
#hidden_dims = np.linspace(2000, 25, 10).astype(int)
hidden_dims = np.repeat(2000, 8).astype(int)
print hidden_dims

#tf.reset_default_graph() #kind of redundant statement
learningRate = 1e-1

graph = tf.Graph() #create new graph

hidden_layers = []

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    
    with tf.name_scope('fullyConnected0'):
        hidden_layers.append(
            fully_connected_layer(inputs, train_data.inputs.shape[1], hidden_dims[0], nonlinearity= tf.nn.tanh)
        )
    
    
    #for i, hidden_dim in enumerate(hidden_dims):
    for i in range(1, len(hidden_dims)):
        with tf.name_scope('fullyConnected%d' % i):
            hidden_layers.append(
                fully_connected_layer(hidden_layers[i-1],
                                      hidden_dims[i-1], hidden_dims[i],
                                      nonlinearity= tf.nn.tanh)
            )
            

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_layers[-1],
                                        hidden_dims[-1], train_data.num_classes,
                                        nonlinearity=tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        #train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)
        train_step = tf.train.GradientDescentOptimizer(learningRate).minimize(error)

    init = tf.global_variables_initializer()
# Out:
# [2000 2000 2000 2000 2000 2000 2000 2000]

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_21-15-23&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\270\\013\\000\\000\\320\\007\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0282842703164\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;fullyConnected0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;fullyConnected0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;fullyConnected0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;fullyConnected0/truncated_normal/mul&quot;\n  input: &quot;fullyConnected0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 3000\n        }\n        dim {\n          size: 2000\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;fullyConnected0/Variable&quot;\n  input: &quot;fullyConnected0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@fullyConnected0/Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable/rea ...

# %%
# %%time

epochs = 5

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()

    for e in range(epochs):
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: 
                trainEpoch(e, train_data, train_step, error, accuracy,
                    extraFeedDict= {}
            ))
        
        print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)
        
        gatherStats(e, train_error, train_accuracy, valid_error = 0., valid_accuracy = 0.)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (92.054 secs): err(train)=2.09 acc(train)=0.36
# End epoch 02 (94.713 secs): err(train)=1.52 acc(train)=0.48
# End epoch 03 (99.992 secs): err(train)=1.25 acc(train)=0.58
# End epoch 04 (95.887 secs): err(train)=0.97 acc(train)=0.68
# End epoch 05 (95.520 secs): err(train)=0.71 acc(train)=0.76
# CPU times: user 5min 38s, sys: 54.3 s, total: 6min 32s
# Wall time: 8min 1s

# %% [markdown]
# #### Conclusion
# Unfortunately after lots of experiments we have not managed to reach to a plateau within our computational limits. Meaning that using 8 hidden layers of 2000 attributes each was not enough to make unable the Gradient Optimizer (with learning rate of 1e-1) to train the model. The training was slow and non optimal but it is not a state where the neural network would have trouble to get out of if it was given more epochs of training.
#
# So as a next step we are going to apply a reduction to the layers from 2000 dimensionality up to the number of the classes, to see if we have better results in terms of performance without sacrificing the rate of the training.

# %% [markdown]
# ### Does a gradual reduction of the dimensionality of the hidden layers help the performance or the acc?

# %%
train_data = MSD10GenreDataProvider('train', batch_size=50, rng=rng) #((50, 3000), (50, 10))
valid_data = MSD10GenreDataProvider('valid', batch_size=50, rng=rng)

# %%
hidden_dims = np.linspace(1000, 25, 6).astype(int)
print hidden_dims

#tf.reset_default_graph() #kind of redundant statement
learningRate = 1e-3 #default of Adam is 1e-3

graph = tf.Graph() #create new graph

hidden_layers = []

with graph.as_default():
    inputs = tf.placeholder(curDtype, [None, train_data.inputs.shape[1]], 'inputs')
    targets = tf.placeholder(curDtype, [None, train_data.num_classes], 'targets')
    
    with tf.name_scope('fullyConnected0'):
        hidden_layers.append(
            fully_connected_layer(inputs, train_data.inputs.shape[1], hidden_dims[0], nonlinearity= tf.nn.tanh)
        )
    
    
    #for i, hidden_dim in enumerate(hidden_dims):
    for i in range(1, len(hidden_dims)):
        with tf.name_scope('fullyConnected%d' % i):
            hidden_layers.append(
                fully_connected_layer(hidden_layers[i-1],
                                      hidden_dims[i-1], hidden_dims[i],
                                      nonlinearity= tf.nn.tanh)
            )
            

    with tf.name_scope('readout_output_layer'):
        outputs = fully_connected_layer(hidden_layers[-1],
                                        hidden_dims[-1], train_data.num_classes,
                                        nonlinearity=tf.identity)

    with tf.name_scope('error'):
        error = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(outputs, targets))

    with tf.name_scope('accuracy'):
        accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1)), dtype=curDtype))

    with tf.name_scope('train'):
        train_step = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(error)

    init = tf.global_variables_initializer()
# Out:
# [1000  805  610  415  220   25]

# %%
show_graph(graph)
# Out:
#         <iframe seamless style="width:900px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph2017-02-07_21-51-25&quot;).pbtxt = 'node {\n  name: &quot;inputs&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;targets&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 2\n          }\n        }\n        tensor_content: &quot;\\270\\013\\000\\000\\350\\003\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.031622774899\n      }\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;fullyConnected0/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;fullyConnected0/truncated_normal/TruncatedNormal&quot;\n  input: &quot;fullyConnected0/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/truncated_normal&quot;\n  op: &quot;Add&quot;\n  input: &quot;fullyConnected0/truncated_normal/mul&quot;\n  input: &quot;fullyConnected0/truncated_normal/mean&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable&quot;\n  op: &quot;Variable&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 3000\n        }\n        dim {\n          size: 1000\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;fullyConnected0/Variable&quot;\n  input: &quot;fullyConnected0/truncated_normal&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@fullyConnected0/Variable&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;use_locking&quot;\n    value {\n      b: true\n    }\n  }\n  attr {\n    key: &quot;validate_shape&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;fullyConnected0/Variable/read ...

# %%
# %%time

epochs = 20

# keep_prob_values = [0.9, 0.6, 0.6, 0.6, 0.6]
# assert len(keep_probs) == len(keep_prob_values)
keep_prob_dict = dict()
# for i, keep_prob_key in enumerate(keep_probs):
#     keep_prob_dict[keep_prob_key] = keep_prob_values[i]

with tf.Session(graph=graph, config=config) as sess:
    sess.run(init)

    stats, keys = initStats()

    for e in range(epochs):
        (train_error, train_accuracy), runTime = getRunTime(lambda _ = None: 
                trainEpoch(e, train_data, train_step, error, accuracy,
                    extraFeedDict= keep_prob_dict
            ))
        
        #print 'End epoch %02d (%.3f secs): err(train)=%.2f acc(train)=%.2f' % (e+1, runTime, train_error,train_accuracy)

        if (e + 1) % 1 == 0:
            valid_error, valid_accuracy = validateEpoch(e, valid_data, error, accuracy)

            #print((' ' * 27) + 'err(valid)={0:.2f} acc(valid)={1:.2f}'.format(valid_error, valid_accuracy))

        print 'End epoch %02d (%.3f secs): err(train)=%.2f, acc(train)=%.2f, err(valid)=%.2f, acc(valid)=%.2f, ' %\
            (e+1, runTime, train_error, train_accuracy, valid_error, valid_accuracy)
        
        gatherStats(e, train_error, train_accuracy, valid_error, valid_accuracy)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats, keys, stats_interval=1)
figcount += 1
fig_1.savefig('cw3_part3_%02d_fig_error.svg' % figcount)
fig_2.savefig('cw3_part3_%02d_fig_valid.svg' % figcount)
# Out:
# End epoch 01 (26.292 secs): err(train)=1.76, acc(train)=0.39, err(valid)=1.71, acc(valid)=0.40,
# End epoch 02 (24.662 secs): err(train)=1.61, acc(train)=0.44, err(valid)=1.65, acc(valid)=0.44,
# End epoch 03 (24.698 secs): err(train)=1.52, acc(train)=0.48, err(valid)=1.66, acc(valid)=0.43,
# End epoch 04 (25.290 secs): err(train)=1.44, acc(train)=0.51, err(valid)=1.64, acc(valid)=0.44,
# End epoch 05 (25.105 secs): err(train)=1.37, acc(train)=0.53, err(valid)=1.65, acc(valid)=0.45,
# End epoch 06 (26.059 secs): err(train)=1.29, acc(train)=0.56, err(valid)=1.69, acc(valid)=0.44,
# End epoch 07 (24.674 secs): err(train)=1.23, acc(train)=0.59, err(valid)=1.69, acc(valid)=0.44,
# End epoch 08 (24.893 secs): err(train)=1.15, acc(train)=0.61, err(valid)=1.72, acc(valid)=0.44,
# End epoch 09 (24.624 secs): err(train)=1.08, acc(train)=0.64, err(valid)=1.75, acc(valid)=0.44,
# End epoch 10 (24.628 secs): err(train)=1.02, acc(train)=0.67, err(valid)=1.80, acc(valid)=0.44,
# End epoch 11 (24.633 secs): err(train)=0.95, acc(train)=0.69, err(valid)=1.83, acc(valid)=0.44,
# End epoch 12 (24.708 secs): err(train)=0.89, acc(train)=0.71, err(valid)=1.88, acc(valid)=0.44,
# End epoch 13 (24.661 secs): err(train)=0.84, acc(train)=0.73, err(valid)=1.93, acc(valid)=0.43,
# End epoch 14 (24.631 secs): err(train)=0.80, acc(train)=0.75, err(valid)=1.99, acc(valid)=0.43,
# End epoch 15 (24.636 secs): err(train)=0.76, acc(train)=0.76, err(valid)=2.03, acc(valid)=0.43,
# End epoch 16 (24.623 secs): err(train)=0.73, acc(train)=0.77, err(valid)=2.10, acc(valid)=0.42,
# End epoch 17 (24.701 secs): err(train)=0.70, acc(train)=0.78, err(valid)=2.11, acc(valid)=0.43,
# End epoch 18 (24.943 secs): err(train)=0.67, acc(train)=0.79, err(valid)=2.17, acc(valid)=0.42,
# End epoch 19 (25.634 secs): err(train)=0.64, acc(train)=0.80, err(valid)=2.20, acc(valid)=0.42,
# End epoch 20 (24.736 secs): err(train)=0.62, acc(train)=0.80, err(valid)=2.18, acc(valid)=0.43,
# CPU times: user 7min 10s, sys: 1min 8s, total: 8min 19s
# Wall time: 8min 41s

# %% [markdown]
# ### Does pretraining help the deeper neural network used above?

# %%
from mylibs.stacked_autoencoder_pretrainer import constructModelFromPretrainedByAutoEncoderStack,\
    buildGraphOfStackedAutoencoder, executeNonLinearAutoencoder

# %%
hidden_dims = np.linspace(1000, 25, 6).astype(int)
hidden_dims
# Out:
# array([1000,  805,  610,  415,  220,   25])

# %%
modelVars = constructModelFromPretrainedByAutoEncoderStack(hidden_dims,
                                                           autoencoder= executeNonLinearAutoencoder,
                                                          rng=rng,
                                                          dataProviderClass= MSD10Genre_StackedAutoEncoderDataProvider)
# Out:
# End epoch 01 (31.187 secs): err(train)=0.584
# End epoch 02 (30.989 secs): err(train)=0.469
# End epoch 03 (30.926 secs): err(train)=0.459
# End epoch 04 (31.038 secs): err(train)=0.455
# End epoch 05 (30.955 secs): err(train)=0.453
# End epoch 06 (30.977 secs): err(train)=0.451
# End epoch 07 (30.949 secs): err(train)=0.450
# End epoch 08 (31.066 secs): err(train)=0.449
# End epoch 09 (30.974 secs): err(train)=0.448
# End epoch 01 (38.971 secs): err(train)=0.241
# End epoch 02 (39.046 secs): err(train)=0.099
# End epoch 03 (38.916 secs): err(train)=0.090
# End epoch 04 (38.935 secs): err(train)=0.086
# End epoch 05 (38.903 secs): err(train)=0.084
# End epoch 06 (38.937 secs): err(train)=0.082
# End epoch 07 (38.868 secs): err(train)=0.081
# End epoch 08 (38.720 secs): err(train)=0.081
# End epoch 09 (38.887 secs): err(train)=0.080
# End epoch 01 (48.709 secs): err(train)=0.113
# End epoch 02 (47.335 secs): err(train)=0.055
# End epoch 03 (51.565 secs): err(train)=0.052
# End epoch 04 (47.200 secs): err(train)=0.051
# End epoch 05 (52.353 secs): err(train)=0.050
# End epoch 01 (55.961 secs): err(train)=0.063
# End epoch 02 (52.859 secs): err(train)=0.037
# End epoch 03 (55.882 secs): err(train)=0.035
# End epoch 04 (52.825 secs): err(train)=0.035
# End epoch 05 (55.778 secs): err(train)=0.035
# End epoch 01 (60.656 secs): err(train)=0.041
# End epoch 02 (56.611 secs): err(train)=0.029
# End epoch 03 (60.819 secs): err(train)=0.028
# End epoch 04 (56.651 secs): err(train)=0.028
# End epoch 05 (60.823 secs): err(train)=0.028
# End epoch 01 (62.061 secs): err(train)=0.037
# End epoch 02 (61.159 secs): err(train)=0.034
# End epoch 03 (62.779 secs): err(train)=0.034
# End epoch 04 (62.153 secs): err(train)=0.034

# %%
np.savez('pretrainedModelVars.npz', modelVars)
