# %% [markdown]
# # Machine Learning Practical: Coursework 2
# ## Experiment 2/3
#
# **Due date: 16:00 Thursday 24th November 2016**

# %% [markdown]
# # Georgios Pligoropoulos - s1687568

# %%
import sys
mlpdir = '/home/student/Dropbox/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical'
sys.path.append(mlpdir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import logging

#%matplotlib notebook
# %matplotlib inline

# %%
from mlp.data_providers import MNISTDataProvider

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, MaxPoolingLayer, DropoutLayer

from mlp.errors import CrossEntropySoftmaxError

from mlp.models import MultipleLayerModel

from mlp.initialisers import ConstantInit, GlorotUniformInit

from mlp.optimisers import Optimiser

from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule, \
    AdaGradLearningRule, RmsPropLearningRule
    
from mlp.schedulers import AnnealedDropoutScheduler, MomentumCoefficientScheduler, ConstantLearningRateScheduler,\
    ReciprocalLearningRateScheduler, ExponentialLearningRateScheduler

# %%
def trainModel(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, schedulers=[]):
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, schedulers = schedulers)

    # Run the optimiser for some number of epochs (full passes through the training set)
    # printing statistics every epoch
    stats, keys, runTime = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
    #stats = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    return stats, keys, runTime

# %%
def plotStats(stats, keys, stats_interval):
    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return fig_1, ax_1, fig_2, ax_2

# %%
def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, schedulers=[]):
    
    stats, keys, runTime = trainModel(model, error, learning_rule, train_data, valid_data,
                                       num_epochs, stats_interval, schedulers)

    fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys)
    
    return stats, keys, fig_1, ax_1, fig_2, ax_2, runTime

# %%
def getFinalValues(statistics):
    lastStats = statistics[-1]
    return {
        "Final Training Error": lastStats[0],
        "Final Training Accuracy": lastStats[1],
        "Final Testing Error": lastStats[2],
        "Final Testing Accuracy": lastStats[3],
    }

# %%
seed = 16011984
rng = np.random.RandomState(seed)

# %% [markdown]
# Note: When in our explanations refer to **accuracy** we mean the final validation accuracy and when we refer to **performance** we mean how fast we reached the optimal accuracy for the current experiment

# %% [markdown]
# # Grand Experiment 2: Annealed Dropout with Maxout
#
# Here first we will explore how Dropout works together with Maxout combining the experiments of lab6 as it is suggested that they generally produce good enough results together.
#
# Afterwards we will explore the system using the RMSprop implementation from coursework1 to boost the performance of our implementation.
#
# The next step is to optimize dropout by using annealed dropout methodology. So instead of using a fixed probability we are going to change it dynamically. We are going to start from a low inclusive-probabily (probability of input being included in output in dropout layer) and we are going to gradually increase the probability as the epochs go by. We are going to stop when probability reaches 100%.

# %%
weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# %%
# Seed a random number generator

# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
trainData = MNISTDataProvider('train', batch_size=50, rng=rng)
validData = MNISTDataProvider('valid', batch_size=50, rng=rng)

# Multiclass classification therefore use cross-entropy + softmax error
error = CrossEntropySoftmaxError() #this does not contain any immutable data that's why it can be set only once

# %%
statsInterval = 5

# %% [markdown]
# Note that we are going to use an architecture that is in consice with the conclusions from Grand Experiment 1.
# We are going to use the two layer model which is much faster in terms of performance and it will allow us to execute more experiments

# %%
#input_dim, output_dim, hidden_dim_layer1, hidden_dim_layer2 = 784, 10, 140, 100
input_dim, output_dim, hidden_dim = 784, 10, 140

# %%
figcount = 0

# %% [markdown]
# ## Maxout

# %%
numEpochs = 60

# Size of pools to take maximum over
pool_size = 4

# Use a momentum learning rule - you could use an adaptive learning rule
# implemented for the coursework here instead
learningRule = MomentumLearningRule(0.02) #let's use the recommended defaults instead

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        #ConstantLearningRateScheduler(learning_rate) #this actually does nothing so it's useless to include it
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_fig1.svg' % figcount)
fig_2.savefig('experiment2_%02d_maxout_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.45e+00, acc(train)=1.05e-01, error(valid)=2.44e+00, acc(valid)=1.11e-01, params_penalty=0.00e+00
# Epoch 5: 5.12s to complete
#   error(train)=2.88e-02, acc(train)=9.92e-01, error(valid)=7.67e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 10: 6.85s to complete
#   error(train)=4.90e-03, acc(train)=1.00e+00, error(valid)=6.56e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# Epoch 15: 5.93s to complete
#   error(train)=2.13e-03, acc(train)=1.00e+00, error(valid)=6.74e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 20: 6.19s to complete
#   error(train)=1.35e-03, acc(train)=1.00e+00, error(valid)=6.97e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 25: 5.55s to complete
#   error(train)=9.93e-04, acc(train)=1.00e+00, error(valid)=7.15e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 30: 5.51s to complete
#   error(train)=7.78e-04, acc(train)=1.00e+00, error(valid)=7.31e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 35: 5.53s to complete
#   error(train)=6.43e-04, acc(train)=1.00e+00, error(valid)=7.42e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 40: 6.46s to complete
#   error(train)=5.40e-04, acc(train)=1.00e+00, error(valid)=7.49e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 45: 5.66s to complete
#   error(train)=4.68e-04, acc(train)=1.00e+00, error(valid)=7.57e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 50: 5.59s to complete
#   error(train)=4.11e-04, acc(train)=1.00e+00, error(valid)=7.66e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# Epoch 55: 6.06s to complete
#   error(train)=3.66e-04, acc(train)=1.00e+00, error(valid)=7.75e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# Epoch 60: 5.55s to complete
#   error(train)=3.29e-04, acc(train)=1.00e+00, error(valid)=7.82e-02, acc(valid)=9.84e-01, params_penalty=0.00e+00
# runtime: 389.950199127
# {'Final Testing Accuracy': 0.98369999999999902,
#  'Final Testing Error': 0.078179863515805789,
#  'Final Training Accuracy': 1.0,
#  'Final Training Error': 0.00032944897215494046}

# %% [markdown]
# Note that the learning here is 1e-3 while in the one used in the lab was 2e-2
#
# Even with smaller learning rate the momentum drives the learning properly to achieve an accuracy of ~98% within 60 epochs
#
# If we increase the learning rate we are going to easily overfit. That's why we need to bring dropout to the game.

# %% [markdown]
# ## Maxout  and Dropout with momentum learning rule

# %%
numEpochs = 100

# Size of pools to take maximum over
pool_size = 4

# Probability of input being included in output in dropout layer
input_incl_prob = 0.9 #different for input layer
hidden_incl_prob = 0.6 #than the rest of the layers

# Use a momentum learning rule
learningRule = MomentumLearningRule(learning_rate=0.02) #and leave mom coefficient to the default 0.9

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #layer
    DropoutLayer(rng, input_incl_prob),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #layer
    DropoutLayer(rng, hidden_incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        #ConstantLearningRateScheduler(learning_rate) #this actually does nothing so it's useless to include it
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_dropout_fig1.svg' % figcount)
fig_2.savefig('experiment2_%02d_maxout_dropout_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.37e+00, acc(train)=1.07e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01, params_penalty=0.00e+00
# Epoch 5: 7.01s to complete
#   error(train)=9.08e-02, acc(train)=9.72e-01, error(valid)=1.13e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 10: 7.65s to complete
#   error(train)=5.44e-02, acc(train)=9.83e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 15: 7.11s to complete
#   error(train)=4.29e-02, acc(train)=9.86e-01, error(valid)=9.79e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 20: 6.65s to complete
#   error(train)=3.21e-02, acc(train)=9.90e-01, error(valid)=9.41e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 25: 7.09s to complete
#   error(train)=3.12e-02, acc(train)=9.89e-01, error(valid)=9.31e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 30: 6.71s to complete
#   error(train)=2.52e-02, acc(train)=9.92e-01, error(valid)=9.60e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 35: 6.79s to complete
#   error(train)=2.25e-02, acc(train)=9.93e-01, error(valid)=9.42e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 40: 7.10s to complete
#   error(train)=1.94e-02, acc(train)=9.93e-01, error(valid)=9.82e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 45: 8.00s to complete
#   error(train)=1.81e-02, acc(train)=9.94e-01, error(valid)=9.02e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 50: 7.94s to complete
#   error(train)=1.83e-02, acc(train)=9.94e-01, error(valid)=9.40e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 55: 8.26s to complete
#   error(train)=1.72e-02, acc(train)=9.94e-01, error(valid)=9.35e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 60: 6.82s to complete
#   error(train)=1.63e-02, acc(train)=9.94e-01, error(valid)=9.87e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# Epoch 65: 8.41s to complete
#   error(train)=1.48e-02, acc(train)=9.95e-01, error(valid)=1.03e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 7.69s to complete
#   error(train)=1.54e-02, acc(train)=9.95e-01, error(valid)=1.11e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 75: 6.49s to complete
#   error(train)=1.34e-02, acc(train)=9.96e-01, error(valid)=1.08e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 80: 8.13s to complete
#   error(train)=1.23e-02, acc(train)=9.96e-01, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 85: 7.04s to complete
#   error(train)=1.24e-02, acc(train)=9.96e-01, error(valid)=9.04e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# Epoch 90: 6.73s to complete
#   error(train)=1.25e-02, acc(train)=9.96e-01, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# Epoch 95: 7.93s to complete
#   error(train)=1.21e-02, acc(train)=9.96e-01, error(valid)=1.11e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 100: 7.80s to complete
#   error(train)=1.10e-02, acc(train)=9.97e-01, error(valid)=1.07e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# runtime: 775.867121935
# {'Final Testing Accuracy': 0.97809999999999919,
#  'Final Testing Error': 0.10682848345968722,
#  'Final Training Accuracy': 0.99670000000000214,
#  'Final Training Error': 0.01097044801313264}

# %% [markdown]
# With a much higher learning rate dropout managed to achieve good regularization and stabilized the validation error instead of leaving it to increase. However we didn't manage to achieve a high validation accuracy as before

# %% [markdown]
# Next we are going to remove the momentum learning rule and use the RMSprop learning rule instead which proved to be better overall in coursework1. Meaning that this adaptive learning rate was flexible enough to allow even small learning rates to be adapted quickly and efficiently

# %% [markdown]
# ## Maxout (pool size = 4)  and Dropout with RMSprop

# %%
learningRate = 1e-4
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 100

# Size of pools to take maximum over
pool_size = 4

# Probability of input being included in output in dropout layer
input_incl_prob = 0.9 #different for input layer
hidden_incl_prob = 0.6 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #layer
    DropoutLayer(rng, input_incl_prob),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #layer
    DropoutLayer(rng, hidden_incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        #ConstantLearningRateScheduler(learning_rate) #this actually does nothing so it's useless to include it
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_dropout_rmsProp_fig1.svg' % figcount)
fig_2.savefig('experiment2_%02d_maxout_dropout_rmsProp_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.35e+00, acc(train)=1.08e-01, error(valid)=2.35e+00, acc(valid)=1.05e-01, params_penalty=0.00e+00
# Epoch 5: 10.28s to complete
#   error(train)=1.96e-01, acc(train)=9.44e-01, error(valid)=1.88e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# Epoch 10: 11.79s to complete
#   error(train)=1.38e-01, acc(train)=9.60e-01, error(valid)=1.41e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# Epoch 15: 13.59s to complete
#   error(train)=1.11e-01, acc(train)=9.67e-01, error(valid)=1.19e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# Epoch 20: 12.02s to complete
#   error(train)=9.71e-02, acc(train)=9.72e-01, error(valid)=1.12e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 25: 11.97s to complete
#   error(train)=8.56e-02, acc(train)=9.74e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# Epoch 30: 12.14s to complete
#   error(train)=7.87e-02, acc(train)=9.77e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 35: 11.82s to complete
#   error(train)=7.05e-02, acc(train)=9.79e-01, error(valid)=9.60e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 40: 13.95s to complete
#   error(train)=6.65e-02, acc(train)=9.81e-01, error(valid)=9.88e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 45: 12.15s to complete
#   error(train)=6.16e-02, acc(train)=9.82e-01, error(valid)=9.87e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 50: 11.84s to complete
#   error(train)=6.01e-02, acc(train)=9.83e-01, error(valid)=9.47e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 55: 13.88s to complete
#   error(train)=5.44e-02, acc(train)=9.84e-01, error(valid)=9.13e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 60: 13.59s to complete
#   error(train)=5.28e-02, acc(train)=9.84e-01, error(valid)=9.15e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 65: 11.90s to complete
#   error(train)=5.03e-02, acc(train)=9.85e-01, error(valid)=8.72e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 70: 11.87s to complete
#   error(train)=4.84e-02, acc(train)=9.86e-01, error(valid)=9.37e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# Epoch 75: 11.89s to complete
#   error(train)=4.77e-02, acc(train)=9.86e-01, error(valid)=9.23e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 80: 11.90s to complete
#   error(train)=4.66e-02, acc(train)=9.86e-01, error(valid)=9.79e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 85: 11.99s to complete
#   error(train)=4.42e-02, acc(train)=9.87e-01, error(valid)=9.18e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 90: 12.04s to complete
#   error(train)=4.35e-02, acc(train)=9.88e-01, error(valid)=8.77e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# Epoch 95: 11.83s to complete
#   error(train)=4.04e-02, acc(train)=9.88e-01, error(valid)=9.86e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 100: 12.09s to complete
#   error(train)=3.94e-02, acc(train)=9.89e-01, error(valid)=9.24e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# runtime: 1281.10038996
# {'Final Testing Accuracy': 0.97619999999999896,
#  'Final Testing Error': 0.092352949149768368,
#  'Final Training Accuracy': 0.98880000000000567,
#  'Final Training Error': 0.039424900776501695}

# %% [markdown]
# This experiment was quite slow and took one third of an hour to execute. This will not be very helpful to try different parameters.
#
# We are going to repeat it by trying a maxout pool size of 2

# %% [markdown]
# ## Maxout (pool size = 2)  and Dropout with RMSprop

# %%
learningRate = 1e-3
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 100

# Size of pools to take maximum over
pool_size = 2

# Probability of input being included in output in dropout layer
input_incl_prob = 0.9 #different for input layer
hidden_incl_prob = 0.7 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #layer
    DropoutLayer(rng, input_incl_prob),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #layer
    DropoutLayer(rng, hidden_incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        #ConstantLearningRateScheduler(learning_rate) #this actually does nothing so it's useless to include it
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount +=1
fig_1.savefig('experiment2_%02d_maxout_dropout_fig1.svg' % figcount)
fig_2.savefig('experiment2_%02d_maxout_dropout_fig2.svg' % figcount)

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.39e+00, acc(train)=9.99e-02, error(valid)=2.39e+00, acc(valid)=1.00e-01, params_penalty=0.00e+00
# Epoch 5: 4.81s to complete
#   error(train)=8.85e-02, acc(train)=9.74e-01, error(valid)=1.17e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# Epoch 10: 4.92s to complete
#   error(train)=6.81e-02, acc(train)=9.79e-01, error(valid)=1.23e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 15: 5.96s to complete
#   error(train)=5.91e-02, acc(train)=9.82e-01, error(valid)=1.21e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# Epoch 20: 6.30s to complete
#   error(train)=5.81e-02, acc(train)=9.83e-01, error(valid)=1.28e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# Epoch 25: 5.00s to complete
#   error(train)=4.43e-02, acc(train)=9.86e-01, error(valid)=1.22e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 30: 5.07s to complete
#   error(train)=4.38e-02, acc(train)=9.87e-01, error(valid)=1.28e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 35: 5.02s to complete
#   error(train)=4.13e-02, acc(train)=9.87e-01, error(valid)=1.28e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 40: 5.17s to complete
#   error(train)=3.58e-02, acc(train)=9.89e-01, error(valid)=1.18e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 45: 6.05s to complete
#   error(train)=3.62e-02, acc(train)=9.89e-01, error(valid)=1.29e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 50: 5.00s to complete
#   error(train)=3.45e-02, acc(train)=9.89e-01, error(valid)=1.34e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 55: 4.96s to complete
#   error(train)=3.15e-02, acc(train)=9.90e-01, error(valid)=1.44e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 60: 5.09s to complete
#   error(train)=3.69e-02, acc(train)=9.89e-01, error(valid)=1.44e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 65: 6.76s to complete
#   error(train)=3.66e-02, acc(train)=9.89e-01, error(valid)=1.45e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 70: 5.33s to complete
#   error(train)=3.31e-02, acc(train)=9.90e-01, error(valid)=1.47e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# Epoch 75: 6.24s to complete
#   error(train)=3.22e-02, acc(train)=9.91e-01, error(valid)=1.42e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 80: 5.19s to complete
#   error(train)=3.00e-02, acc(train)=9.90e-01, error(valid)=1.51e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# Epoch 85: 6.39s to complete
#   error(train)=3.07e-02, acc(train)=9.91e-01, error(valid)=1.57e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# Epoch 90: 4.96s to complete
#   error(train)=2.90e-02, acc(train)=9.91e-01, error(valid)=1.62e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# Epoch 95: 4.91s to complete
#   error(train)=3.02e-02, acc(train)=9.91e-01, error(valid)=1.70e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# Epoch 100: 5.01s to complete
#   error(train)=3.10e-02, acc(train)=9.91e-01, error(valid)=1.64e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# runtime: 572.393479109
# {'Final Testing Accuracy': 0.97219999999999918,
#  'Final Testing Error': 0.16408024330393034,
#  'Final Training Accuracy': 0.9909600000000045,
#  'Final Training Error': 0.030960291560478217}

# %% [markdown]
# We see here that regularization has been achieved again even with slightly larger inclusive probability for the hidden layer from 60% to 70% and even though the coefficient of the learning rate of the adaptive RMSprop learning rule was 10 times larger than the previous experiment.
#
# Decreasing the maxout parameters made our experiment to run within ~15minutes and the final validation accuracy after 100 epochs was slightly higher than before.

# %% [markdown]
# ## Annealed Dropout of starting Maxout and Dropout with RMSprop

# %% [markdown]
# ### Starting input inclusive probability from 0.8 to 1
# ### Starting hidden layer inclusive probability from 0.1 to 1
# ### Percentage of epochs in the end where probability is equal to 100% constantly is 0.1
# ### Number of epochs: 200
# ### Max Pooling size 2

# %% [markdown]
# We see that the first run of the annealing dropout created a very smooth graph where the training curve was close to the validation/testing curve meaning that we have a good convergence.
#
# In terms of performance this is not the best because we had to spend 100 epochs to achieve a not so bad accuracy but the whole training procedure took >15 minutes to complete
#
# In terms of accuracy we did do better than our previous experiments at ~98.02% but not better than our top performance we saw

# %%
holdOnPercent = 0.1

learningRate = 1e-4
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 200

# Size of pools to take maximum over
pool_size = 2

# Probability of input being included in output in dropout layer
startInputInclProb = 0.8 #different for input layer
startHiddenInclProb = 0.1 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #
    DropoutLayer(rng, startInputInclProb),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #
    DropoutLayer(rng, startHiddenInclProb),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        AnnealedDropoutScheduler(model = model,
                         startInputInclProb = startInputInclProb,
                         startHiddenInclProb = startHiddenInclProb,
                         epochs = numEpochs,
                         holdOnPercent=holdOnPercent)
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig1.svg' % (figcount, startInputInclProb, startHiddenInclProb))
fig_2.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig2.svg' % (figcount, startInputInclProb, startHiddenInclProb))

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.31e+00, acc(train)=9.63e-02, error(valid)=2.31e+00, acc(valid)=1.04e-01, params_penalty=0.00e+00
# all probs from model: 0.8, 0.1
# all probs from model: 0.801117318436, 0.105027932961
# all probs from model: 0.802234636872, 0.110055865922
# all probs from model: 0.803351955307, 0.115083798883
# all probs from model: 0.804469273743, 0.120111731844
# Epoch 5: 7.00s to complete
#   error(train)=1.10e+00, acc(train)=7.20e-01, error(valid)=1.07e+00, acc(valid)=7.43e-01, params_penalty=0.00e+00
# all probs from model: 0.805586592179, 0.125139664804
# all probs from model: 0.806703910615, 0.130167597765
# all probs from model: 0.80782122905, 0.135195530726
# all probs from model: 0.808938547486, 0.140223463687
# all probs from model: 0.810055865922, 0.145251396648
# Epoch 10: 7.73s to complete
#   error(train)=6.70e-01, acc(train)=8.09e-01, error(valid)=6.15e-01, acc(valid)=8.34e-01, params_penalty=0.00e+00
# all probs from model: 0.811173184358, 0.150279329609
# all probs from model: 0.812290502793, 0.15530726257
# all probs from model: 0.813407821229, 0.160335195531
# all probs from model: 0.814525139665, 0.165363128492
# all probs from model: 0.815642458101, 0.170391061453
# Epoch 15: 6.15s to complete
#   error(train)=5.00e-01, acc(train)=8.55e-01, error(valid)=4.59e-01, acc(valid)=8.71e-01, params_penalty=0.00e+00
# all probs from model: 0.816759776536, 0.175418994413
# all probs from model: 0.817877094972, 0.180446927374
# all probs from model: 0.818994413408, 0.185474860335
# all probs from model: 0.820111731844, 0.190502793296
# all probs from model: 0.821229050279, 0.195530726257
# Epoch 20: 7.21s to complete
#   error(train)=4.17e-01, acc(train)=8.80e-01, error(valid)=3.76e-01, acc(valid)=8.93e-01, params_penalty=0.00e+00
# all probs from model: 0.822346368715, 0.200558659218
# all probs from model: 0.823463687151, 0.205586592179
# all probs from model: 0.824581005587, 0.21061452514
# all probs from model: 0.825698324022, 0.215642458101
# all probs from model: 0.826815642458, 0.220670391061
# Epoch 25: 7.45s to complete
#   error(train)=3.60e-01, acc(train)=8.96e-01, error(valid)=3.39e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# all probs from model: 0.827932960894, 0.225698324022
# all probs from model: 0.82905027933, 0.230726256983
# all probs from model: 0.830167597765, 0.235754189944
# all probs from model: 0.831284916201, 0.240782122905
# all probs from model: 0.832402234637, 0.245810055866
# Epoch 30: 7.42s to complete
#   error(train)=3.22e-01, acc(train)=9.08e-01, error(valid)=2.91e-01, acc(valid)=9.18e-01, params_penalty=0.00e+00
# all probs from model: 0.833519553073, 0.250837988827
# all probs from model: 0.834636871508, 0.255865921788
# all probs from model: 0.835754189944, 0.260893854749
# all probs from model: 0.83687150838, 0.265921787709
# all probs from model: 0.837988826816, 0.27094972067
# Epoch 35: 5.86s to complete
#   error(train)=2.92e-01, acc(train)=9.18e-01, error(valid)=2.75e-01, acc(valid)=9.25e-01, params_penalty=0.00e+00
# all probs from model: 0.839106145251, 0.275977653631
# all probs from model: 0.840223463687, 0.281005586592
# all probs from model: 0.841340782123, 0.286033519553
# all probs from model: 0.842458100559, 0.291061452514
# all probs from model: 0.843575418994, 0.296089385475
# Epoch 40: 5.55s to complete
#   error(train)=2.61e-01, acc(train)=9.26e-01, error(valid)=2.51e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# all probs from model: 0.84469273743, 0.301117318436
# all probs from model: 0.845810055866, 0.306145251397
# all probs from model: 0.846927374302, 0.311173184358
# all probs from model: 0.848044692737, 0.316201117318
# all probs from model: 0.849162011173, 0.321229050279
# Epoch 45: 6.96s to complete
#   error(train)=2.41e-01, acc(train)=9.34e-01, error(valid)=2.29e-01, acc(valid)=9.36e-01, params_penalty=0.00e+00
# all probs from model: 0.850279329609, 0.32625698324
# all probs from model: 0.851396648045, 0.331284916201
# all probs from model: 0.85251396648, 0.336312849162
# all probs from model: 0.853631284916, 0.341340782123
# all probs from model: 0.854748603352, 0.346368715084
# Epoch 50: 6.85s to complete
#   error(train)=2.22e-01, acc(train)=9.38e-01, error(valid)=2.14e-01, acc(valid)=9.40e-01, params_penalty=0.00e+00
# all probs from model: 0.855865921788, 0.351396648045
# all probs from model: 0.856983240223, 0.356424581006
# all probs from model: 0.858100558659, 0.361452513966
# all probs from model: 0.859217877095, 0.366480446927
# all probs from model: 0.860335195531, 0.371508379888
# Epoch 55: 7.58s to complete
#   error(train)=2.09e-01, acc(train)=9.42e-01, error(valid)=1.94e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# all probs from model: 0.861452513966, 0.376536312849
# all probs from model: 0.862569832402, 0.38156424581
# all probs from model: 0.863687150838, 0.386592178771
# all probs from model: 0.864804469274, 0.391620111732
# all probs from model: 0.865921787709, 0.396648044693
# Epoch 60: 6.10s to complete
#   error(train)=1.85e-01, acc(train)=9.49e-01, error(valid)=1.87e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# all probs from model: 0.867039106145, 0.401675977654
# all probs from model: 0.868156424581, 0.406703910615
# all probs from model: 0.869273743017, 0.411731843575
# all probs from model: 0.870391061453, 0.416759776536
# all probs from model: 0.871508379888, 0.421787709497
# Epoch 65: 5.58s to complete
#   error(train)=1.74e-01, acc(train)=9.51e-01, error(valid)=1.67e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# all probs from model: 0.872625698324, 0.426815642458
# all probs from model: 0.87374301676, 0.431843575419
# all probs from model: 0.874860335196, 0.43687150838
# all probs from model: 0.875977653631, 0.441899441341
# all probs from model: 0.877094972067, 0.446927374302
# Epoch 70: 7.49s to complete
#   error(train)=1.58e-01, acc(train)=9.56e-01, error(valid)=1.66e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# all probs from model: 0.878212290503, 0.451955307263
# all probs from model: 0.879329608939, 0.456983240223
# all probs from model: 0.880446927374, 0.462011173184
# all probs from model: 0.88156424581, 0.467039106145
# all probs from model: 0.882681564246, 0.472067039106
# Epoch 75: 6.73s to complete
#   error(train)=1.47e-01, acc(train)=9.58e-01, error(valid)=1.56e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# all probs from model: 0.883798882682, 0.477094972067
# all probs from model: 0.884916201117, 0.482122905028
# all probs from model: 0.886033519553, 0.487150837989
# all probs from model: 0.887150837989, 0.49217877095
# all probs from model: 0.888268156425, 0.497206703911
# Epoch 80: 6.07s to complete
#   error(train)=1.36e-01, acc(train)=9.60e-01, error(valid)=1.42e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# all probs from model: 0.88938547486, 0.502234636872
# all probs from model: 0.890502793296, 0.507262569832
# all probs from model: 0.891620111732, 0.512290502793
# all probs from model: 0.892737430168, 0.517318435754
# all probs from model: 0.893854748603, 0.522346368715
# Epoch 85: 5.95s to complete
#   error(train)=1.25e-01, acc(train)=9.65e-01, error(valid)=1.34e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# all probs from model: 0.894972067039, 0.527374301676
# all probs from model: 0.896089385475, 0.532402234637
# all probs from model: 0.897206703911, 0.537430167598
# all probs from model: 0.898324022346, 0.542458100559
# all probs from model: 0.899441340782, 0.54748603352
# Epoch 90: 5.62s to complete
#   error(train)=1.16e-01, acc(train)=9.67e-01, error(valid)=1.36e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# all probs from model: 0.900558659218, 0.55251396648
# all probs from model: 0.901675977654, 0.557541899441
# all probs from model: 0.902793296089, 0.562569832402
# all probs from model: 0.903910614525, 0.567597765363
# all probs from model: 0.905027932961, 0.572625698324
# Epoch 95: 5.74s to complete
#   error(train)=1.09e-01, acc(train)=9.70e-01, error(valid)=1.27e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# all probs from model: 0.906145251397, 0.577653631285
# all probs from model: 0.907262569832, 0.582681564246
# all probs from model: 0.908379888268, 0.587709497207
# all probs from model: 0.909497206704, 0.592737430168
# all probs from model: 0.91061452514, 0.597765363128
# Epoch 100: 6.25s to complete
#   error(train)=9.86e-02, acc(train)=9.73e-01, error(valid)=1.25e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# all probs from model: 0.911731843575, 0.602793296089
# all probs from model: 0.912849162011, 0.60782122905
# all probs from model: 0.913966480447, 0.612849162011
# all probs from model: 0.915083798883, 0.617877094972
# all probs from model: 0.916201117318, 0.622905027933
# Epoch 105: 5.58s to complete
#   error(train)=8.96e-02, acc(train)=9.74e-01, error(valid)=1.19e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# all probs from model: 0.917318435754, 0.627932960894
# all probs from model: 0.91843575419, 0.632960893855
# all probs from model: 0.919553072626, 0.637988826816
# all probs from model: 0.920670391061, 0.643016759777
# all probs from model: 0.921787709497, 0.648044692737
# Epoch 110: 5.71s to complete
#   error(train)=8.32e-02, acc(train)=9.76e-01, error(valid)=1.12e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# all probs from model: 0.922905027933, 0.653072625698
# all probs from model: 0.924022346369, 0.658100558659
# all probs from model: 0.925139664804, 0.66312849162
# all probs from model: 0.92625698324, 0.668156424581
# all probs from model: 0.927374301676, 0.673184357542
# Epoch 115: 6.25s to complete
#   error(train)=7.72e-02, acc(train)=9.78e-01, error(valid)=1.21e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# all probs from model: 0.928491620112, 0.678212290503
# all probs from model: 0.929608938547, 0.683240223464
# all probs from model: 0.930726256983, 0.688268156425
# all probs from model: 0.931843575419, 0.693296089385
# all probs from model: 0.932960893855, 0.698324022346
# Epoch 120: 5.50s to complete
#   error(train)=7.21e-02, acc(train)=9.79e-01, error(valid)=1.06e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# all probs from model: 0.934078212291, 0.703351955307
# all probs from model: 0.935195530726, 0.708379888268
# all probs from model: 0.936312849162, 0.713407821229
# all probs from model: 0.937430167598, 0.71843575419
# all probs from model: 0.938547486034, 0.723463687151
# Epoch 125: 5.45s to complete
#   error(train)=6.35e-02, acc(train)=9.82e-01, error(valid)=9.68e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# all probs from model: 0.939664804469, 0.728491620112
# all probs from model: 0.940782122905, 0.733519553073
# all probs from model: 0.941899441341, 0.738547486034
# all probs from model: 0.943016759777, 0.743575418994
# all probs from model: 0.944134078212, 0.748603351955
# Epoch 130: 5.65s to complete
#   error(train)=5.97e-02, acc(train)=9.82e-01, error(valid)=1.03e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# all probs from model: 0.945251396648, 0.753631284916
# all probs from model: 0.946368715084, 0.758659217877
# all probs from model: 0.94748603352, 0.763687150838
# all probs from model: 0.948603351955, 0.768715083799
# all probs from model: 0.949720670391, 0.77374301676
# Epoch 135: 5.46s to complete
#   error(train)=5.25e-02, acc(train)=9.85e-01, error(valid)=1.01e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# all probs from model: 0.950837988827, 0.778770949721
# all probs from model: 0.951955307263, 0.783798882682
# all probs from model: 0.953072625698, 0.788826815642
# all probs from model: 0.954189944134, 0.793854748603
# all probs from model: 0.95530726257, 0.798882681564
# Epoch 140: 5.79s to complete
#   error(train)=4.76e-02, acc(train)=9.86e-01, error(valid)=1.02e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# all probs from model: 0.956424581006, 0.803910614525
# all probs from model: 0.957541899441, 0.808938547486
# all probs from model: 0.958659217877, 0.813966480447
# all probs from model: 0.959776536313, 0.818994413408
# all probs from model: 0.960893854749, 0.824022346369
# Epoch 145: 7.54s to complete
#   error(train)=4.17e-02, acc(train)=9.88e-01, error(valid)=9.28e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# all probs from model: 0.962011173184, 0.82905027933
# all probs from model: 0.96312849162, 0.834078212291
# all probs from model: 0.964245810056, 0.839106145251
# all probs from model: 0.965363128492, 0.844134078212
# all probs from model: 0.966480446927, 0.849162011173
# Epoch 150: 7.62s to complete
#   error(train)=3.72e-02, acc(train)=9.89e-01, error(valid)=9.67e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# all probs from model: 0.967597765363, 0.854189944134
# all probs from model: 0.968715083799, 0.859217877095
# all probs from model: 0.969832402235, 0.864245810056
# all probs from model: 0.97094972067, 0.869273743017
# all probs from model: 0.972067039106, 0.874301675978
# Epoch 155: 5.50s to complete
#   error(train)=3.30e-02, acc(train)=9.90e-01, error(valid)=9.05e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# all probs from model: 0.973184357542, 0.879329608939
# all probs from model: 0.974301675978, 0.884357541899
# all probs from model: 0.975418994413, 0.88938547486
# all probs from model: 0.976536312849, 0.894413407821
# all probs from model: 0.977653631285, 0.899441340782
# Epoch 160: 5.44s to complete
#   error(train)=2.85e-02, acc(train)=9.92e-01, error(valid)=9.39e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# all probs from model: 0.978770949721, 0.904469273743
# all probs from model: 0.979888268156, 0.909497206704
# all probs from model: 0.981005586592, 0.914525139665
# all probs from model: 0.982122905028, 0.919553072626
# all probs from model: 0.983240223464, 0.924581005587
# Epoch 165: 7.77s to complete
#   error(train)=2.43e-02, acc(train)=9.93e-01, error(valid)=8.83e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# all probs from model: 0.984357541899, 0.929608938547
# all probs from model: 0.985474860335, 0.934636871508
# all probs from model: 0.986592178771, 0.939664804469
# all probs from model: 0.987709497207, 0.94469273743
# all probs from model: 0.988826815642, 0.949720670391
# Epoch 170: 5.32s to complete
#   error(train)=1.92e-02, acc(train)=9.95e-01, error(valid)=9.16e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# all probs from model: 0.989944134078, 0.954748603352
# all probs from model: 0.991061452514, 0.959776536313
# all probs from model: 0.99217877095, 0.964804469274
# all probs from model: 0.993296089385, 0.969832402235
# all probs from model: 0.994413407821, 0.974860335196
# Epoch 175: 7.26s to complete
#   error(train)=1.49e-02, acc(train)=9.96e-01, error(valid)=8.98e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 0.995530726257, 0.979888268156
# all probs from model: 0.996648044693, 0.984916201117
# all probs from model: 0.997765363128, 0.989944134078
# all probs from model: 0.998882681564, 0.994972067039
# all probs from model: 1.0, 1.0
# Epoch 180: 5.75s to complete
#   error(train)=1.10e-02, acc(train)=9.98e-01, error(valid)=9.13e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 185: 7.03s to complete
#   error(train)=9.43e-03, acc(train)=9.98e-01, error(valid)=9.15e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 190: 5.95s to complete
#   error(train)=8.06e-03, acc(train)=9.98e-01, error(valid)=9.41e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 195: 6.52s to complete
#   error(train)=6.92e-03, acc(train)=9.99e-01, error(valid)=9.45e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 200: 5.70s to complete
#   error(train)=6.15e-03, acc(train)=9.99e-01, error(valid)=9.62e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# runtime: 1354.82056618
# {'Final Testing Accuracy': 0.98029999999999862,
#  'Final Testing Error': 0.09619017831096531,
#  'Final Training Accuracy': 0.99876000000000054,
#  'Final Training Error': 0.0061450748950512037}

# %% [markdown]
# Our second experiment where the epochs are 200 twice the number we had before it seems that when dropout inclusive probability increasing linearly it does not tend to increase the accuracy a lot. We had done worse in terms of performance.
#
# However we have slightly increased the performance of the final accuracy for 0.1%.
# We have 98.1% of final performance accuracy.
#
# By letting our model run for the last 10% of our test, for 20 epochs, with full probability it is obvious that the validation error starts to increase which means that we have overfitted since our dropout regularization is not active anymore and we do not have any other regularization in place.

# %% [markdown]
# ### Starting input inclusive probability from 0.8 to 1
# ### Starting hidden layer inclusive probability from 0.1 to 1
# ### Percentage of epochs in the end where probability is equal to 1 constantly: 0.1
# ### Number of epochs 200
# ### Max Pooling size 4

# %%
holdOnPercent = 0.1

learningRate = 1e-4
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 200

# Size of pools to take maximum over
pool_size = 4

# Probability of input being included in output in dropout layer
startInputInclProb = 0.8 #different for input layer
startHiddenInclProb = 0.1 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #
    DropoutLayer(rng, startInputInclProb),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #
    DropoutLayer(rng, startHiddenInclProb),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        AnnealedDropoutScheduler(model = model,
                         startInputInclProb = startInputInclProb,
                         startHiddenInclProb = startHiddenInclProb,
                         epochs = numEpochs,
                         holdOnPercent=holdOnPercent)
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig1.svg' % (figcount, startInputInclProb, startHiddenInclProb))
fig_2.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig2.svg' % (figcount, startInputInclProb, startHiddenInclProb))

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=1.63e+00, acc(train)=7.21e-02, error(valid)=2.31e+00, acc(valid)=9.85e-02, params_penalty=0.00e+00
# all probs from model: 0.8, 0.1
# all probs from model: 0.801117318436, 0.105027932961
# all probs from model: 0.802234636872, 0.110055865922
# all probs from model: 0.803351955307, 0.115083798883
# all probs from model: 0.804469273743, 0.120111731844
# Epoch 5: 12.19s to complete
#   error(train)=1.10e+00, acc(train)=7.26e-01, error(valid)=1.07e+00, acc(valid)=7.53e-01, params_penalty=0.00e+00
# all probs from model: 0.805586592179, 0.125139664804
# all probs from model: 0.806703910615, 0.130167597765
# all probs from model: 0.80782122905, 0.135195530726
# all probs from model: 0.808938547486, 0.140223463687
# all probs from model: 0.810055865922, 0.145251396648
# Epoch 10: 13.29s to complete
#   error(train)=6.28e-01, acc(train)=8.28e-01, error(valid)=5.83e-01, acc(valid)=8.50e-01, params_penalty=0.00e+00
# all probs from model: 0.811173184358, 0.150279329609
# all probs from model: 0.812290502793, 0.15530726257
# all probs from model: 0.813407821229, 0.160335195531
# all probs from model: 0.814525139665, 0.165363128492
# all probs from model: 0.815642458101, 0.170391061453
# Epoch 15: 15.76s to complete
#   error(train)=4.60e-01, acc(train)=8.70e-01, error(valid)=4.23e-01, acc(valid)=8.83e-01, params_penalty=0.00e+00
# all probs from model: 0.816759776536, 0.175418994413
# all probs from model: 0.817877094972, 0.180446927374
# all probs from model: 0.818994413408, 0.185474860335
# all probs from model: 0.820111731844, 0.190502793296
# all probs from model: 0.821229050279, 0.195530726257
# Epoch 20: 14.33s to complete
#   error(train)=3.70e-01, acc(train)=8.94e-01, error(valid)=3.51e-01, acc(valid)=9.02e-01, params_penalty=0.00e+00
# all probs from model: 0.822346368715, 0.200558659218
# all probs from model: 0.823463687151, 0.205586592179
# all probs from model: 0.824581005587, 0.21061452514
# all probs from model: 0.825698324022, 0.215642458101
# all probs from model: 0.826815642458, 0.220670391061
# Epoch 25: 14.77s to complete
#   error(train)=3.17e-01, acc(train)=9.09e-01, error(valid)=2.92e-01, acc(valid)=9.19e-01, params_penalty=0.00e+00
# all probs from model: 0.827932960894, 0.225698324022
# all probs from model: 0.82905027933, 0.230726256983
# all probs from model: 0.830167597765, 0.235754189944
# all probs from model: 0.831284916201, 0.240782122905
# all probs from model: 0.832402234637, 0.245810055866
# Epoch 30: 14.37s to complete
#   error(train)=2.78e-01, acc(train)=9.21e-01, error(valid)=2.63e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# all probs from model: 0.833519553073, 0.250837988827
# all probs from model: 0.834636871508, 0.255865921788
# all probs from model: 0.835754189944, 0.260893854749
# all probs from model: 0.83687150838, 0.265921787709
# all probs from model: 0.837988826816, 0.27094972067
# Epoch 35: 14.33s to complete
#   error(train)=2.49e-01, acc(train)=9.29e-01, error(valid)=2.38e-01, acc(valid)=9.37e-01, params_penalty=0.00e+00
# all probs from model: 0.839106145251, 0.275977653631
# all probs from model: 0.840223463687, 0.281005586592
# all probs from model: 0.841340782123, 0.286033519553
# all probs from model: 0.842458100559, 0.291061452514
# all probs from model: 0.843575418994, 0.296089385475
# Epoch 40: 14.49s to complete
#   error(train)=2.26e-01, acc(train)=9.37e-01, error(valid)=2.14e-01, acc(valid)=9.41e-01, params_penalty=0.00e+00
# all probs from model: 0.84469273743, 0.301117318436
# all probs from model: 0.845810055866, 0.306145251397
# all probs from model: 0.846927374302, 0.311173184358
# all probs from model: 0.848044692737, 0.316201117318
# all probs from model: 0.849162011173, 0.321229050279
# Epoch 45: 18.48s to complete
#   error(train)=2.01e-01, acc(train)=9.42e-01, error(valid)=1.93e-01, acc(valid)=9.44e-01, params_penalty=0.00e+00
# all probs from model: 0.850279329609, 0.32625698324
# all probs from model: 0.851396648045, 0.331284916201
# all probs from model: 0.85251396648, 0.336312849162
# all probs from model: 0.853631284916, 0.341340782123
# all probs from model: 0.854748603352, 0.346368715084
# Epoch 50: 15.63s to complete
#   error(train)=1.81e-01, acc(train)=9.48e-01, error(valid)=1.84e-01, acc(valid)=9.49e-01, params_penalty=0.00e+00
# all probs from model: 0.855865921788, 0.351396648045
# all probs from model: 0.856983240223, 0.356424581006
# all probs from model: 0.858100558659, 0.361452513966
# all probs from model: 0.859217877095, 0.366480446927
# all probs from model: 0.860335195531, 0.371508379888
# Epoch 55: 15.09s to complete
#   error(train)=1.67e-01, acc(train)=9.53e-01, error(valid)=1.67e-01, acc(valid)=9.55e-01, params_penalty=0.00e+00
# all probs from model: 0.861452513966, 0.376536312849
# all probs from model: 0.862569832402, 0.38156424581
# all probs from model: 0.863687150838, 0.386592178771
# all probs from model: 0.864804469274, 0.391620111732
# all probs from model: 0.865921787709, 0.396648044693
# Epoch 60: 17.93s to complete
#   error(train)=1.54e-01, acc(train)=9.57e-01, error(valid)=1.58e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# all probs from model: 0.867039106145, 0.401675977654
# all probs from model: 0.868156424581, 0.406703910615
# all probs from model: 0.869273743017, 0.411731843575
# all probs from model: 0.870391061453, 0.416759776536
# all probs from model: 0.871508379888, 0.421787709497
# Epoch 65: 18.85s to complete
#   error(train)=1.37e-01, acc(train)=9.61e-01, error(valid)=1.46e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# all probs from model: 0.872625698324, 0.426815642458
# all probs from model: 0.87374301676, 0.431843575419
# all probs from model: 0.874860335196, 0.43687150838
# all probs from model: 0.875977653631, 0.441899441341
# all probs from model: 0.877094972067, 0.446927374302
# Epoch 70: 18.71s to complete
#   error(train)=1.26e-01, acc(train)=9.64e-01, error(valid)=1.42e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# all probs from model: 0.878212290503, 0.451955307263
# all probs from model: 0.879329608939, 0.456983240223
# all probs from model: 0.880446927374, 0.462011173184
# all probs from model: 0.88156424581, 0.467039106145
# all probs from model: 0.882681564246, 0.472067039106
# Epoch 75: 19.39s to complete
#   error(train)=1.16e-01, acc(train)=9.68e-01, error(valid)=1.32e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# all probs from model: 0.883798882682, 0.477094972067
# all probs from model: 0.884916201117, 0.482122905028
# all probs from model: 0.886033519553, 0.487150837989
# all probs from model: 0.887150837989, 0.49217877095
# all probs from model: 0.888268156425, 0.497206703911
# Epoch 80: 17.30s to complete
#   error(train)=1.06e-01, acc(train)=9.70e-01, error(valid)=1.23e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# all probs from model: 0.88938547486, 0.502234636872
# all probs from model: 0.890502793296, 0.507262569832
# all probs from model: 0.891620111732, 0.512290502793
# all probs from model: 0.892737430168, 0.517318435754
# all probs from model: 0.893854748603, 0.522346368715
# Epoch 85: 15.85s to complete
#   error(train)=1.00e-01, acc(train)=9.72e-01, error(valid)=1.18e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# all probs from model: 0.894972067039, 0.527374301676
# all probs from model: 0.896089385475, 0.532402234637
# all probs from model: 0.897206703911, 0.537430167598
# all probs from model: 0.898324022346, 0.542458100559
# all probs from model: 0.899441340782, 0.54748603352
# Epoch 90: 15.31s to complete
#   error(train)=9.06e-02, acc(train)=9.75e-01, error(valid)=1.15e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# all probs from model: 0.900558659218, 0.55251396648
# all probs from model: 0.901675977654, 0.557541899441
# all probs from model: 0.902793296089, 0.562569832402
# all probs from model: 0.903910614525, 0.567597765363
# all probs from model: 0.905027932961, 0.572625698324
# Epoch 95: 16.88s to complete
#   error(train)=8.10e-02, acc(train)=9.77e-01, error(valid)=1.15e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# all probs from model: 0.906145251397, 0.577653631285
# all probs from model: 0.907262569832, 0.582681564246
# all probs from model: 0.908379888268, 0.587709497207
# all probs from model: 0.909497206704, 0.592737430168
# all probs from model: 0.91061452514, 0.597765363128
# Epoch 100: 17.66s to complete
#   error(train)=7.67e-02, acc(train)=9.78e-01, error(valid)=1.09e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# all probs from model: 0.911731843575, 0.602793296089
# all probs from model: 0.912849162011, 0.60782122905
# all probs from model: 0.913966480447, 0.612849162011
# all probs from model: 0.915083798883, 0.617877094972
# all probs from model: 0.916201117318, 0.622905027933
# Epoch 105: 16.93s to complete
#   error(train)=6.75e-02, acc(train)=9.81e-01, error(valid)=1.08e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# all probs from model: 0.917318435754, 0.627932960894
# all probs from model: 0.91843575419, 0.632960893855
# all probs from model: 0.919553072626, 0.637988826816
# all probs from model: 0.920670391061, 0.643016759777
# all probs from model: 0.921787709497, 0.648044692737
# Epoch 110: 17.76s to complete
#   error(train)=6.11e-02, acc(train)=9.83e-01, error(valid)=1.00e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# all probs from model: 0.922905027933, 0.653072625698
# all probs from model: 0.924022346369, 0.658100558659
# all probs from model: 0.925139664804, 0.66312849162
# all probs from model: 0.92625698324, 0.668156424581
# all probs from model: 0.927374301676, 0.673184357542
# Epoch 115: 17.21s to complete
#   error(train)=5.71e-02, acc(train)=9.84e-01, error(valid)=1.03e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# all probs from model: 0.928491620112, 0.678212290503
# all probs from model: 0.929608938547, 0.683240223464
# all probs from model: 0.930726256983, 0.688268156425
# all probs from model: 0.931843575419, 0.693296089385
# all probs from model: 0.932960893855, 0.698324022346
# Epoch 120: 17.14s to complete
#   error(train)=5.06e-02, acc(train)=9.86e-01, error(valid)=9.10e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# all probs from model: 0.934078212291, 0.703351955307
# all probs from model: 0.935195530726, 0.708379888268
# all probs from model: 0.936312849162, 0.713407821229
# all probs from model: 0.937430167598, 0.71843575419
# all probs from model: 0.938547486034, 0.723463687151
# Epoch 125: 16.07s to complete
#   error(train)=4.49e-02, acc(train)=9.88e-01, error(valid)=9.39e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# all probs from model: 0.939664804469, 0.728491620112
# all probs from model: 0.940782122905, 0.733519553073
# all probs from model: 0.941899441341, 0.738547486034
# all probs from model: 0.943016759777, 0.743575418994
# all probs from model: 0.944134078212, 0.748603351955
# Epoch 130: 15.07s to complete
#   error(train)=4.10e-02, acc(train)=9.88e-01, error(valid)=9.37e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# all probs from model: 0.945251396648, 0.753631284916
# all probs from model: 0.946368715084, 0.758659217877
# all probs from model: 0.94748603352, 0.763687150838
# all probs from model: 0.948603351955, 0.768715083799
# all probs from model: 0.949720670391, 0.77374301676
# Epoch 135: 17.53s to complete
#   error(train)=3.69e-02, acc(train)=9.90e-01, error(valid)=9.65e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# all probs from model: 0.950837988827, 0.778770949721
# all probs from model: 0.951955307263, 0.783798882682
# all probs from model: 0.953072625698, 0.788826815642
# all probs from model: 0.954189944134, 0.793854748603
# all probs from model: 0.95530726257, 0.798882681564
# Epoch 140: 15.18s to complete
#   error(train)=3.15e-02, acc(train)=9.92e-01, error(valid)=9.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# all probs from model: 0.956424581006, 0.803910614525
# all probs from model: 0.957541899441, 0.808938547486
# all probs from model: 0.958659217877, 0.813966480447
# all probs from model: 0.959776536313, 0.818994413408
# all probs from model: 0.960893854749, 0.824022346369
# Epoch 145: 16.91s to complete
#   error(train)=2.74e-02, acc(train)=9.92e-01, error(valid)=9.06e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 0.962011173184, 0.82905027933
# all probs from model: 0.96312849162, 0.834078212291
# all probs from model: 0.964245810056, 0.839106145251
# all probs from model: 0.965363128492, 0.844134078212
# all probs from model: 0.966480446927, 0.849162011173
# Epoch 150: 17.47s to complete
#   error(train)=2.38e-02, acc(train)=9.94e-01, error(valid)=9.06e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# all probs from model: 0.967597765363, 0.854189944134
# all probs from model: 0.968715083799, 0.859217877095
# all probs from model: 0.969832402235, 0.864245810056
# all probs from model: 0.97094972067, 0.869273743017
# all probs from model: 0.972067039106, 0.874301675978
# Epoch 155: 17.60s to complete
#   error(train)=1.89e-02, acc(train)=9.95e-01, error(valid)=8.63e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 0.973184357542, 0.879329608939
# all probs from model: 0.974301675978, 0.884357541899
# all probs from model: 0.975418994413, 0.88938547486
# all probs from model: 0.976536312849, 0.894413407821
# all probs from model: 0.977653631285, 0.899441340782
# Epoch 160: 15.91s to complete
#   error(train)=1.61e-02, acc(train)=9.96e-01, error(valid)=8.82e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 0.978770949721, 0.904469273743
# all probs from model: 0.979888268156, 0.909497206704
# all probs from model: 0.981005586592, 0.914525139665
# all probs from model: 0.982122905028, 0.919553072626
# all probs from model: 0.983240223464, 0.924581005587
# Epoch 165: 17.78s to complete
#   error(train)=1.30e-02, acc(train)=9.97e-01, error(valid)=8.75e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# all probs from model: 0.984357541899, 0.929608938547
# all probs from model: 0.985474860335, 0.934636871508
# all probs from model: 0.986592178771, 0.939664804469
# all probs from model: 0.987709497207, 0.94469273743
# all probs from model: 0.988826815642, 0.949720670391
# Epoch 170: 15.59s to complete
#   error(train)=1.02e-02, acc(train)=9.98e-01, error(valid)=8.77e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# all probs from model: 0.989944134078, 0.954748603352
# all probs from model: 0.991061452514, 0.959776536313
# all probs from model: 0.99217877095, 0.964804469274
# all probs from model: 0.993296089385, 0.969832402235
# all probs from model: 0.994413407821, 0.974860335196
# Epoch 175: 14.99s to complete
#   error(train)=7.22e-03, acc(train)=9.98e-01, error(valid)=9.12e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# all probs from model: 0.995530726257, 0.979888268156
# all probs from model: 0.996648044693, 0.984916201117
# all probs from model: 0.997765363128, 0.989944134078
# all probs from model: 0.998882681564, 0.994972067039
# all probs from model: 1.0, 1.0
# Epoch 180: 15.12s to complete
#   error(train)=5.22e-03, acc(train)=9.99e-01, error(valid)=9.12e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 185: 15.08s to complete
#   error(train)=4.45e-03, acc(train)=9.99e-01, error(valid)=9.12e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 190: 15.08s to complete
#   error(train)=3.83e-03, acc(train)=9.99e-01, error(valid)=9.38e-02, acc(valid)=9.83e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 195: 15.21s to complete
#   error(train)=3.33e-03, acc(train)=9.99e-01, error(valid)=9.52e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 200: 18.97s to complete
#   error(train)=2.83e-03, acc(train)=9.99e-01, error(valid)=9.82e-02, acc(valid)=9.82e-01, params_penalty=0.00e+00
# figcount: 7
# runtime: 3312.20865393
# {'Final Testing Accuracy': 0.9820999999999992,
#  'Final Testing Error': 0.098154630284018191,
#  'Final Training Accuracy': 0.99938000000000038,
#  'Final Training Error': 0.0028349326601966609}

# %% [markdown]
# And yes here annealing dropout resulted in one the highest validation accuracies we have seen. We must note that we don’t expect annealing dropout to produce remarkable results in comparison to simple dropout nor that it is expected to yield a higher performance because it does nothing special in contributing to the architecture or the complexity or the simplicity of the model. However what annealing dropout does is maximize the potential of the model in hand by avoid the convergence towards local minima.
#
# Because Annealing Dropout is just a computationally intensive procedure it worths doing some experiments with fewer number of epochs and different initial inclusive probabilities to see if we can get the same good results but faster.

# %% [markdown]
# ### Starting input inclusive probability from 0.8 to 1
# ### Starting hidden layer inclusive probability from 0.5 to 1
# ### Percentage of epochs in the end where probability is equal to 1 constantly: 0.05
# ### Number of epochs 30
# ### Max Pooling size 4

# %%
holdOnPercent = 0.05

learningRate = 1e-4
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 30

# Size of pools to take maximum over
pool_size = 4

# Probability of input being included in output in dropout layer
startInputInclProb = 0.8 #different for input layer
startHiddenInclProb = 0.5 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #
    DropoutLayer(rng, startInputInclProb),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #
    DropoutLayer(rng, startHiddenInclProb),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        AnnealedDropoutScheduler(model = model,
                         startInputInclProb = startInputInclProb,
                         startHiddenInclProb = startHiddenInclProb,
                         epochs = numEpochs,
                         holdOnPercent=holdOnPercent)
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig1.svg' % (figcount, startInputInclProb, startHiddenInclProb))
fig_2.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig2.svg' % (figcount, startInputInclProb, startHiddenInclProb))

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.01e-01, params_penalty=0.00e+00
# all probs from model: 0.8, 0.5
# all probs from model: 0.807407407407, 0.518518518519
# all probs from model: 0.814814814815, 0.537037037037
# all probs from model: 0.822222222222, 0.555555555556
# all probs from model: 0.82962962963, 0.574074074074
# Epoch 5: 10.78s to complete
#   error(train)=2.37e-01, acc(train)=9.31e-01, error(valid)=2.23e-01, acc(valid)=9.39e-01, params_penalty=0.00e+00
# all probs from model: 0.837037037037, 0.592592592593
# all probs from model: 0.844444444444, 0.611111111111
# all probs from model: 0.851851851852, 0.62962962963
# all probs from model: 0.859259259259, 0.648148148148
# all probs from model: 0.866666666667, 0.666666666667
# Epoch 10: 12.33s to complete
#   error(train)=1.47e-01, acc(train)=9.56e-01, error(valid)=1.46e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# all probs from model: 0.874074074074, 0.685185185185
# all probs from model: 0.881481481481, 0.703703703704
# all probs from model: 0.888888888889, 0.722222222222
# all probs from model: 0.896296296296, 0.740740740741
# all probs from model: 0.903703703704, 0.759259259259
# Epoch 15: 14.73s to complete
#   error(train)=1.01e-01, acc(train)=9.70e-01, error(valid)=1.17e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# all probs from model: 0.911111111111, 0.777777777778
# all probs from model: 0.918518518519, 0.796296296296
# all probs from model: 0.925925925926, 0.814814814815
# all probs from model: 0.933333333333, 0.833333333333
# all probs from model: 0.940740740741, 0.851851851852
# Epoch 20: 13.36s to complete
#   error(train)=7.26e-02, acc(train)=9.79e-01, error(valid)=1.01e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# all probs from model: 0.948148148148, 0.87037037037
# all probs from model: 0.955555555556, 0.888888888889
# all probs from model: 0.962962962963, 0.907407407407
# all probs from model: 0.97037037037, 0.925925925926
# all probs from model: 0.977777777778, 0.944444444444
# Epoch 25: 13.57s to complete
#   error(train)=4.65e-02, acc(train)=9.87e-01, error(valid)=8.23e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# all probs from model: 0.985185185185, 0.962962962963
# all probs from model: 0.992592592593, 0.981481481481
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 30: 14.17s to complete
#   error(train)=2.95e-02, acc(train)=9.92e-01, error(valid)=7.77e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# runtime: 395.63371706
# {'Final Testing Accuracy': 0.97709999999999908,
#  'Final Testing Error': 0.077706504433064316,
#  'Final Training Accuracy': 0.99230000000000385,
#  'Final Training Error': 0.029451786118968395}

# %% [markdown]
# This experiment did not yield the expected results. Seems like 30 epochs is not slow enough for the model to go from simpler to more complex representations

# %% [markdown]
# ### Starting input inclusive probability from 0.8 to 1
# ### Starting hidden layer inclusive probability from 0.1 to 1
# ### Percentage of epochs in the end where probability is equal to 1 constantly: 0.05
# ### Number of epochs 50
# ### Max Pooling size 4

# %%
holdOnPercent = 0.05

learningRate = 1e-4
beta = 0.9
learningRule = RmsPropLearningRule(learning_rate=learningRate, beta=beta)

numEpochs = 50

# Size of pools to take maximum over
pool_size = 4

# Probability of input being included in output in dropout layer
startInputInclProb = 0.8 #different for input layer
startHiddenInclProb = 0.1 #than the rest of the layers

#####################

# Create three affine layer model interleaved with max-pooling layers
model = MultipleLayerModel([
    #
    DropoutLayer(rng, startInputInclProb),
    AffineLayer(input_dim, hidden_dim * pool_size, weights_init, biases_init), 
    MaxPoolingLayer(pool_size),
        
    #
    DropoutLayer(rng, startHiddenInclProb),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

stats, keys, runTime = trainModel(model=model, error=error,learning_rule=learningRule, train_data=trainData,
                                   valid_data=validData,num_epochs = numEpochs, stats_interval=statsInterval,
                                   schedulers = [
        AnnealedDropoutScheduler(model = model,
                         startInputInclProb = startInputInclProb,
                         startHiddenInclProb = startHiddenInclProb,
                         epochs = numEpochs,
                         holdOnPercent=holdOnPercent)
    ]
)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)
figcount += 1
fig_1.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig1.svg' % (figcount, startInputInclProb, startHiddenInclProb))
fig_2.savefig('experiment2_%02d_maxout_annealed_dropout_rmsProp_%.2f_%.2f_fig2.svg' % (figcount startInputInclProb, startHiddenInclProb))

print "figcount: " + str(figcount)
print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.32e+00, acc(train)=1.00e-01, error(valid)=2.32e+00, acc(valid)=1.04e-01, params_penalty=0.00e+00
# all probs from model: 0.8, 0.1
# all probs from model: 0.804347826087, 0.119565217391
# all probs from model: 0.808695652174, 0.139130434783
# all probs from model: 0.813043478261, 0.158695652174
# all probs from model: 0.817391304348, 0.178260869565
# Epoch 5: 11.49s to complete
#   error(train)=7.77e-01, acc(train)=7.99e-01, error(valid)=7.32e-01, acc(valid)=8.20e-01, params_penalty=0.00e+00
# all probs from model: 0.821739130435, 0.197826086957
# all probs from model: 0.826086956522, 0.217391304348
# all probs from model: 0.830434782609, 0.236956521739
# all probs from model: 0.834782608696, 0.25652173913
# all probs from model: 0.839130434783, 0.276086956522
# Epoch 10: 16.23s to complete
#   error(train)=3.74e-01, acc(train)=8.92e-01, error(valid)=3.35e-01, acc(valid)=9.04e-01, params_penalty=0.00e+00
# all probs from model: 0.84347826087, 0.295652173913
# all probs from model: 0.847826086957, 0.315217391304
# all probs from model: 0.852173913043, 0.334782608696
# all probs from model: 0.85652173913, 0.354347826087
# all probs from model: 0.860869565217, 0.373913043478
# Epoch 15: 14.65s to complete
#   error(train)=2.56e-01, acc(train)=9.25e-01, error(valid)=2.36e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# all probs from model: 0.865217391304, 0.39347826087
# all probs from model: 0.869565217391, 0.413043478261
# all probs from model: 0.873913043478, 0.432608695652
# all probs from model: 0.878260869565, 0.452173913043
# all probs from model: 0.882608695652, 0.471739130435
# Epoch 20: 13.64s to complete
#   error(train)=1.88e-01, acc(train)=9.44e-01, error(valid)=1.78e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# all probs from model: 0.886956521739, 0.491304347826
# all probs from model: 0.891304347826, 0.510869565217
# all probs from model: 0.895652173913, 0.530434782609
# all probs from model: 0.9, 0.55
# all probs from model: 0.904347826087, 0.569565217391
# Epoch 25: 15.56s to complete
#   error(train)=1.43e-01, acc(train)=9.58e-01, error(valid)=1.51e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# all probs from model: 0.908695652174, 0.589130434783
# all probs from model: 0.913043478261, 0.608695652174
# all probs from model: 0.917391304348, 0.628260869565
# all probs from model: 0.921739130435, 0.647826086957
# all probs from model: 0.926086956522, 0.667391304348
# Epoch 30: 18.11s to complete
#   error(train)=1.09e-01, acc(train)=9.68e-01, error(valid)=1.22e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# all probs from model: 0.930434782609, 0.686956521739
# all probs from model: 0.934782608696, 0.70652173913
# all probs from model: 0.939130434783, 0.726086956522
# all probs from model: 0.94347826087, 0.745652173913
# all probs from model: 0.947826086957, 0.765217391304
# Epoch 35: 16.97s to complete
#   error(train)=8.23e-02, acc(train)=9.76e-01, error(valid)=1.09e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# all probs from model: 0.952173913043, 0.784782608696
# all probs from model: 0.95652173913, 0.804347826087
# all probs from model: 0.960869565217, 0.823913043478
# all probs from model: 0.965217391304, 0.84347826087
# all probs from model: 0.969565217391, 0.863043478261
# Epoch 40: 20.00s to complete
#   error(train)=5.83e-02, acc(train)=9.83e-01, error(valid)=9.57e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# all probs from model: 0.973913043478, 0.882608695652
# all probs from model: 0.978260869565, 0.902173913043
# all probs from model: 0.982608695652, 0.921739130435
# all probs from model: 0.986956521739, 0.941304347826
# all probs from model: 0.991304347826, 0.960869565217
# Epoch 45: 19.83s to complete
#   error(train)=4.06e-02, acc(train)=9.89e-01, error(valid)=8.57e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# all probs from model: 0.995652173913, 0.980434782609
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# all probs from model: 1.0, 1.0
# Epoch 50: 17.91s to complete
#   error(train)=2.72e-02, acc(train)=9.93e-01, error(valid)=8.12e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# runtime: 821.790541172
# {'Final Testing Accuracy': 0.97949999999999904,
#  'Final Testing Error': 0.081238606177604145,
#  'Final Training Accuracy': 0.99300000000000366,
#  'Final Training Error': 0.027229031752991996}

# %% [markdown]
# Here we have not achieved any remarkable results in comparison to previous experiments but it is interesting to note that with 20 more epochs we were able to derive a better final model with higher validation accuracy than before. Note that here we have started from 0.1 initial inclusive probability for the hidden layers but this did not have any slowing-down or other unwanted effect.
# This experiment is a good indication that we should better start from lower probabilities rather than higher ones for the hidden layer.
