# %% [markdown]
# # Autoencoders
#
# In this notebook we will explore autoencoder models. These are models in which the inputs are *encoded* to some intermediate representation before this representation is then *decoded* to try to reconstruct the inputs. They are example of a model which uses an unsupervised training method and are both interesting as a model in their own right and as a method for pre-training useful representations to use in supervised tasks such as classification. Autoencoders were covered as a pre-training method in the [sixth lecture slides](http://www.inf.ed.ac.uk/teaching/courses/mlp/2016/mlp06-enc.pdf).

# %%
import sys
mlpdir = '/home/student/Dropbox/msc_Artificial_Intelligence/mlp_Machine_Learning_Practical/mlpractical'
sys.path.append(mlpdir)

# %%
import matplotlib.pyplot as plt
import numpy as np
import logging

#%matplotlib notebook
# %matplotlib inline

# %%
import mlp.layers as layers
import mlp.models as models
import mlp.optimisers as optimisers
import mlp.errors as errors
import mlp.learning_rules as learning_rules
import mlp.data_providers as data_providers
import mlp.initialisers as initialisers
import math

# %%
from mlp.data_providers import MNISTDataProvider, MNISTAutoencoderDataProvider, AugmentedMNISTDataProvider, \
    MNISTAutoencoderWithNoiseDataProvider

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer

from mlp.errors import CrossEntropySoftmaxError, SumOfSquaredDiffsError

from mlp.models import MultipleLayerModel

from mlp.initialisers import ConstantInit, GlorotUniformInit

from mlp.optimisers import Optimiser

from mlp.learning_rules import GradientDescentLearningRule, MomentumLearningRule, AdamLearningRule, \
    AdaGradLearningRule, RmsPropLearningRule
    
from mlp.schedulers import MomentumCoefficientScheduler, ConstantLearningRateScheduler,\
    ReciprocalLearningRateScheduler, ExponentialLearningRateScheduler

# %%
#seeding a random number generator
seed = 16011984
rng = np.random.RandomState(seed)

# %%
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# %%
def trainModel(model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, schedulers=[]):
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda outputs, targets: (outputs.argmax(-1) == targets.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, schedulers = schedulers)

    # Run the optimiser for some number of epochs (full passes through the training set)
    # printing statistics every epoch
    stats, keys, runTime = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)
    
    return stats, keys, runTime

# %%
def plotStats(stats, keys, stats_interval):
    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return fig_1, ax_1, fig_2, ax_2

# %%
def getFinalValues(statistics):
    lastStats = statistics[-1]
    return {
        "Final Training Error": lastStats[0],
        "Final Training Accuracy": lastStats[1],
        "Final Testing Error": lastStats[2],
        "Final Testing Accuracy": lastStats[3],
    }

# %%
#for autoencoders input has same dimensionality as output
inputOutputDim, hiddenDim = 784, 50

# %% [markdown]
# ## Exercise 1: Linear contractive autoencoders
#
# For the first exercise we will consider training a simple 'contractive' autoencoder - that is one in which the hidden representation is smaller in dimension than the input and the objective is to minimise the mean squared error between the original inputs and reconstructed inputs. To begin with we will consider models in which the encoder and decoder are both simple affine transformations.
#
# When training an autoencoder the target outputs for the model are the original inputs. A simple way to integrate this in to our `mlp` framework is to define a new data provider inheriting from a base data provider (e.g. `MNISTDataProvider`) which overrides the `next` method to return the inputs batch as both inputs and targets to the model. A data provider of this form has been provided for you in `mlp.data_providers` as `MNISTAutoencoderDataProvider`.
#
# Use this data provider to train an autoencoder model with a 50 dimensional hidden representation and both encoder and decoder defined by affine transformations. You should use a sum of squared differences error and a basic gradient descent learning rule with learning rate 0.01. Initialise the biases to zero and use a uniform Glorot initialisation for both layers weights. Train the model for 25 epochs with a batch size of 50.

# %%
error = SumOfSquaredDiffsError()

learningRate = 1e-2 #0.01
learningRule = GradientDescentLearningRule(learning_rate=learningRate)

numEpochs = 25

#initializing weights
weightsInit = GlorotUniformInit(rng=rng)
biasesInit = ConstantInit(0.)

# %%
trainData = MNISTAutoencoderDataProvider('train', batch_size=50, rng=rng)

# %%
model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit)
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1 #,schedulers = [ConstantLearningRateScheduler(learningRate)]
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=5.27e+01, acc(train)=6.80e-04, params_penalty=0.00e+00
# Epoch 1: 1.60s to complete
#   error(train)=7.65e+00, acc(train)=1.16e-02, params_penalty=0.00e+00
# Epoch 2: 1.65s to complete
#   error(train)=5.81e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 3: 1.62s to complete
#   error(train)=5.15e+00, acc(train)=1.40e-02, params_penalty=0.00e+00
# Epoch 4: 2.64s to complete
#   error(train)=4.89e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 5: 1.57s to complete
#   error(train)=4.77e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 6: 1.70s to complete
#   error(train)=4.72e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 7: 2.17s to complete
#   error(train)=4.69e+00, acc(train)=1.36e-02, params_penalty=0.00e+00
# Epoch 8: 2.35s to complete
#   error(train)=4.68e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 9: 2.33s to complete
#   error(train)=4.66e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 10: 1.97s to complete
#   error(train)=4.66e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 11: 2.58s to complete
#   error(train)=4.65e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 12: 2.58s to complete
#   error(train)=4.64e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 13: 2.66s to complete
#   error(train)=4.64e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 14: 1.80s to complete
#   error(train)=4.63e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 15: 1.55s to complete
#   error(train)=4.63e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 16: 1.73s to complete
#   error(train)=4.63e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 17: 3.02s to complete
#   error(train)=4.63e+00, acc(train)=1.38e-02, params_penalty=0.00e+00
# Epoch 18: 1.54s to complete
#   error(train)=4.62e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 19: 1.56s to complete
#   error(train)=4.65e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 20: 1.63s to complete
#   error(train)=4.62e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 21: 2.97s to complete
#   error(train)=4.62e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 22: 1.62s to complete
#   error(train)=4.62e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 23: 1.61s to complete
#   error(train)=4.62e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 24: 1.67s to complete
#   error(train)=4.62e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 25: 2.54s to complete
#   error(train)=4.61e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# runtime: 84.5751230717

# %% [markdown]
# Using the function defined in the cell below (from the first lab notebook), plot a batch of the original images and the autoencoder reconstructions.

# %%
def show_batch_of_images(img_batch, fig_size=(3, 3), num_rows=None):
    fig = plt.figure(figsize=fig_size)
    batch_size, im_height, im_width = img_batch.shape
    if num_rows is None:
        # calculate grid dimensions to give square(ish) grid
        num_rows = int(batch_size**0.5)
    num_cols = int(batch_size * 1. / num_rows)
    if num_rows * num_cols < batch_size:
        num_cols += 1
    # intialise empty array to tile image grid into
    tiled = np.zeros((im_height * num_rows, im_width * num_cols))
    # iterate over images in batch + indexes within batch
    for i, img in enumerate(img_batch):
        # calculate grid row and column indices
        r, c = i % num_rows, i // num_rows
        tiled[r * im_height:(r + 1) * im_height, 
              c * im_height:(c + 1) * im_height] = img
    ax = fig.add_subplot(111)
    ax.imshow(tiled, cmap='Greys', vmin=0., vmax=1.)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

# %% [markdown]
# Let's take some inputs from the training data

# %%
inputs, targets = trainData.next()

# %%
assert np.all(inputs == targets), "for the experiment with autoencoders inputs and targets must be the same"

# %%
inputs.shape
# Out:
# (50, 784)

# %%
imgSide = int(math.sqrt(inputs.shape[1]))

# %%
originalImgBatch = inputs.reshape(inputs.shape[:1] + (imgSide,imgSide))

# %%
activationsOfAllLayers = model.fprop(inputs)

# %%
activationsOfAllLayers[0].shape,activationsOfAllLayers[1].shape,activationsOfAllLayers[2].shape,
# Out:
# ((50, 784), (50, 50), (50, 784))

# %%
assert np.all(activationsOfAllLayers[0] == inputs), "fprop must return as first item of the activations list the inputs"

# %%
encodedVectors = activationsOfAllLayers[-1]

# %%
encodedImgBatch = encodedVectors.reshape(encodedVectors.shape[:1] + (imgSide, imgSide))

# %%
print "these are the original images"
show_batch_of_images(originalImgBatch)
# Out:
# these are the original images
# (<matplotlib.figure.Figure at 0x7f4cad7840d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f4cad784b90>)

# %%
print "these are the decoded images after passing from the autoencoder of dimensionality %d" % hiddenDim
show_batch_of_images(encodedImgBatch)
# Out:
# these are the decoded images after passing from the autoencoder of dimensionality 50
# (<matplotlib.figure.Figure at 0x7f4cad7e4e90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f4cad75ae10>)

# %% [markdown]
# ### Optional extension: principle components analysis
#
# *This section is provided for the interest of those also sitting MLPR or otherwise already familiar with eigendecompositions and PCA. Feel free to skip over if this doesn't apply to you (or even if it does).*
#
# For a linear (affine) contractive autoencoder model trained with a sum of squared differences error function there is an analytic solution for the optimal model parameters corresponding to [principle components analysis](https://en.wikipedia.org/wiki/Principal_component_analysis).
#
# If we have a training dataset of $N$ $D$-dimensional vectors $\left\lbrace \boldsymbol{x}^{(n)} \right\rbrace_{n=1}^N$, then we can calculate the empiricial mean and covariance of the training data using
#
# \begin{equation}
#   \boldsymbol{\mu} = \frac{1}{N} \sum_{n=1}^N \left[ \boldsymbol{x}^{(n)} \right]
#   \qquad
#   \text{and}
#   \qquad
#   \mathbf{\Sigma} = \frac{1}{N}
#   \sum_{n=1}^N \left[
#     \left(\boldsymbol{x}^{(n)} - \boldsymbol{\mu} \right)
#     \left(\boldsymbol{x}^{(n)} - \boldsymbol{\mu} \right)^{\rm T}
#   \right].
# \end{equation}
#
# We can then calculate an [eigendecomposition](https://en.wikipedia.org/wiki/Eigendecomposition_of_a_matrix) of the covariance matrix
# \begin{equation}
#   \mathbf{\Sigma} = \mathbf{Q} \mathbf{\Lambda} \mathbf{Q}^{\rm T}
#   \qquad
#   \mathbf{Q} = \left[
#   \begin{array}{cccc}
#   \uparrow & \uparrow & \cdots & \uparrow \\
#   \boldsymbol{q}_1 & \boldsymbol{q}_2 & \cdots & \boldsymbol{q}_D \\
#   \downarrow & \downarrow & \cdots & \downarrow \\
#   \end{array}
#   \right]
#   \qquad
#   \mathbf{\Lambda} = \left[
#   \begin{array}{cccc}
#   \lambda_1 & 0 & \cdots & 0 \\
#   0 & \lambda_2 & \cdots & \vdots \\
#   \vdots & \vdots & \ddots & 0 \\
#   0 & 0 & \cdots & \lambda_D \\
#   \end{array} \right]
# \end{equation}
#
# with $\mathbf{Q}$ an orthogonal matrix, $\mathbf{Q}\mathbf{Q}^{\rm T} = \mathbf{I}$, with columns $\left\lbrace \boldsymbol{q}_d \right\rbrace_{d=1}^D$ corresponding to the eigenvectors of $\mathbf{\Sigma}$ and $\mathbf{\Lambda}$ a diagonal matrix with diagonal elements $\left\lbrace \lambda_d \right\rbrace_{d=1}^D$ the corresponding eigenvalues of $\mathbf{\Sigma}$.
#
# Assuming the eigenvalues are ordered such that $\lambda_1 < \lambda_2 < \dots < \lambda_D$ then the top $K$ principle components of the inputs (eigenvectors with largest eigenvalues) correspond to $\left\lbrace \boldsymbol{q}_d \right\rbrace_{d=D + 1 - K}^D$. If we define a $D \times K$ matrix $\mathbf{V} = \left[ \boldsymbol{q}_{D + 1 - K} ~ \boldsymbol{q}_{D + 2 - K} ~\cdots~ \boldsymbol{q}_D \right]$ then we can find the projections of a (mean normalised) input vector on to the selected $K$ principle components as $\boldsymbol{h} = \mathbf{V}^{\rm T}\left( \boldsymbol{x} - \boldsymbol{\mu}\right)$. We can then use these principle component projections to form a reconstruction of the original input just in terms of the $K$ top principle components using $\boldsymbol{r} = \mathbf{V} \boldsymbol{h} + \boldsymbol{\mu}$. We can see that this is just a sequence of two affine transformations and so is directly analagous to a model with two affine layers and with $K$ dimensional outputs of the first layer / inputs to second.
#
# The function defined in the cell below will calculate the PCA solution for a set of input vectors and a defined number of components $K$. Use it to calculate the top 50 principle components of the MNIST training data. Use the returned matrix and mean vector to calculate the PCA based reconstructions of a batch of 50 MNIST images and use the `show_batch_of_images` function to plot both the original and reconstructed inputs alongside each other. Also calculate the sum of squared differences error for the PCA solution on the MNIST training set and compare to the figure you got by gradient descent based training above. Will the gradient based training produce the same hidden representations as the PCA solution if it is trained to convergence?

# %%
def get_pca_parameters(inputs, num_components=50):
    mean = inputs.mean(0)
    inputs_zm = inputs - mean[None, :]
    covar = np.einsum('ij,ik', inputs_zm, inputs_zm)
    eigvals, eigvecs = np.linalg.eigh(covar)
    return eigvecs[:, -num_components:], mean

# %% [markdown]
# ## Exercise 2: Non-linear contractive autoencoders
#
# Those who did the extension in the previous exercise will have just seen that for an autoencoder with both linear / affine encoder and decoders, there is an analytic solution for the parameters which minimise a sum of squared differences error.
#
# In general the advantage of using gradient-based training methods is that it allows us to use non-linear models for which there is no analytic solution for the optimal parameters. The hope is the use of non-linear transformations between the affine transformation layers will increase the representational power of the model (a sequence of affine transformations applied without any interleaving non-linear operations can always be represented by a single affine transformation).
#
# Train a contractive autoencoder with an initial affine layer (output dimension again 50) followed by a rectified linear layer, then an affine transformation projecting to outputs of same dimension as the original inputs, and finally a logistic sigmoid layer at the output. As the only layers with parameters are the two affine layers which have the same dimensions as in the fully affine model above, the overall model here has the same number of parameters as previously.
#
# Again train for 25 epochs with 50 training examples per batch and use a uniform Glorot initialisation for the weights, and zero biases initialisation. Use our implementation of the 'Adam' adaptive moments learning rule (available in `mlp.learning_rules` as `AdamLearningRule`) rather than basic gradient descent here (the adaptivity helps deal with the varying appropriate scale of updates induced by the non-linear transformations in this model).

# %% [markdown]
# ### My notes:
# a sequence of affine transformations applied without any interleaving non-linear operations can always be represented by a single affine transformation. This is what prof Murray was saying about having linear matrices multiplied together can be represented by a single matrix after all (if non-linearities are not used)

# %%
#Affine -> ReLU -> Affine -> Sigmoid

# %%
#for autoencoders input has same dimensionality as output
inputOutputDim, hiddenDim = 784, 50

error = SumOfSquaredDiffsError()

learningRule = AdamLearningRule() # default params

numEpochs = 25

#initializing weights
weightsInit = GlorotUniformInit(rng=rng)
biasesInit = ConstantInit(0.)

# %%
trainData = MNISTAutoencoderDataProvider('train', batch_size=50, rng=rng)

# %%
model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    #ReluLayer(),
    SigmoidLayer(),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
    SigmoidLayer()
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=9.23e+01, acc(train)=2.00e-05, params_penalty=0.00e+00
# Epoch 1: 3.72s to complete
#   error(train)=2.37e+01, acc(train)=1.48e-02, params_penalty=0.00e+00
# Epoch 2: 4.10s to complete
#   error(train)=1.75e+01, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 3: 4.16s to complete
#   error(train)=1.45e+01, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 4: 3.35s to complete
#   error(train)=1.22e+01, acc(train)=1.15e-02, params_penalty=0.00e+00
# Epoch 5: 3.40s to complete
#   error(train)=1.08e+01, acc(train)=1.11e-02, params_penalty=0.00e+00
# Epoch 6: 3.58s to complete
#   error(train)=9.86e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 7: 3.33s to complete
#   error(train)=9.10e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 8: 3.61s to complete
#   error(train)=8.59e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 9: 3.47s to complete
#   error(train)=8.19e+00, acc(train)=1.16e-02, params_penalty=0.00e+00
# Epoch 10: 3.22s to complete
#   error(train)=7.71e+00, acc(train)=1.23e-02, params_penalty=0.00e+00
# Epoch 11: 3.40s to complete
#   error(train)=6.81e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 12: 4.42s to complete
#   error(train)=5.65e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 13: 4.68s to complete
#   error(train)=4.73e+00, acc(train)=1.27e-02, params_penalty=0.00e+00
# Epoch 14: 3.61s to complete
#   error(train)=4.15e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 15: 3.32s to complete
#   error(train)=3.78e+00, acc(train)=1.44e-02, params_penalty=0.00e+00
# Epoch 16: 3.17s to complete
#   error(train)=3.52e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 17: 3.50s to complete
#   error(train)=3.34e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 18: 3.13s to complete
#   error(train)=3.21e+00, acc(train)=1.38e-02, params_penalty=0.00e+00
# Epoch 19: 3.26s to complete
#   error(train)=3.10e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 20: 3.23s to complete
#   error(train)=3.00e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 21: 3.98s to complete
#   error(train)=2.93e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 22: 4.97s to complete
#   error(train)=2.87e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 23: 3.60s to complete
#   error(train)=2.81e+00, acc(train)=1.35e-02, params_penalty=0.00e+00
# Epoch 24: 5.42s to complete
#   error(train)=2.77e+00, acc(train)=1.35e-02, params_penalty=0.00e+00
# Epoch 25: 3.35s to complete
#   error(train)=2.72e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# runtime: 140.551300049

# %% [markdown]
# Plot batches of the inputs and reconstructed inputs for this non-linear contractive autoencoder model and compare to the corresponding plots for the linear models above.

# %%
def getOriginalAndEncodedBatches(dataProvider, model, noisy=False):
    inputs, targets = dataProvider.next()
    if not noisy:
        assert np.all(inputs == targets), "for the experiment with autoencoders inputs and targets must be the same"
    imgSide = int(math.sqrt(inputs.shape[1]))
    imgShape = (imgSide, imgSide)
    batchSize = inputs.shape[:1]
    originalImgBatch = inputs.reshape(batchSize + imgShape)
    activationsOfAllLayers = model.fprop(inputs)
    assert np.all(activationsOfAllLayers[0] == inputs), "fprop must return as first item of the activations list the inputs"
    codecVectors = activationsOfAllLayers[-1]
    assert codecVectors.shape[:1] == batchSize
    codecImgBatch = codecVectors.reshape(batchSize + imgShape)
    return originalImgBatch, codecImgBatch

# %%
origImgBatch, codecImgBatch = getOriginalAndEncodedBatches(dataProvider=trainData, model=model)

# %%
print "original images"
show_batch_of_images(origImgBatch)
# Out:
# original images
# (<matplotlib.figure.Figure at 0x7f4cad647350>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f4cad690ed0>)

# %%
print "decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality %d" % hiddenDim
show_batch_of_images(codecImgBatch)
# Out:
# decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality 50
# (<matplotlib.figure.Figure at 0x7f4cac568190>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f4cad7e4fd0>)

# %% [markdown]
# It is obvious to the bare eye that the non-linearities has allowed better representation of the autoencoder of the original digit. The digits now look less blurry, more sharpened and generally more clear than on the first experiment. This is a clear indication to us that the digits are reprensentated better with the autoencoder of dimensionality 50 where the non-linearities are included

# %% [markdown]
# ## Exercise 3: Denoising autoencoders
#
# So far we have just considered autoencoders that try to reconstruct the input vector fed into them via some intermediate lower-dimensional 'contracted' representation. The contraction is important as if we were to maintain the input dimensionality in all layers of the model a trivial optima for the model to learn would be to apply an identity transformation at each layer.
#
# It can be desirable for the intermediate hidden representation to be robust to noise in the input. The intuition is that this will force the model to learn to maintain the 'important structure' in the input in the hidden representation (that needed to reconstruct the input). This also removes the requirement to have a contracted hidden representation (as the model can no longer simply learn to apply an identity transformation) though in practice we will still often use a lower-dimensional hidden representation as we believe there is a certain level of redundancy in the input data and so the important structure can be represented with a lower dimensional representation.
#
# Create a new data provider object which adds noise to the inputs to an autoencoder in each batch it returns. There are various different ways you could introduce noise. The three suggested in the lecture slides are
#
#   * *Gaussian*: add independent, zero-mean Gaussian noise of a fixed standard-deviation to each dimension of the input vectors.
#   * *Masking*: generate a random binary mask and perform an elementwise multiplication with each input (forcing some subset of the values to zero).
#   * *Salt and pepper*: select a random subset of values in each input and randomly assign either zero or one to them.
#
# You should choose one of these noising schemes to implement. It may help to know that the base `DataProvider` object already has access to a random number generator object as its `self.rng` attribute.

# %% [markdown]
# ### My notes
# This is important: we will still often use a lower-dimensional hidden representation as we believe there is a certain level of redundancy in the input data and so the important structure can be represented with a lower dimensional representation. Because in general the input is represented with lower dimensionality than it is store

# %% [markdown]
# Let's try and add some noise to the data and see how the images look like

# %%
def imageBatchVectorTo2D(vectors):
    return vectors.reshape(vectors.shape[:1] + \
                           ( int(math.sqrt(vectors.shape[1])), int(math.sqrt(vectors.shape[1])) ))
    
def imageBatch2DtoVector(imgs):
    return imgs.reshape(imgs.shape[:1] + (imgs.shape[1]**2,))

# %%
inputs, targets = trainData.next()
inputs.shape, targets.shape
# Out:
# ((50, 784), (50, 784))

# %%
std = 2

# %%
def addGaussianNoise(vectors, std=1, rng=np.random):
    return vectors + std*rng.randn(vectors.shape[0],vectors.shape[1])

# %%
show_batch_of_images(imageBatchVectorTo2D(inputs))
# Out:
# (<matplotlib.figure.Figure at 0x7fcd3c7d6b50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c7cd150>)

# %%
show_batch_of_images(imageBatchVectorTo2D( addGaussianNoise(inputs, std=0.5, rng=rng)))
# Out:
# (<matplotlib.figure.Figure at 0x7fcd3e1d9e90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c78af10>)

# %%
show_batch_of_images(imageBatchVectorTo2D( addGaussianNoise(inputs, std=0.3, rng=rng)))
# Out:
# (<matplotlib.figure.Figure at 0x7fcd3c8be790>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c8a9f50>)

# %% [markdown]
# Standard deviation of 0.3 for the gaussian noise of zero means seems like a good amount of noise visually with a bare eye

# %% [markdown]
# Once you have implemented your chosen scheme, use the new data provider object to train a denoising autoencoder with the same model architecture as in exercise 2.

# %% [markdown]
# Use the `show_batch_of_images` function from above to visualise a batch of noisy inputs from your data provider implementation and the denoised reconstructions from your trained denoising autoencoder.

# %%
#for autoencoders input has same dimensionality as output
inputOutputDim, hiddenDim = 784, 50

error = SumOfSquaredDiffsError()

learningRule = AdamLearningRule() # default params

numEpochs = 25

#initializing weights
weightsInit = GlorotUniformInit(rng=rng)
biasesInit = ConstantInit(0.)

# %% [markdown]
# ### Noise with std = 0.3

# %%
trainData = MNISTAutoencoderWithNoiseDataProvider('train', batch_size=50, rng=rng, std=0.3)

model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    ReluLayer(),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
    SigmoidLayer()
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=9.11e+01, acc(train)=1.46e-03, params_penalty=0.00e+00
# Epoch 1: 5.87s to complete
#   error(train)=8.41e+00, acc(train)=1.10e-02, params_penalty=0.00e+00
# Epoch 2: 5.75s to complete
#   error(train)=5.69e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 3: 5.26s to complete
#   error(train)=4.84e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 4: 5.29s to complete
#   error(train)=4.51e+00, acc(train)=1.19e-02, params_penalty=0.00e+00
# Epoch 5: 5.17s to complete
#   error(train)=4.43e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 6: 5.39s to complete
#   error(train)=4.36e+00, acc(train)=1.40e-02, params_penalty=0.00e+00
# Epoch 7: 5.50s to complete
#   error(train)=4.34e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 8: 5.50s to complete
#   error(train)=4.32e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 9: 5.13s to complete
#   error(train)=4.31e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 10: 5.02s to complete
#   error(train)=4.30e+00, acc(train)=1.27e-02, params_penalty=0.00e+00
# Epoch 11: 5.05s to complete
#   error(train)=4.28e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 12: 5.14s to complete
#   error(train)=4.26e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 13: 6.41s to complete
#   error(train)=4.25e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 14: 5.22s to complete
#   error(train)=4.25e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 15: 5.36s to complete
#   error(train)=4.23e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 16: 5.21s to complete
#   error(train)=4.24e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 17: 5.37s to complete
#   error(train)=4.24e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 18: 6.13s to complete
#   error(train)=4.21e+00, acc(train)=1.33e-02, params_penalty=0.00e+00
# Epoch 19: 6.36s to complete
#   error(train)=4.22e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 20: 5.88s to complete
#   error(train)=4.22e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 21: 5.31s to complete
#   error(train)=4.22e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 22: 5.46s to complete
#   error(train)=4.21e+00, acc(train)=1.36e-02, params_penalty=0.00e+00
# Epoch 23: 5.70s to complete
#   error(train)=4.25e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 24: 5.15s to complete
#   error(train)=4.22e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 25: 5.29s to complete
#   error(train)=4.23e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# runtime: 234.219007969

# %%
origImgBatch, codecImgBatch = getOriginalAndEncodedBatches(dataProvider=trainData, model=model, noisy=True)

# %%
print "original images"
show_batch_of_images(origImgBatch)
# Out:
# original images
# (<matplotlib.figure.Figure at 0x7fcd3c5d1dd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c5d1c90>)

# %%
print "decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality %d" % hiddenDim
show_batch_of_images(codecImgBatch)
# Out:
# decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality 50
# (<matplotlib.figure.Figure at 0x7fcd3c656250>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c64dd90>)

# %% [markdown]
# We see that we have achieved very good denoising and the features are represented much better with zero noise. Let's try more and less noise and see what happens

# %% [markdown]
# ### Noise with std = 0.1

# %%
trainData = MNISTAutoencoderWithNoiseDataProvider('train', batch_size=50, rng=rng, std=0.1)

model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    ReluLayer(),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
    SigmoidLayer()
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=9.10e+01, acc(train)=7.00e-04, params_penalty=0.00e+00
# Epoch 1: 5.46s to complete
#   error(train)=7.18e+00, acc(train)=1.01e-02, params_penalty=0.00e+00
# Epoch 2: 5.25s to complete
#   error(train)=4.08e+00, acc(train)=1.16e-02, params_penalty=0.00e+00
# Epoch 3: 5.40s to complete
#   error(train)=3.11e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 4: 5.33s to complete
#   error(train)=2.80e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 5: 6.44s to complete
#   error(train)=2.72e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 6: 5.47s to complete
#   error(train)=2.62e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 7: 5.52s to complete
#   error(train)=2.59e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 8: 5.11s to complete
#   error(train)=2.55e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 9: 7.43s to complete
#   error(train)=2.54e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 10: 7.61s to complete
#   error(train)=2.53e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 11: 5.04s to complete
#   error(train)=2.53e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 12: 5.33s to complete
#   error(train)=2.50e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 13: 5.57s to complete
#   error(train)=2.48e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 14: 5.25s to complete
#   error(train)=2.48e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 15: 5.16s to complete
#   error(train)=2.48e+00, acc(train)=1.31e-02, params_penalty=0.00e+00
# Epoch 16: 5.72s to complete
#   error(train)=2.46e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 17: 5.56s to complete
#   error(train)=2.45e+00, acc(train)=1.15e-02, params_penalty=0.00e+00
# Epoch 18: 5.11s to complete
#   error(train)=2.46e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 19: 5.54s to complete
#   error(train)=2.45e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 20: 5.36s to complete
#   error(train)=2.44e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 21: 5.21s to complete
#   error(train)=2.44e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 22: 5.83s to complete
#   error(train)=2.43e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 23: 5.00s to complete
#   error(train)=2.44e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 24: 6.97s to complete
#   error(train)=2.42e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 25: 5.10s to complete
#   error(train)=2.42e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# runtime: 236.328704119

# %%
origImgBatch, codecImgBatch = getOriginalAndEncodedBatches(dataProvider=trainData, model=model, noisy=True)

# %%
print "original images"
show_batch_of_images(origImgBatch)
# Out:
# original images
# (<matplotlib.figure.Figure at 0x7fcd3c516550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c516390>)

# %%
print "decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality %d" % hiddenDim
show_batch_of_images(codecImgBatch)
# Out:
# decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality 50
# (<matplotlib.figure.Figure at 0x7fcd3c4952d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c56d650>)

# %% [markdown]
# As expected with fewer noise the results are better than the previous experiment

# %% [markdown]
# ### Noise with std = 0.5

# %%
trainData = MNISTAutoencoderWithNoiseDataProvider('train', batch_size=50, rng=rng, std=0.5)

model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    ReluLayer(),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
    SigmoidLayer()
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=9.13e+01, acc(train)=1.10e-03, params_penalty=0.00e+00
# Epoch 1: 5.24s to complete
#   error(train)=1.02e+01, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 2: 5.13s to complete
#   error(train)=7.81e+00, acc(train)=1.13e-02, params_penalty=0.00e+00
# Epoch 3: 5.68s to complete
#   error(train)=7.13e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 4: 5.12s to complete
#   error(train)=6.90e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 5: 5.34s to complete
#   error(train)=6.83e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 6: 6.91s to complete
#   error(train)=6.79e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 7: 5.62s to complete
#   error(train)=6.73e+00, acc(train)=1.11e-02, params_penalty=0.00e+00
# Epoch 8: 6.19s to complete
#   error(train)=6.71e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 9: 7.10s to complete
#   error(train)=6.68e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 10: 8.07s to complete
#   error(train)=6.70e+00, acc(train)=1.14e-02, params_penalty=0.00e+00
# Epoch 11: 5.41s to complete
#   error(train)=6.67e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 12: 9.04s to complete
#   error(train)=6.67e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 13: 7.38s to complete
#   error(train)=6.68e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 14: 9.21s to complete
#   error(train)=6.65e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 15: 10.01s to complete
#   error(train)=6.65e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 16: 9.25s to complete
#   error(train)=6.63e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 17: 10.23s to complete
#   error(train)=6.64e+00, acc(train)=1.23e-02, params_penalty=0.00e+00
# Epoch 18: 9.14s to complete
#   error(train)=6.64e+00, acc(train)=1.27e-02, params_penalty=0.00e+00
# Epoch 19: 10.43s to complete
#   error(train)=6.60e+00, acc(train)=1.16e-02, params_penalty=0.00e+00
# Epoch 20: 9.16s to complete
#   error(train)=6.60e+00, acc(train)=1.21e-02, params_penalty=0.00e+00
# Epoch 21: 8.99s to complete
#   error(train)=6.61e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 22: 9.81s to complete
#   error(train)=6.59e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 23: 10.55s to complete
#   error(train)=6.61e+00, acc(train)=1.19e-02, params_penalty=0.00e+00
# Epoch 24: 11.36s to complete
#   error(train)=6.62e+00, acc(train)=1.20e-02, params_penalty=0.00e+00
# Epoch 25: 12.36s to complete
#   error(train)=6.61e+00, acc(train)=1.15e-02, params_penalty=0.00e+00
# runtime: 343.48202014

# %%
origImgBatch, codecImgBatch = getOriginalAndEncodedBatches(dataProvider=trainData, model=model, noisy=True)

# %%
print "original images"
show_batch_of_images(origImgBatch)
# Out:
# original images
# (<matplotlib.figure.Figure at 0x7fcd3c38ecd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c3857d0>)

# %%
print "decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality %d" % hiddenDim
show_batch_of_images(codecImgBatch)
# Out:
# decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality 50
# (<matplotlib.figure.Figure at 0x7fcd3c4a1450>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c34e290>)

# %% [markdown]
# The auto-encoder here had a much harder time to be able and get the essense out of the number but it did. Most of the noise is cancelled out and even numbers that were difficult to be distinguished by a bare eye due to too much noise are now clear and sharp.

# %% [markdown]
# ## Exercise 4: Using an autoencoder as an initialisation for supervised training

# %% [markdown]
# As a final exercise we will use the first layer of an autoencoder for MNIST digit images as a layer within a multiple layer model trained to do digit classification. The intuition behind pretraining methods like this is that the hidden representations learnt by an autoencoder should be a more useful representation for training a classifier than the raw pixel values themselves. We could fix the parameters in the layers taken from the autoencoder but generally we can get better performance by letting the whole model be trained end-to-end on the supervised training task, with the learnt autoencoder parameters in this case acting as a potentially more intelligent initialisation than randomly sampling the parameters which can help ease some of the optimisation issues encountered due to poor initialisation of a model.
#
# You can either use one of the autoencoder models you trained in the previous exercises, or train a new autoencoder model for specifically for this exercise. Create a new model object (instance of `mlp.models.MultipleLayerModel`) in which the first layer(s) of the list of layer passed to the model constructor are the trained first layer(s) from your autoencoder model (these can be accessed via the `layers` attribute which is a list of all the layers in a model). Add any additional layers you wish to the pretrained layers - at the very least you will need to add an output layer with output dimension 10 to allow the model to be used to predict class labels. Train this new model on the original MNIST image, digit labels pairs with a cross entropy error.

# %% [markdown]
# ### Noise with std = 0.2

# %%
trainData = MNISTAutoencoderWithNoiseDataProvider('train', batch_size=50, rng=rng, std=0.2)

model = MultipleLayerModel([
    AffineLayer(inputOutputDim, hiddenDim, weightsInit, biasesInit),
    ReluLayer(),
    AffineLayer(hiddenDim, inputOutputDim, weightsInit, biasesInit),
    SigmoidLayer()
])

stats, keys, runTime = trainModel(
    model=model,
    error=error, 
    learning_rule = learningRule,
    train_data = trainData,
    valid_data = None,
    num_epochs = numEpochs,
    stats_interval = 1
)

print "runtime: " + str(runTime)
# Out:
# Epoch 0:
#   error(train)=9.06e+01, acc(train)=9.00e-04, params_penalty=0.00e+00
# Epoch 1: 9.58s to complete
#   error(train)=7.77e+00, acc(train)=1.15e-02, params_penalty=0.00e+00
# Epoch 2: 8.44s to complete
#   error(train)=4.82e+00, acc(train)=1.18e-02, params_penalty=0.00e+00
# Epoch 3: 9.50s to complete
#   error(train)=3.81e+00, acc(train)=1.19e-02, params_penalty=0.00e+00
# Epoch 4: 9.45s to complete
#   error(train)=3.51e+00, acc(train)=1.22e-02, params_penalty=0.00e+00
# Epoch 5: 7.93s to complete
#   error(train)=3.40e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# Epoch 6: 10.76s to complete
#   error(train)=3.35e+00, acc(train)=1.29e-02, params_penalty=0.00e+00
# Epoch 7: 9.56s to complete
#   error(train)=3.34e+00, acc(train)=1.20e-02, params_penalty=0.00e+00
# Epoch 8: 8.40s to complete
#   error(train)=3.30e+00, acc(train)=1.24e-02, params_penalty=0.00e+00
# Epoch 9: 8.29s to complete
#   error(train)=3.28e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 10: 7.90s to complete
#   error(train)=3.28e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 11: 9.82s to complete
#   error(train)=3.26e+00, acc(train)=1.23e-02, params_penalty=0.00e+00
# Epoch 12: 9.66s to complete
#   error(train)=3.25e+00, acc(train)=1.30e-02, params_penalty=0.00e+00
# Epoch 13: 9.68s to complete
#   error(train)=3.24e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 14: 9.11s to complete
#   error(train)=3.22e+00, acc(train)=1.35e-02, params_penalty=0.00e+00
# Epoch 15: 8.75s to complete
#   error(train)=3.22e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 16: 9.41s to complete
#   error(train)=3.21e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 17: 9.45s to complete
#   error(train)=3.23e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 18: 9.40s to complete
#   error(train)=3.21e+00, acc(train)=1.28e-02, params_penalty=0.00e+00
# Epoch 19: 9.68s to complete
#   error(train)=3.23e+00, acc(train)=1.25e-02, params_penalty=0.00e+00
# Epoch 20: 8.43s to complete
#   error(train)=3.22e+00, acc(train)=1.39e-02, params_penalty=0.00e+00
# Epoch 21: 9.50s to complete
#   error(train)=3.22e+00, acc(train)=1.26e-02, params_penalty=0.00e+00
# Epoch 22: 8.63s to complete
#   error(train)=3.19e+00, acc(train)=1.32e-02, params_penalty=0.00e+00
# Epoch 23: 8.75s to complete
#   error(train)=3.20e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 24: 9.23s to complete
#   error(train)=3.20e+00, acc(train)=1.34e-02, params_penalty=0.00e+00
# Epoch 25: 9.75s to complete
#   error(train)=3.20e+00, acc(train)=1.37e-02, params_penalty=0.00e+00
# runtime: 396.176434994

# %%
origImgBatch, codecImgBatch = getOriginalAndEncodedBatches(dataProvider=trainData, model=model, noisy=True)

# %%
print "original images"
show_batch_of_images(origImgBatch)
# Out:
# original images
# (<matplotlib.figure.Figure at 0x7fcd3c20aa90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c2e0590>)

# %%
print "decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality %d" % hiddenDim
show_batch_of_images(codecImgBatch)
# Out:
# decoded images after passing from autoencoder with ReLU and Sigmoid non-linearities of dimensionality 50
# (<matplotlib.figure.Figure at 0x7fcd3c294250>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcd3c227450>)

# %% [markdown]
# We are doing the bare minimum and we are adding a layer with output dimensionality of 10 to do classification

# %%
inputFromPreviousLayer = hiddenDim
outputClassificationDim = 10

# %%
model.layers = model.layers[:-2] #drop the last two layers

# %%
model.layers.append(AffineLayer(inputFromPreviousLayer, outputClassificationDim, weightsInit, biasesInit))
model.layers.append(SigmoidLayer())

# %%
assert len(model.layers) == 4, len(model.layers)

# %%
assert trainData.std == 0.2

# %%
def addGaussianNoiseTransformerFormat(std):
    return lambda vectors, rng: vectors + std * rng.randn(vectors.shape[0], vectors.shape[1])

# %%
tempStd = 0.2
tempRng = np.random.RandomState(0)
test1 = addGaussianNoise(inputs, std=tempStd, rng=tempRng)
tempRng = np.random.RandomState(0)
test2 = addGaussianNoiseTransformerFormat(std=tempStd)(inputs, rng=tempRng)

assert np.all(test1 == test2), "asserting that the two implementations are the same"

# %%
# trainDataForClassification = AugmentedMNISTDataProvider('train', batch_size=50, rng=rng,
#                                                         transformer=addGaussianNoiseTransformerFormat(std=0.2))
trainDataForClassification = MNISTDataProvider('train', batch_size=50, rng=rng)
validDataForClassification = MNISTDataProvider('valid', batch_size=50, rng=rng)

# %%
numEpochs = 100

statsInterval = 5

learningRule = AdamLearningRule()

stats, keys, runTime = trainModel(model=model,
                                  error=CrossEntropySoftmaxError(),
                                  learning_rule=learningRule,
                                  train_data=trainDataForClassification,
                                  valid_data=validDataForClassification,
                                  num_epochs=numEpochs,
                                  stats_interval=statsInterval)

fig_1, ax_1, fig_2, ax_2 = plotStats(stats=stats, keys=keys, stats_interval=statsInterval)

print "runtime: " + str(runTime)

getFinalValues(stats)
# Out:
# Epoch 0:
#   error(train)=2.42e+00, acc(train)=7.97e-02, error(valid)=2.42e+00, acc(valid)=7.60e-02, params_penalty=0.00e+00
# Epoch 5: 0.98s to complete
#   error(train)=1.67e+00, acc(train)=7.68e-01, error(valid)=1.67e+00, acc(valid)=7.70e-01, params_penalty=0.00e+00
# Epoch 10: 1.07s to complete
#   error(train)=1.66e+00, acc(train)=7.78e-01, error(valid)=1.66e+00, acc(valid)=7.78e-01, params_penalty=0.00e+00
# Epoch 15: 1.02s to complete
#   error(train)=1.65e+00, acc(train)=7.83e-01, error(valid)=1.65e+00, acc(valid)=7.82e-01, params_penalty=0.00e+00
# Epoch 20: 1.11s to complete
#   error(train)=1.65e+00, acc(train)=7.86e-01, error(valid)=1.65e+00, acc(valid)=7.83e-01, params_penalty=0.00e+00
# Epoch 25: 1.03s to complete
#   error(train)=1.64e+00, acc(train)=7.88e-01, error(valid)=1.65e+00, acc(valid)=7.85e-01, params_penalty=0.00e+00
# Epoch 30: 1.14s to complete
#   error(train)=1.64e+00, acc(train)=7.90e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 35: 1.19s to complete
#   error(train)=1.64e+00, acc(train)=7.91e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 40: 1.03s to complete
#   error(train)=1.64e+00, acc(train)=7.91e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 45: 1.05s to complete
#   error(train)=1.64e+00, acc(train)=7.92e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 50: 1.10s to complete
#   error(train)=1.64e+00, acc(train)=7.92e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 55: 1.09s to complete
#   error(train)=1.64e+00, acc(train)=7.93e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 60: 1.03s to complete
#   error(train)=1.64e+00, acc(train)=7.93e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 65: 1.10s to complete
#   error(train)=1.64e+00, acc(train)=7.93e-01, error(valid)=1.65e+00, acc(valid)=7.85e-01, params_penalty=0.00e+00
# Epoch 70: 1.10s to complete
#   error(train)=1.64e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 75: 1.12s to complete
#   error(train)=1.63e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 80: 1.05s to complete
#   error(train)=1.64e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.86e-01, params_penalty=0.00e+00
# Epoch 85: 1.07s to complete
#   error(train)=1.63e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 90: 1.12s to complete
#   error(train)=1.63e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 95: 1.07s to complete
#   error(train)=1.63e+00, acc(train)=7.94e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# Epoch 100: 1.05s to complete
#   error(train)=1.63e+00, acc(train)=7.95e-01, error(valid)=1.65e+00, acc(valid)=7.87e-01, params_penalty=0.00e+00
# runtime: 119.202050924
# {'Final Testing Accuracy': 0.78700000000000014,
#  'Final Testing Error': 1.6505472454547678,
#  'Final Training Accuracy': 0.79479999999999851,
#  'Final Training Error': 1.6338478151874141}

# %% [markdown]
# The good news is that when we reached 100% percent accuracy if we had performed early stopping we would have concluded with a relatively high validation accuracy of 98.4%
#
# From epoch 40 and further we have severely overfitted and this causes the accuracy of both the training and especially of validation to drop.
